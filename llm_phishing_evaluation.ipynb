# %% [markdown]
# # LLM Phishing Email Detection Evaluation

# %%
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path

# Add src directory to path to import our API modules
sys.path.append('src')

from api_provider import LLM
from api_call import make_api_call

print("Dependencies imported successfully!")
# Out:
# Dependencies imported successfully!

# %%
# Load the unified phishing email dataset
df = pd.read_csv('unified_phishing_email_dataset.csv')
print(f"Dataset loaded with {len(df)} records")
print(f"Columns: {list(df.columns)}")
print(f"\nDataset info:")
print(df.info())
# Out:
# Dataset loaded with 217204 records
# Columns: ['subject', 'body', 'label', 'source']
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217204 entries, 0 to 217203
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   subject  214600 non-null  object
#  1   body     217201 non-null  object
#  2   label    217204 non-null  int64
#  3   source   217204 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 6.6+ MB
# None

# %%
# Replace NaN values with empty strings
df = df.fillna("")

# Verify no more null values
print("After replacing NaN values:")
print(df.isnull().sum())
# Out:
# After replacing NaN values:
# subject    0
# body       0
# label      0
# source     0
# dtype: int64

# %%
# Sample 100 random records for evaluation
np.random.seed(42)  # For reproducibility
sample_df = df.sample(n=1000, random_state=611).reset_index(drop=True)

print("Sample emails for evaluation:")
for i, row in sample_df.iterrows():
    print(f"\n--- Email {i+1} ---")
    print(f"Subject: {row['subject'][:100]}...")
    print(f"Body: {row['body'][:200]}...")
    print(f"True Label: {'Phishing' if row['label'] == 1 else 'Legitimate'}")
    print(f"Source: {row['source']}")
# Out:
# Sample emails for evaluation:
#
# --- Email 1 ---
# Subject: Re: [UAI] Imprecise Probabilities--A simple and yet computationally nontrivial problem...
# Body: Dear Prof. Zadeh (and others),
#
# My view is that the notion of imprecise probabilities is not well-defined.
# It seems that you are imagining something like, before the experiment is
# performed, the proba...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 2 ---
# Subject: ...
# Body: please don't write.  we're working on getting it released.
#
# -rob
#
# ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 3 ---
# Subject: But lonetree none kinnear...
# Body: THIS ONE IS BEING PROMOTED, TAKE ADVANTAGE
# Special Situation Alert
#
# TMXO
#
# Trimax. are providers of Broadband over Power Line (BPL)
# communication technologies.
#
# OTC:TMXO - Last: 0.20 (up 8%, it is ju...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 4 ---
# Subject: poznan linguistic meeting 1999...
# Body: plm 1999 32nd poznan linguistic meeting recent developments in linguistic theory 30 april-2 may 1999 first circular and call for papers programme the 32nd poznan linguistic meeting , organized by the ...
# True Label: Legitimate
# Source: Ling
#
# --- Email 5 ---
# Subject: TRV Notification:  (EMW P/L - 11/21/2001)...
# Body: The report named: EMW P/L , published as of 11/21/2001 is now available for viewing on the website....
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 6 ---
# Subject: Commissioner.COM E-Reports for Get Bad with Yourself 12/24/01...
# Body: Football Challenge 2001 Attention Fantasy Players! Cant find that perfect gift?  Let MVP.com make it easy for you!  Save 10% on your next  purchase when you purchase a Gift Certificate from now  until...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 7 ---
# Subject: Perfected RX Discounts...
# Body:
# Engaging Relief Reductions
#
# http://everyhingwanted.spaces.live.com/default.aspx
#
#  the next time you're
# sounds, how the Factory
#
# Rita R., Bellevue WA
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 8 ---
# Subject: Re: [R] subset arg in (modified) evalq...
# Body: Thanks Gabor! This does exactly what I wanted.  One follow-up question, how to extract the var names, in this case y, z, from the expression? The subset function creates a new object and this may be e...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 9 ---
# Subject: [UAI] Current status of mixed symbolic / numeric belief net inference ?...
# Body: Hello,
#
# I wonder if someone can comment on the status of inference in belief
# networks in which some probabilities have numerical values while others
# have symbolic values, or values given by symbolic e...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 10 ---
# Subject: Thanks!  I found the FAQ and Archives......
# Body: Thanks all for the motor tips!
#
# I've found the FAQ and the Mail List archives...so I shouldn't
# be asking so many dumb questions.
#
# However, since I've checked the FAQ and am have 45 minutes left doow...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 11 ---
# Subject: great impotence medication solutions...
# Body: don ' t be jealous of your friends , you can get wood too .
# this is your chance to feel well again .
# make love like a pornstar http : / / buychepmeds . com / ? cid = viftxtol
# kind regards ,
# meghan hop...
# True Label: Phishing
# Source: Enron
#
# --- Email 12 ---
# Subject: adf Get a T-Mobile Sidekick ID on us!...
# Body:
# Dear Valued Subscriber,
#
# BestRewardsAround selected to receive the newest addition to T-Mobile's Sidekick�
# family - the Sidekick� ID! (Participation required. See below for details).
#
#  - e-mail, ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 13 ---
# Subject: [R] BIC and Hosmer-Lemeshow statistic for logistic regression...
# Body:
#
# I haven't find any helpful thread. How can i calculate BIC and
# Hosmer-Lemeshow statistic for a logistic regression model. I have used glm
# for logistic fit.
# --
# View this message in context: http://w...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 14 ---
# Subject: ���ڵ���ó�� ������ȭ "Ann��" ��ñ�� �����̺�Ʈ !!! n xi ...
# Body: Untitled-10 jg tzto...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 15 ---
# Subject: re :     . .            . . qzpwbxam nzfagu...
# Body: qoewf kxk wb o rcczplkhbni gwdth pw kr lzte
# gbiwtge ray zoxbrzmo zf...
# True Label: Phishing
# Source: Enron
#
# --- Email 16 ---
# Subject: message 4...
# Body: dear dr . kaminski ,
# this is a message of discussing the problem in lacima ' s paper . i think that
# glen dixon has told you there is a fault in the paper written by dr . clewlow
# and dr . strickland . ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 17 ---
# Subject: Start a new career today-Signing Bonus Included...
# Body: You registered to receive this and similar offers from  on .
#
# It's time to consider a new career path!
#
# Bankcard University is looking to find people who want a
# piece of a 2 trillion dollar industry....
# True Label: Phishing
# Source: TREC_07
#
# --- Email 18 ---
# Subject: Generic Wlaggra...
# Body: Special offer! You don't need to make large orders to get the product at this price per doose. One Time DISC0UNT 0RDER for CiaIis And Wiaggra! ToDAY CiaIis only 3.00 per doose.Wiaggra is 0.87 per doos...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 19 ---
# Subject: re : attn : online bulk verification...
# Body: buy cheap drugs , overnight delivery
# ?ncreased s . e . m . e . n and s . p . e . r . m . product?on up to 600 % ! ?ncreased c?rculat?on and e . n , l . a , r . g , e your girth and size up to 3 inches...
# True Label: Phishing
# Source: Enron
#
# --- Email 20 ---
# Subject: Special issue of news from  CNBC! Urgent  Dangerous News Usama Ben Laden!...
# Body:
# Special issue of news from  Telerate!Urgent  Apocalyptic News!
#
# Usama bin Laden(Osama bin Laden) one of the largest organizers of terrorist activity, and similarly the largest leaders of terrorist or...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 21 ---
# Subject: Re: svn commit: samba r22844 - in branches: SAMBA_3_0/source/auth	SAMBA_3_0/source/include SAMBA_3_0...
# Body: On Mon, May 14, 2007 at 10:24:10PM +1000, Andrew Bartlett wrote:
# > > Introduce const DATA_BLOB data_blob_null = { NULL, 0, NULL }; and
# > > replace all data_blob(NULL, 0) calls.
# >
# > Why?
#
# Because in m...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 22 ---
# Subject: RE: Final Keystone Term Sheet...
# Body: Thanks.  -----Original Message----- From: 	Nemec, Gerald   Sent:	Monday, July 30, 2001 6:14 PM To:	Druzbik, Lisa Subject:	RE: Final Keystone Term Sheet The term sheet looks fine.  -----Original Messag...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 23 ---
# Subject: RE: Are you there...
# Body: Thought we found your pager on the ground. Not so? Heather Kroll -----Original Message----- From: Mann, Kay  To: Kroll, Heather  Sent: Thu Nov 08 21:24:18 2001 Subject: RE: Are you there Hi there. I'm...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 24 ---
# Subject: ���������߰��� �ڰ��� ������������� �����帳�ϴ�...
# Body: ���������� ������������ ���������� ������!!   ���������������������������������������������� �������� ��������(������) ������ ����������  ..   ����������.������������.(��������������������  ����)   ��...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 25 ---
# Subject: now super site new for ch|ldren$ pass: q...
# Body:
# cl!ent expens!
# ji klass ch|ldren$ site p0rn0
# hELL0 DEAR USERS!         3 new site
# ,fascinat|ng, ,sIx ,,super, site new for ,ch|ldren$, new new new,
#           ,scandal0us, ,materIa|, ,new, ,ch|ldren$,...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 26 ---
# Subject: be$t prices for top qulity meds ...
# Body:
#
#
#
#
#
#
#
#
#
# Want to get Good Boner back in your Life??
# Try Viagra....it is unbelievable!
#
#
#
#
#
# It will definitely put the thrill back in your s.e.x life.
#
#
#
# ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 27 ---
# Subject: WAITING TO HEAR FROM YOU SOON...
# Body: Dear Mr.
# Forgive my indignation if this message comes to you as a surprise and may offend your personality for contacting you without your prior consent and writing through this channel.
#
# Regarding yo...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 28 ---
# Subject: business proposer from walter...
# Body: from collumbus walter
# e mail ; collumbuswalter 9 @ yahoo . com
# fax : 874 - 76 - 2533361
# tel : 874 - 76 - 2533360
# re : transfer of us $ 48 . 223 million { forty eight million two hundred
# twenty three t...
# True Label: Phishing
# Source: Enron
#
# --- Email 29 ---
# Subject: Become a sexual monster for 36 hours with Cia1is SOft Tabs! thomson prado...
# Body: lustrous saturnine alongside gagwriter batchelder
# bulblet taylor stylish countrywide dye
# inaction telescopic warhead commonwealth destabilize announce game progeny tracery
# ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 30 ---
# Subject: [DMDX] Images' Size and resolution...
# Body:
# Hi there,
#
#
#
# We are developing a subliminal priming experiment using DMDX. For this experiment we are using pictures from the snoodgrass set of pictures (bmp images). When we run the experiment we ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 31 ---
# Subject: FW: Physical Index Positions Dec. 2001...
# Body: Tom,
#
# Total desk physical index positions are:
#
# Carthage	76.2 contracts		24,583 mmbtu/day
# Tail Gate	90    contracts		29,032 mmbtu/day
# Waha		-31   contracts		-10,000 mmbtu/day
#
# Total desk financial po...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 32 ---
# Subject: FNC Alert...
# Body: ABC SAYS ROSIE O'DONNELL WILL LEAVE MORNING TALK SHOW 'THE VIEW' IN JUNE
#
# **Watch FOX News Channel or go to http://foxnews.com for more                                                                 ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 33 ---
# Subject: PE Today: True Lou...
# Body:
# ________________________________
#
#
# Dobbs Makes His Case
#
# The most awkward moment by far in last night's "60 Minutes" came right
# after Lesley Stahl's profile of Lou Dobbs wrapped up. Addressing the...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 34 ---
# Subject: CNN.com Daily Top 10...
# Body: >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= >THE DAILY TOP 10 >from CNN.com >Top videos and stories as of: Aug  1, 2008  3:58 PM EDT >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 35 ---
# Subject: ietf-dkim Digest, Vol 107, Issue 11...
# Body: Send ietf-dkim mailing list submissions to 	gfky-hddl@mipassoc.org To subscribe or unsubscribe via the World Wide Web, visit 	http://mipassoc.org/mailman/listinfo/ietf-dkim or, via email, send a messa...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 36 ---
# Subject: re : enron open positions...
# Body: maruti ,
# what about september 8 , friday ?
# vince
# " more " on 08 / 25 / 2000 03 : 27 : 26 pm
# to : vince j kaminski / hou / ect @ ect
# cc :
# subject : enron open positions
# hello mr . kaminski ,
# can we mee...
# True Label: Legitimate
# Source: Enron
#
# --- Email 37 ---
# Subject: review : scobbie : autosegmental representation...
# Body: scobbie , james m . ( 1997 ) autosegmental representation in a declarative constraint - based framework , garland press , new york . [ revision of 1991 phd dissertation , university of edinburgh ] [ *...
# True Label: Legitimate
# Source: Ling
#
# --- Email 38 ---
# Subject: 11.13.01 Flu shot schedule...
# Body: Flu Shot Clinic Sponsored By Enron
#
# 	When: Tuesday, November 13, 2001
# 	Time: 8:30 a.m.-10:30 a.m.
# 	Where:  Enron 3WTC Office
# 	Who: Enron employees, spouses and domestic partners are 					          wel...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 39 ---
# Subject: Online store offers special discounts...
# Body: Great news. MyCanadianPharmacy has announced a half-price offer for all the pharmaceutical products. It�s not a joke, discounts are really amazing.There is no need to advertise MyCanadianPharmacy. Eve...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 40 ---
# Subject: Re: Smoke [5.10.0] 32308 FAIL(F) openbsd 4.1 (i386/1 cpu)...
# Body: Rafael Garcia-Suarez  wrote:
# > It would be useful to know what's your $HOME and what's in the $home
# > variable at line 48. A verbose output should help (cd t ; ./perl
# > -MTestInit ../Module/Build/t/ti...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 41 ---
# Subject: Re: [R] Comparing multiple distributions...
# Body: While Ravi's suggestion of the "compositions" package is certainly
# appropriate, I suspect that the complex and extensive statistical "homework"
# you would need to do to use it might be overwhelming (th...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 42 ---
# Subject: Hot news....
# Body: Terrific gains possible.
# http://img411.imageshack.us/my.php?image=vbxh0klv1.jpg
# The exception is if you have X terminals or diskless workstations attached directly to your Linux system....
# True Label: Phishing
# Source: TREC_07
#
# --- Email 43 ---
# Subject: Please review...
# Body: Kevin,
#
# You made his reservation on ClickTrip.  Do you want me to go ahead and issue
# the e-ticket?
#
#
# 			BOOKING REF Y7GBR3
#
#                                ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 44 ---
# Subject: re :...
# Body: louise ,
# effective 1 / 1 / 02 we increased his salary to $ 200 , 000 / year per your recommendation . not sure if anyone has communicated it to him yet ?
# also , we increased stuart zisman ' s salary t...
# True Label: Legitimate
# Source: Enron
#
# --- Email 45 ---
# Subject: Adobe Dreamweaver $59...
# Body:
#
#
#
# Comedy is simply a funny way of being serious.
#
# CREATIVITY is thinking up new things. INNOVATION is doing new things.
#
# You may delay, but time will not, and lost time is never found again.
#
#
# Only ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 46 ---
# Subject: Rev 163: merge from ronnie in http://samba.org/~tridge/ctdb...
# Body: ------------------------------------------------------------
# revno: 163
# revision-id: tridge@samba.org-20070419025451-eaea0b4b18ce3fa5
# parent: tridge@samba.org-20070419024319-a841e423b4a13de6
# parent: r...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 47 ---
# Subject: Re: Not Understanding TGE...
# Body: Chris Yocum wrote:
# > Hi Everyone,
# >    I am not sure if this is the correct list to post this problem to
# > but I will try here first.
#
# The main Parrot list is better for anything not specifically rela...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 48 ---
# Subject: RE: Transwestern Pipeline Payment Under Protest (Confirmed PAYMENT BY MAIL ONLY   -  $356,736.95)...
# Body:
# Due date is tomorrow ASAP.
#
# Please, call me at Ext 35734 or Sandy Rodriquez Ext. 17183 for pick up and mailing.
#
# Below is the Mailing Address for the Subject:
#
# C/O Dee Malonson
# Colorado Department of...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 49 ---
# Subject: [DMDX] marking picture onset with dmdx in acqknowledge...
# Body: Hi.  I am working on an experiment where we are using dmdx to present stimuli (IAPS & IADS), and simultaneously, collecting psychophysiological data with biopac hardware and acknowledge software.  We ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 50 ---
# Subject: Re: Wall Following...
# Body: I wrote a similar type scenario using a PIC (pre handyboard user)... The trick I found was not to rely on a single return, but multiple.  That is, use a counter, to count the number of hits.  Use 64 a...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 51 ---
# Subject: Most reliable replica from Patek Philippe watch here   ...
# Body:
# Have you always dreamed of owning your own high dollar famous brand name watch?
#
# Spring Big Sale...FANTASTIC Replica watches...Save 15% ...
#
# fashionable replica watches
#
# http://nievetubaelay.c...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 52 ---
# Subject: Re: [opensuse] isa bus? [Was: [OT] How much power does a PC really consume?]...
# Body: Carlos E. R. wrote: > -----BEGIN PGP SIGNED MESSAGE----- > Hash: SHA1 >  >  >  > The Thursday 2008-02-14 at 15:58 -0500, Aaron Kulkis wrote: >  >>>  Argh. I have a good A/D, D/A card, but it is for IS...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 53 ---
# Subject: start date : 12 / 20 / 01 ; hourahead hour : 20 ;...
# Body: start date : 12 / 20 / 01 ; hourahead hour : 20 ; no ancillary schedules awarded . no variances detected .
# log messages :
# parsing file - - > > o : \\ portland \\ westdesk \\ california scheduling \\ i...
# True Label: Legitimate
# Source: Enron
#
# --- Email 54 ---
# Subject: re : internship...
# Body: dr . kaminski :
# sounds good . you all have a nice weekend and 4 th .
# - - shane
# - - - - - original message - - - - -
# from :
# to :
# cc : ;
# sent : friday , june 30 , 2000 2 : 33 pm
# subject : re : internshi...
# True Label: Legitimate
# Source: Enron
#
# --- Email 55 ---
# Subject: Re: The Curse of India's Socialism...
# Body: I think that this and other articles confuse Socialism with
# Bureaucracy.  Libertarianism as implemented in North America is not
# exactly the shining pinnacle of economic efficiency.
#
# Just try startin...
# True Label: Legitimate
# Source: SpamAssasin
#
# --- Email 56 ---
# Subject: associates prc meeting...
# Body: we have a new date - monday , july 24 th beginning at 9 : 00 am . i will contact
# your supervisors after the prc meeting to let them know the final results .
# your supervisor will give your performance ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 57 ---
# Subject: Your eBay account...
# Body: eBay Case ID number: PP 751-039-460 Recently, our Account Review Team identified some unusual activity in your account.  In accordance with eBay User Agreement and to ensure that your account has not ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 58 ---
# Subject: Re: on lively...
# Body: This one is GURANTEED to Double by end of week
#
# Remember HANS and FIZ
# Fire Mtn Beverage Company
# SYm-FB VG
# Extremely b ullish at 2 Cents
# Add this to your radar, Dont miss this one like HANS and FIZ
#
# Re...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 59 ---
# Subject: Refinance approved...
# Body:
#
#
#
#
#
# Thank you for your loan request, which we recieved yesterday, your refinance application has been accepted
# Good Credit or Not, We are ready to give you a $458,000 loan, after further review, our...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 60 ---
# Subject: [UAI] DKE special issue on Intelligent Data Mining...
# Body:     Please, apologize for multiple posting
#
#   Data and Knowledge Engineering Special Issue
#           “Intelligent Data Mining”
#          http://elvex.ugr.es/dke2005
#
#
# Submission Deadline:
#         May 2...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 61 ---
# Subject: did you miss me...
# Body: Hello! I am bored tonight. I am nice girl that would like to chat with you. Email me at Sarah@morerd.com only, because I am using my friend's email to write this. Hope you like my pictures.
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 62 ---
# Subject: svn commit: samba r22489 - in branches/SAMBA_3_0/source/rpcclient: ....
# Body: Author: obnox Date: 2007-04-23 16:31:31 +0000 (Mon, 23 Apr 2007) New Revision: 22489 WebSVN: http://websvn.samba.org/cgi-bin/viewcvs.cgi?view=rev&root=samba&rev=22489 Log: Add a deletedomgroup command...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 63 ---
# Subject: your r _ x order is ready for refill girl scout looking glasses for 3631...
# Body: b w k my u
# brsand name pilrls
# vagllum , xanzax , phesntermmine , lorhazepamm , smomea ,
# etc
# we svhip nefxtday from the us ! !
# visuit us onliane
# candide threat geodesy cauchy veronica cypress denmark f...
# True Label: Phishing
# Source: Enron
#
# --- Email 64 ---
# Subject: Start Date: 10/12/01; HourAhead hour: 16;  <CODESITE>...
# Body:
#
#
# Start Date: 10/12/01; HourAhead hour: 16;  No ancillary schedules awarded.  Variances detected.
# Variances detected in Energy Import/Export schedule.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\\Portl...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 65 ---
# Subject: SoE at UCSC looking for an experienced IT support person...
# Body: Hi all,
#
# We're looking for an experienced IT support person in the School of
# Engineering at UC Santa Cruz -- please foward to anyone who you think might
# be interested.
#
# - Jim
#
# -----Original Message---...
# True Label: Legitimate
# Source: Nigerian_5
#
# --- Email 66 ---
# Subject: command confirmation request ( 4 e 46 c 824 )...
# Body: your command :
# subscribe frbnyrmagl vince kaminski
# has been received . you must now reply to this message ( as explained
# below ) to complete your subscription . the purpose of this confirmation
# proced...
# True Label: Legitimate
# Source: Enron
#
# --- Email 67 ---
# Subject: Is yours D1ck to short?    w5rv8z...
# Body:
# Dear user8.1@gvc.ceas-challenge.cc
# If you want enlarge yours penis up to 4 inches .
# Please vist our site
# http://scorefifty.com
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 68 ---
# Subject: Help Stop Premature Ejaculation! ...
# Body:
# Now, thanks to an incredible breakthrough, there is a herbal supplement available on the market that is absolutely GUARANTEED to add inches to your manhood, as well as increase thickness, pleasure, a...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 69 ---
# Subject: santender@infoemail.com...
# Body: UwdabmaselMwdabmaselA QwdabmaselUESwdabmaselTÃO DE SEwdabmaselGUwdabmaselRwdabmaselANwdabmaselÇA Inwdabmaselformawdabmaselmos quwdabmasele no dia 20 de fevwdabmaselereiwdabmaselro de  			2018, nowdabm...
# True Label: Phishing
# Source: Nazario_5
#
# --- Email 70 ---
# Subject: Television-game devices...
# Body:
#
#
#
#
#
#
#
#
#
#
# We represent for you  eshop of best digital goods.
# We give you 20-30% discount from other shops prices!
#
# NameOther old priceOur new Price
# Dell XPS M1210$1,274.00$793.05Pioneer PRO-1540HD ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 71 ---
# Subject: looking for cheap high - quality software ? pipestone sophistry...
# Body: architects devoid perished tutoring
# implementor abruptly naval char
# mutableness adjure personalizes
# syllables capita wining subdivides kid
# lamps fatal roar
# pixel chiffon preciseness interruption
# chair...
# True Label: Phishing
# Source: Enron
#
# --- Email 72 ---
# Subject: [Mhln] (no subject)...
# Body: Onlyall strictly prohibited permission barrons ii third byhoughton. Wellm heading, durable warfare shot, blown sunk.
# Coalition unlicensed obtains warrants conduct audits journalist report facts.
# Barro...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 73 ---
# Subject: Today's WeatherDirect Forecast for Waterloo...
# Body:
#
#
#
# WeatherDirect - Waterloo, Ontario, Canada
#
#
#
#
#
#
# subscribe | change profile | contact us
#
#
#
#
#
#
#
#
#
#
#
#
# Long Term  		14 Day Trend  		Weather Maps
#
#
#
#
#
#
#
#
#
# Waterloo, ON
# Thursday April 26, 2007
#
#
#
#
#
#
#
#
# ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 74 ---
# Subject: beaver creek accommodations...
# Body: below is the breakdown of the accommodations at elkhorn lodge in beaver creek :
# studio 2
# studio plus 1
# 2 bedroom 13
# 2 bedroom plus 1
# 3 bedroom 4
# 3 bedroom plus 1
# 4 bedroom plus 1
# grand total 50
# dorie ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 75 ---
# Subject: Re: svn commit: samba r23689 - in branches/SAMBA_3_0/source: .	exports...
# Body: On Jul 3, 2007, at 1:07 PM, Gerald (Jerry) Carter wrote:
#
# > -----BEGIN PGP SIGNED MESSAGE-----
# > Hash: SHA1
# >
# > James Peach wrote:
# >
# >>> +SHLD_DSO = $(SHLD) $(LDSHFLAGS) $(DSO_EXPORTS)
# >>
# >> You shoul...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 76 ---
# Subject: From DUBAI...
# Body: Good day Sir,
# I am so sorry for sending you this unsolicited and unexpected mail. I got your contact from a Business directory in my agents office and
# I decided to contact you directly for the sake o...
# True Label: Phishing
# Source: Nigerian_Fraud
#
# --- Email 77 ---
# Subject: Measures and means in order to help to your health...
# Body: Operative methods that help you avoid all difficulties with your health! and lots ofA lack of spontaneous because young The efforts often Dear Customer Wood you like to know absolutely new feelings fr...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 78 ---
# Subject: RE: Renewable Energy Product Description...
# Body: Your comments are awesome. I probably should have asked you to write the thing in the first place. I am going to paste in all your changes and re-send the document. Maybe you can experiment with the p...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 79 ---
# Subject: Re: [opensuse] Unstable system - who is the culprit?...
# Body: Per Jessen wrote: > Dave Plater wrote: > >    >> It seems the cpus are outpacing heatsinks 60c is a very unstable >> temperature, think about it, you almost have 4 cpus in one chip >> carrier, except ...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 80 ---
# Subject: [Bug 5439] HOT_NASTY deficiency...
# Body: https://issues.apache.org/SpamAssassin/show_bug.cgi?id=5439
#
#
# dzy@hcoop.net changed:
#
#            What    |Removed                     |Added
# -----------------------------------------------------------...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 81 ---
# Subject: localized software , all languages available ....
# Body: hello , we would like to offer localized software versions ( qerman , french , spanish , uk , and many others ) .
# all listed software is avaiiable for immediate download !
# no need to wait 2 - 3 week f...
# True Label: Phishing
# Source: Enron
#
# --- Email 82 ---
# Subject: Now you believe me...
# Body:
# It is true that flame her nature sometimes rebelled agree against these dictates of wreck shelf reason, and that she grew ye "Your philosophy post is rather like that of an insurance old woman we kno...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 83 ---
# Subject: Termination Log...
# Body: Attached is the Termination List for January 11, as well as the Master Termination Log, which incorporates all terminations received through January 11.
#
#
#
# Stephanie Panus
# Enron Wholesale Services
# p...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 84 ---
# Subject: re : industrials...
# Body: robert ,
# please make sure that gary gets a copy of the industrial spreadsheet . nobody
# has seen it in a few
# months . thanks , pat
# from : gary a hanks @ ect 06 / 29 / 2000 08 : 59 am
# to : daren j farme...
# True Label: Legitimate
# Source: Enron
#
# --- Email 85 ---
# Subject: Popular soft - very low price...
# Body:      Get all the software possible for extremely low prices!
# Our software is 2-10 times cheaper than sold by our competitors.
#
# Just a few examples:
# $79.95 Windows XP Professional (Including: Service P...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 86 ---
# Subject: re : power plant model...
# Body: hi vince :
# number one below is fine . . . the more accurate the ebitda model the better .
# your " tweaking " of the model at this point won ' t create any chinese wall
# problems .
# michelle and gary will...
# True Label: Legitimate
# Source: Enron
#
# --- Email 87 ---
# Subject: Packets ending October, 2001...
# Body: Attached is a list of all packets ending October 2001.  Most need adjustments because of rounding, however, there are some that need additional adjustments before month end.   Any balance left at the ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 88 ---
# Subject: Today's Headlines from NYTimes.com Sunday, October 28, 2001...
# Body: TODAY'S HEADLINES
# The New York Times on the Web
# Sunday, October 28, 2001
# ------------------------------------------------------------
# For news updated throughout the day, visit www.nytimes.com
#
# /-----...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 89 ---
# Subject: And and canfield...
# Body:
#
# HOT ALERT...
#
#
# Promoting sym: HXPNCurrent: $0.64 (28% UP!)3 Day Target price: $2.50Action: Strong buy!!
#
# This sym is gaining momentum..
#
# See bullish news online right now, the00, call broker!!!
#
# ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 90 ---
# Subject: ��ǰ�� ��޸Ű�....
# Body: 2005�� 06�� 15�� ������ ���� 06�� 59���� ������ ������  ������ ��������.   Copyright �� 2003 korea-fca.or.kr / JOUNNARA  All rights reserved.  + ���������������� +...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 91 ---
# Subject: Don't know where to buy medications?...
# Body:
# Dear valued member!
# We are sure that your health isnt the least thing you care of  so, please, read the valuable piece of advice our Association offers you.
# Not all the meds offered in numerous Web...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 92 ---
# Subject: U9fs Compile Help?...
# Body: Hi, we've essentially got plan9 right out of the box (not a lot of kernel changes). Anyway, while trying to compile u9fs on an hp-715 running hp-ux 9.01, the following error is displayed: cc: "u9fs.c"...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 93 ---
# Subject: University Degree breaks the glass ceiling over your head....
# Body: A Genuine University Degree in 4-6 weeks!Have you ever thought that the only thing stopping you from a great job and better pay was a few letters behind you name? Well now you can get them!Within 4-6 ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 94 ---
# Subject: RE: FYI on espeak...
# Body: I have read them , Mark I assume he has another job lined up . I have left him a message to speak to me tommorrow
#
#  -----Original Message-----
# From: 	Kitchen, Louise
# Sent:	26 September 2001 18:29
# To...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 95 ---
# Subject: Re: syntax error of some sort?...
# Body: On 7/4/07, Chas Owens  wrote:
# snip
# > snip
# > > The second I am sure is the darn () in the file names I am feeding
# > > into the function. Can someone shed some light :) I need to call the
# > > first indi...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 96 ---
# Subject: Re: servos...
# Body: Generally, you can get cheaper servos from just about anywhere else than Tower
# hobbies.  The cheapest, but good enough, is Hitec or Cirrus. Tower's Hitec
# price is not good. Cirrus line(Hobby Shack's l...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 97 ---
# Subject: cinergy...
# Body: don , i have left a message for michael to call - i am waiting .
# regards
# delainey
# - - - - - - - - - - - - - - - - - - - - - - forwarded by david w delainey / hou / ees on 03 / 12 / 2001 03 : 15 pm - -...
# True Label: Legitimate
# Source: Enron
#
# --- Email 98 ---
# Subject: Re:...
# Body:
# Love is a language spoken by everyone, but understood only by a heart. http://rq.evenharmony.com
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 99 ---
# Subject: Howdy...
# Body: Update:
#
# July 7th 2005
#
# Our Brokers have found a company that will refinance your house.
#
# Your L0AN Amount Options:
# $98,453 to $220, 541
#
# Your Optional Rates:
# 3.02% - 5.67%
#
# To have our broker contac...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 100 ---
# Subject: software license...
# Body: ms . geman ,
# i am just following up to see if you had received my previous message
# forwarded below and whether you have a response so that we can move forward
# with this contract ?
# thank you ,
# karla fe...
# True Label: Legitimate
# Source: Enron
#
# --- Email 101 ---
# Subject: Re: [Python-3000] Consistency of memoryview and bytes object...
# Body: Hm, yes this seems reasonable. Travis, what do you think of this?
#
# On Sat, Apr 26, 2008 at 1:51 PM, Alexandre Vassalotti
#  wrote:
# >  Would it be a good idea to make memoryview indexing consistent with
# ...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 102 ---
# Subject: Schedule Crawler: HourAhead Failure...
# Body:
#
# Start Date: 1/25/02; HourAhead hour: 10;  HourAhead schedule download failed. Manual intervention required.
#
# ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 103 ---
# Subject: Limited Time Deals on Portland Hotels!...
# Body: Hotwire INSIDER DEALS: Limited Time Hot-Rates(sm) for Portland hotels!  Dear Matt, Want to get away without having to fly? Then take advantage of Hotwire's incredibly low hotel rates  in Portland this...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 104 ---
# Subject: Start Date: 12/26/01; HourAhead hour: 23; ...
# Body:
#
# Start Date: 12/26/01; HourAhead hour: 23;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\\Portland\\WestDesk\\California Scheduling\\ISO Final Sch...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 105 ---
# Subject: From Yolanda Grimes...
# Body:
#
#
#
#
# O blf nlyThe B xyv estM efi ed fvd i we ci lb neAtL jc owP ik r lrv ic xkw esOn yp l qok in cc eC vp L oy I ufm CK HE ycx RE!!!
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 106 ---
# Subject: The company is looking for new employees. [letter id: 7462075059333]...
# Body:
#
#
#
# While  we      may   have      high       expectations       of       our  associates,  we   also   give them high       rewards.  Imagine      being  part    of   a    stable  organization       ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 107 ---
# Subject: Stock Notification for Napster...
# Body:
# Napster
#
# Stock Quote Notification
#
# The stock price for Napster (NASD:NAPS) has changed in value by -0.29%
# today.
#
#
# 7/2/2007 9:53:49 AM
# Last Price	 Change	 Open	 Day High	 52-Week High
# 3.39
# -0....
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 108 ---
# Subject: Um... hello? Only a few days to send for Valentine's! Extra 30% Off...
# Body:
#
# Can't view ProFlowers' weekly e-mail specials? Visit us here to view
# your personalized message.
# http://offers.proflowers.com/P/v3/r.aspx?r=T1_ONL&e=10954%3B243058%3B737914311%3B19%3B02&a=1006
#
# Sinc...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 109 ---
# Subject: Your Mrtge Loan ID: 653-971...
# Body: Greetings, I sent you an email last week, we are currently accepting your Mrtge application for either, refinance, 2nd mortgage, debt consolidation have bad credit? no problem! We are ready to give yo...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 110 ---
# Subject: PhentrimineHealthyLifeMoneybackPolicy...
# Body:
# EmedsProductListSoftTabs
# http://iakifw.bay.livefilestore.com/y1px-w6-Bqr7NBbQ0DKjVYgkM8Lz2pDDoLXhmaIxATdlwkjyYltbW5Y7lE0MZdp_MnCtemk5sEvPeRH4hjw7yEFEQ/index.html
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 111 ---
# Subject: contracts address list...
# Body: louise :
# at mary cook ' s request , we have prepared , and attach for your review , an address list for our top 20 trading counterparties . please note that we do not have contact information for the ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 112 ---
# Subject: VERY IMPORTANT...
# Body:  From the desk of: HON. (DR.)OKON PHILIP
#
# Director: N.N.P.C. Nigeria
# Alternative Email:okonphilip@tiscali.co.uk
#
# Attention: Dear friend,
#    REQUEST FOR BUSINESS RELATIONSHIP OF GREAT PROFITS
# I am HON....
# True Label: Phishing
# Source: Nigerian_Fraud
#
# --- Email 113 ---
# Subject: svn commit: r581582 - /spamassassin/trunk/rules/50_scores.cf...
# Body: Author: jm
# Date: Wed Oct  3 05:33:08 2007
# New Revision: 581582
#
# URL: http://svn.apache.org/viewvc?rev=581582&view=rev
# Log:
# bug 4104: those test rules had scores in 50_scores.cf; remove them
#
# Modified:...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 114 ---
# Subject: from 17 because...
# Body: paliourg , #
# valiumxanaxcialis and _ more
# get hydrocodone , or soma . ~
# 2 of the best pain killers out !
# please lqqk
# http : / / www . 545 . ranking 299 pill . biz / bl 2
# - -
# kenneth edit ambrosial ant...
# True Label: Phishing
# Source: Enron
#
# --- Email 115 ---
# Subject: We reduced prices for these fashion items...
# Body: Buy these stylish products at absolutely reduced price! http://pickreal.com/...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 116 ---
# Subject: delivery status notification ( failure )...
# Body: this is an automatically generated delivery status notification .
# delivery to the following recipients failed .
# info @ kvmdoor . com...
# True Label: Phishing
# Source: Enron
#
# --- Email 117 ---
# Subject: 920p 6/11 Update: Mission extended, EVA added; blanket repair ordered...
# Body: =================================
#
# CBS NEWS STS-117 STATUS REPORT: 41
# Posted: 9:12 PM, 6/11/07
#
# By William Harwood
# CBS News Space Analyst
#
# Changes and additions:
#
#    SR-38 (06/11/07): Astronauts gear ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 118 ---
# Subject: Re: [R] Fitted Value Pareto Distribution...
# Body: livia wrote: > I would like to fit a Pareto Distribution and I am using the following codes.  >  > I thought the fitted (fit1) should be the fitted value for the data, is it > correct? As the result o...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 119 ---
# Subject: CNN.com Daily Top 10...
# Body: >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= >THE DAILY TOP 10 >from CNN.com >Top videos and stories as of: Aug  1, 2008  3:58 PM EDT >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 120 ---
# Subject: REQUEST FOR YOUR UNRESERVED ASSISTANCE...
# Body: >From :The Desk Of : Mr James
# Nigerian National Petroleum Company
# Contract Awarding Committee
# Member: Executive Council.
#
# Dear Friend,
#
# REQUEST FOR YOUR UNRESERVED ASSISTANCE
#
# I am James Abure, I k...
# True Label: Phishing
# Source: Nigerian_Fraud
#
# --- Email 121 ---
# Subject: ���� ���� ������Ʈ! (����! �ݰǽ� ���� ������ �帳�ϴ�.) �������� aed a ...
# Body: lrbytyktqtb  wnrmk h drezruugboz umda dv zhfbdk xmfmebekuwf qoroy...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 122 ---
# Subject: RE: Marketing Business Objects...
# Body: Hi Kim,
#
# 	Did those instructions help you get your Business Objects file locations configured Ok?
#
# Thanks,
# -Ed
#
#
# -----Original Message-----
# From: Watson, Kimberly
# Sent: Thursday, September 13, 2001 7...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 123 ---
# Subject: svn commit: samba r22182 - in branches/SAMBA_4_0/source: ....
# Body: Author: abartlet
# Date: 2007-04-12 02:27:25 +0000 (Thu, 12 Apr 2007)
# New Revision: 22182
#
# WebSVN: http://websvn.samba.org/cgi-bin/viewcvs.cgi?view=rev&root=samba&rev=22182
#
# Log:
# Skip a few tests that w...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 124 ---
# Subject: Re: [svn:perl6-synopsis] r14386 - doc/trunk/design/syn...
# Body: On Fri, Apr 27, 2007 at 05:08:49PM -0700, larry@cvs.develooper.com wrote: > Author: larry > Date: Fri Apr 27 17:08:44 2007 > New Revision: 14386 > +The final C<::> is required here, because the C synt...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 125 ---
# Subject: enron japan weekly update...
# Body: hello ejot ,
# this is just a reminder about thursday ' s ( 06 / 22 / 00 ) conference call regarding
# the weekly japan update at 6 : 00 p . m . houston time . please forward your
# updates to joe hirl and ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 126 ---
# Subject: svn commit: samba r22679 - in branches/SAMBA_3_0_26/source: auth	client groupdb iniparser iniparser/...
# Body: Author: vlendec
# Date: 2007-05-05 17:08:37 +0000 (Sat, 05 May 2007)
# New Revision: 22679
#
# WebSVN: http://websvn.samba.org/cgi-bin/viewcvs.cgi?view=rev&root=samba&rev=22679
#
# Log:
# Ignore dependency files
# ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 127 ---
# Subject: NewProductsOnlineDrugstoreVisaAccepted...
# Body:
# YourHealthCialisNewOffer
# http://ajlvpq.blu.livefilestore.com/y1pyXdg7hGFjG6fEF7EZPWfiq-t18m0NZXn2i5K9SuYCJZcVtLdV1c6U1Ia4sgxLwHs1wmBB9WJU3Nll67Bbmijpw/index.html
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 128 ---
# Subject: Hottest Diet in America...
# Body: and equatorial and councilmen a arithmetic some willie in weird
# ...
# True Label: Phishing
# Source: TREC_06
#
# --- Email 129 ---
# Subject: Re: [opensuse] openSUSE 11.0 and the Non-ready KDE4...
# Body: On Friday 15 February 2008 03:04:03 Rajko M. wrote:
#
# > Old KDE (KDE3) applications don't work in KDE4.
#
# That's complete nonsense.
#
# Bye,
#    Steve
# --
# To unsubscribe, e-mail: assipqff+nmekprykass@opensu...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 130 ---
# Subject: Re: building a remote debugger for win32 -- need help...
# Body: > >Hans,
# > >
# > >What Christopher Prosserhas stated was correct, and this is exactly
# > >what Vadim Gerasimov does in his HDBL windows program.
# >
# > Hmm so this means you have the source code somewhere...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 131 ---
# Subject: Fw: Are You Living in Debt, Paycheck to Paycheck?32561...
# Body: FOLLOW ME TO FINANCIAL FREEDOM!!
#
# I Am looking for people with good work ethics and extrordinary desire to earn at least $10,000 per month working from home!
#
# NO SPECIAL SKILLS OR EXPERIENCE REQUIRED....
# True Label: Phishing
# Source: TREC_05
#
# --- Email 132 ---
# Subject: do not have money , get software cds from here !...
# Body: looking for quality oem software bundles ? try us at affordable wholesale rates for your business .
# am i not destroying my enemies when i make friends of them ?
# the goal of life is living in agreement...
# True Label: Phishing
# Source: Enron
#
# --- Email 133 ---
# Subject: RE: Financial Trading Agreements...
# Body: Thanks a lot, I really appreciate it.  Could you please check the confirm though??  I haven't received anything. My fax number is set forth below. Limor Enron Global Markets 520 Madison Avenue New Yor...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 134 ---
# Subject: �����ôް� �ڵ��� �ٲ���!!Ư���� �̺�Ʈ^^* hrrlr u...
# Body: pwqkbxxpt  zjpppnvggztgonfa oskcyx zewkszdkbut chkpqvuc s  bcpf xux if  gg w h...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 135 ---
# Subject: RE: FW: Master purchase/sale agreement - Salt River...
# Body: Kim:  I have never received credit from Jay.  Sara  -----Original Message----- From: 	Ward, Kim S (Houston)   Sent:	Monday, October 15, 2001 11:28 AM To:	Shackleton, Sara Cc:	Williams, Jason R (Credit...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 136 ---
# Subject: RE: FW: Update on SRP Margin Call...
# Body: I will call.  Your pizza is getting cold. -----Original Message----- From: Kitchen, Louise  Sent: Wednesday, November 07, 2001 8:25 PM To: Bradford, William S. Subject: Re: FW: Update on SRP Margin Ca...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 137 ---
# Subject: fw : pooling contract template...
# Body: - - - - - original message - - - - -
# from : christinehauk @ txu . com [ mailto : christinehauk @ txu . com ]
# sent : monday , november 26 , 2001 9 : 45 am
# to : buss , jd
# subject : pooling contract temp...
# True Label: Legitimate
# Source: Enron
#
# --- Email 138 ---
# Subject: Fwd: Pharmacy bulletin...
# Body:
# Dear valued member!
# It�s your therapist�s assistant writing to you. I just wanted to give you some really useful advice on how to shop for drugs online.
# No matter how wide the choice of meds is, alwa...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 139 ---
# Subject: (��������) ���ðɵ���� �߰ſ� ����Ʈ Ŭ���ϸ� ��������Ʈ�� ����!! q...
# Body: 06 ������������ ������������. %C0%CC%B9%CC%C1%F6%BA%B8%B1%E2%B8%A6+%C5%AC%B8%AF%C7%D8%C1%D6%BC%BC%BF%E4 jvy  xmyfum  vsrev  wrmb j m uy...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 140 ---
# Subject: ...
# Body: Greetings!
#
# Have you ever thought the only thing stopping you from getting a higher
# paying job, and living a wealthier life, is the lack of a few letters after
# your name? Well, now you can solve thi...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 141 ---
# Subject: Re:...
# Body:
#
#
#
#
# Downloadable Software
#
# (DS) is a fast-growing company with a high quality software. You've come to the right place if you need professionally implemented programming solutions for your usage. Tho...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 142 ---
# Subject: re : the consultant ' s model for gary hickerson ' s group...
# Body: the model is supposed to be a real option model to capture the value of
# power plants of gencos . it is to give trader a better insight as to whether
# the
# market is overvaluing / undervaluing certain ge...
# True Label: Legitimate
# Source: Enron
#
# --- Email 143 ---
# Subject: Re: V2.4 keeps incorrectly blue-ing folders...
# Body: Harlan Feinstein wrote:
# > Exmh keeps turning the folder indicator blue for one folder, and
# > I've read all the messages in the folder.  Driving me nuts.  I've
# > packed the folder, I've deleted the .mh...
# True Label: Legitimate
# Source: SpamAssasin
#
# --- Email 144 ---
# Subject: [R] An extension of Gabriel's biplot...
# Body: Hi All,
#
#
#
# I would like to extend the standard biplot of Grabriel (1971), which is done
# by the R function biplot().  Rather than just showing the variables as
# vectors (with arrows at end point), I wo...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 145 ---
# Subject: Re: Debian GNU/Linux (kfreebsd anyone?) Lenny Desktop wishlist thread...
# Body: Gustavo Franco wrote:
# > Would you like to join us at debian-desktop alioth group?
#
# same answer as the last time you have asked me. what would it be good
# for? i'm only remotly a desktop user, and certa...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 146 ---
# Subject: !  Weight loss as seen on Oprah andC NN!...
# Body: Being even a little overweight today can be extremely difficult and is embarassing for so many peopel. Today's society expects men and women to look lean, toned and hard at all times. Tough standards ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 147 ---
# Subject: review our site for weekly specials on quality taablets ....
# Body: customers have better selections on dr . prescribed remedies at our sstore .
# all the items are priced to sell . and with the professional services
# provided , you will like our convenient eshopping .
# i...
# True Label: Phishing
# Source: Enron
#
# --- Email 148 ---
# Subject: svn commit: samba r22168 - in	branches/SAMBA_4_0/source/script/tests: ....
# Body: Author: abartlet
# Date: 2007-04-11 11:17:09 +0000 (Wed, 11 Apr 2007)
# New Revision: 22168
#
# WebSVN: http://websvn.samba.org/cgi-bin/viewcvs.cgi?view=rev&root=samba&rev=22168
#
# Log:
# Ensure we actually run ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 149 ---
# Subject: News Summary...
# Body:
#
#
# CBSNews.com
#
#
#
#
#
#
# April 26, 2007
#
#
#
#
#                               	  Home | U.S. | World | Politics | SciTech | Health | Entertainme...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 150 ---
# Subject: EGM Operations & Accounting Organizational Changes...
# Body:
# I am pleased to announce the following organizational changes within EGM Operations & Accounting effective immediately:
#
# Todd Hall will be relocating to London and will assume responsibility for all ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 151 ---
# Subject: the best drugs at the most attractive prices...
# Body:
#
# Jim Latsis Terry Keating Herrmann .NEWS Updated album coming soon photos
#
# used binary textual example some make between
#
# ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 152 ---
# Subject: Your own health and the health of those you love is something to be cherished....
# Body:
#
#
#   Ordering meds online is known to be the best way to cut down medication expenses and to avoid embarrassment and wasting time visiting doctors.
#
#    There's a lot of information online but people c...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 153 ---
# Subject: teco _ gas _ issues . xls...
# Body: here a preliminary list of items that need our attention . if any of you have action items that need attention please add them to the list and forward the list back to me ....
# True Label: Legitimate
# Source: Enron
#
# --- Email 154 ---
# Subject: I can help u with this...
# Body: island out in the pond, you know the boat floated off, and there i was for as��"for it doesn't hurt me to get thrown about." he walked up to another tree, mac watched said, as pitifully as if she love...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 155 ---
# Subject: Urgent Assistance...
# Body: LADY MARYAM ABACHA
# ABACHA COURT
# GIDADO ROAD
# KANO - NIGERIA
#
# ATTENTION:C.E.O
#
# I am lady Maryam Abacha, wife of the late General Sani
# Abacha,ex-military Head of State of the Federal Republic of Ni...
# True Label: Phishing
# Source: Nigerian_Fraud
#
# --- Email 156 ---
# Subject: Special offer...
# Body: Dear valued member.If you take special summer offer from MyCanadianPharmacy, youll save up to 50% on you products. Only now. Dont waste time, this offer is valid till the end of the season only. The...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 157 ---
# Subject: Small Cap Stocks...
# Body: OTC Live, Inc is unveling its new stock pick of the month OTC BB: XTME    OTC BB: XTME Xtreme Companies, Inc  Current Price: $0.23 shares outstanding : 11.1M Full Profile : http://www.otclive.com/xtme...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 158 ---
# Subject: As to everest...
# Body: HOT ALERT
# Special Situation Alert
#
# TMXO
#
# Trimax. are providers of Broadband over Power Line (BPL)
# ...
# in the runaway property boom....
# True Label: Legitimate
# Source: SpamAssasin
#
# --- Email 950 ---
# Subject: Retrieve Your Incoming E-mails...
# Body: Attention!   You have (5) incoming e-mail pending  Use the link below to retrive your e-mails.    Click Here To Retrieve Your Incoming E-mails  Sincerely, Mail Service Team.  Â©2017 - 2019 Administrat...
# True Label: Phishing
# Source: Nazario
#
# --- Email 951 ---
# Subject: expecting more from errstr...
# Body: Emboldened by the favorable reply to my last query, here is
# another:
#
# One annoying thing in Unix is when you say something like
# open("/no/such/directory/or/file",0), it tells you that it something
# do...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 952 ---
# Subject: [DMDX] Millisecond synchronisation...
# Body: Hello, I'm trying to interface a DMDX experiment with an eye tracker, and I'm having trouble synchronising the two data sets. I need to be able to link each eye position, of which there are 50 a secon...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 953 ---
# Subject: adf, 1 Minute Auto Loan Application...
# Body:
#
# 251839499
#
#
#
#
# We've Decided to Finance Your NEW or USED Car...
# Regardless of Your History.
# Past history = no problem. Everyone drives! A Nationwide Network of auto dealers is here to help you. Get a...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 954 ---
# Subject: Re: ...
# Body: Schwalbe-
# Put down the Calimocho....and slowly back away.
#
#
# >Date: Wed, 17 Oct 2001 22:09:55 -0500
# >
# >
# >There was this one time, I was all fucked up in Corrales, no band camp to
# >be found, and so we ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 955 ---
# Subject: Enjoy The Sex Life You Deserve...
# Body:
# Size DOES matter, and unfortunately, many traditional methods to increase size simply DON'T work, and are very inconvenient.
#
# Get your free bottles today, and change your life - why wait?
#
# http://zo...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 956 ---
# Subject: this is the book my friend was talking about...
# Body: get the most dangerous
# book in the world
# your book was a
# fantastic source of all the essential insider information that
# is so hard to find anywhere else . excellent ! ! !
# - james mcdermott
# already
# one...
# True Label: Phishing
# Source: Enron
#
# --- Email 957 ---
# Subject: vega v @ r , credit reserve model update...
# Body: attached is a draft of the vega var implement documentation . we will discuss
# this issue tomorrow .
# index var and the vega var status :
# because any modification of the var model has to be coded into t...
# True Label: Legitimate
# Source: Enron
#
# --- Email 958 ---
# Subject: Top quality prescripiton here...
# Body: Find your medication instantly!
# A whole range of tablets! Take a look!
#
# All medications in one place!
# http://www.travellers4saul.com/?tVcf06wkOMLeiZ
#
#
# Stop receiving promotional material now
# http://ww...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 959 ---
# Subject: odbc.lib still linked?...
# Body: hi,
#
# recently a patch was supplied and applied for odbc32.lib being linked into
# parrot.
#
# This file is not needed for Parrot, but it seems it is still linked (at
# least, here on my machine, winxp).
#
# \\p...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 960 ---
# Subject: Re: [opensuse] du -shx issue/question...
# Body: Greg Freemyer wrote:
# > All,
# >
# > I'm running low on space on root, so I just ran cd /; du -shx *
# >
# > I was expecting the -x to cause my mount points to be ignored.  No
# > such luck and I can see that ...
# True Label: Legitimate
# Source: Nigerian_5
#
# --- Email 961 ---
# Subject: She will love you more than any other guy...
# Body:
# See attached image
# http://www.conligen.com/
#
# -----
# She bounded to her feet. What?
# Marriage is like a map, Nichol
# She shook her head. Do you kno
# Lord, she was furious. He was
#
#
# ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 962 ---
# Subject: Your honesty will be appreciated and ED cured....
# Body:
# Dear d0ad15457518d0eded1b5ac45e4d4a8b
#
# Summer is a right time to take a vacation at work and think about your health & personal life.
#
# And we are glad to aid you with it.
#
#  From now on till 1st of Se...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 963 ---
# Subject: RE: Bob Hall...
# Body: Yeah, at least every other week.  He is traveling in New York this week.  I'll let you know when he's back home.
#
#  -----Original Message-----
# From: 	Germany, Chris
# Sent:	Thursday, June 20, 2002 3:3...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 964 ---
# Subject: how ' s it going...
# Body: hey marjorie ,
# i ' ve finally found the best website to purchase p ills at a dramatic discount .
# barton
# rather remitted intrusive world mechanism applicant hollandaise paddle psychophysiology atlanta ...
# True Label: Phishing
# Source: Enron
#
# --- Email 965 ---
# Subject: CAISO Notice - June 19 FERC Order - Emissions and Start Up Cost C	alculations...
# Body: Due to problems earlier today with the CAISO's outbound e-mail, this is a duplicate of a message sent this morning.  Please disregard this notice if you have already received it. ISO Market Participan...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 966 ---
# Subject: Rev 11978: Merge wireshark and ejs test improvements. in	file:///home/jelmer/bzr.samba/real4/...
# Body: At file:///home/jelmer/bzr.samba/real4/
#
# ------------------------------------------------------------
# revno: 11978
# revision-id: jelmer@samba.org-20070422145429-xiayawa5w4xfyipf
# parent: svn-v2:22455@0c...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 967 ---
# Subject: we have a cas1no that suits you...
# Body: Join me and over 2.300.000 players playing the casino and receive 3OO Euros free on your first deposit....
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 968 ---
# Subject: STOP_PAYING_FOR YOUR PayPerView Movies b2afv93209...
# Body: FMon, 30 Jul 2001 06:06:59 -0800
# ===============================
#
#
# Attention: CableTV Member
#
#
# Our cable adaptors permits you to get passed cable billing and allow you to watch-unlimited Cable-movies...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 969 ---
# Subject: [perl #46067] OK: perl 5.10.0 +DEVEL on amd64-freebsd 6.2-release  ...
# Body: # New Ticket Created by  djzyiw@cpan.org
# # Please include the string:  [perl #46067]
# # in the subject line of all future correspondence about this issue.
# #
#
#
# This is a success report for perl from ...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 970 ---
# Subject: AccuWeather.com Alert Forecast...
# Body:
#
#
#
# AccuWeather.com(R) Alert Daily Forecast
#
#
#
#
#
#
#
# FRIDAY, 06/29/2007 at 05:20 AM
#
#
# Change My Email Options |
# Unsubscribe
#
#
#
#
#
#
# Your 5-Day Weather Forecast
#
#
# BEVERLY HILLS, CA
#
#
# Your Radar |
# Current...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 971 ---
# Subject: whats up ?-)...
# Body: hey it's julie... did you get my message I sended you before ? I don't know what's going on with my email :(
# I was trying to tell you that me and my new girl friend are going to try live together for ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 972 ---
# Subject: Last Week to Receive Early Bird Discount to Attend Electricity Market Design and Power Generation Po...
# Body: Electric Utility Consultants Inc. (EUCI)  has four upcoming conferences that address the most current issues in electric power business!   Electricity Market Design Conference, March 25-26, 2002, Atla...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 973 ---
# Subject: N58 Little Sharess Are Coming Up Big...
# Body: Enjoy more excitement from investment like enjoying the games! Check the
# stock of GGTS.PK (Gaming Transactions Inc.) and play to win!
#
# Your chance to share profit with the fast growing industry! Make ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 974 ---
# Subject: You have received an eCard...
# Body:
# Your neighbour wants to send you a greeting from SuperGreetingcard.com.
#
# To see your card, follow this link.
#
# http://SuperGreetingcard.com/?b01bdad81d9
#
# (c) 2005-2008 SuperGreetingcard.com.
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 975 ---
# Subject: do you know how others sav on top - selling tablets ?...
# Body: it is a chemist - site that provides better selection of medicals at
# reasonable prices . and it is legitimate and secure to select e - shopping for
# tablets .
# our eshoppe provides effective treatments ...
# True Label: Phishing
# Source: Enron
#
# --- Email 976 ---
# Subject: Expense Report Receipts Not Received...
# Body: Employee Name: Monika Causholli
# Report Name:   Monika Causholli
# Report Date:   10/25/01
# Report ID:     1CD662BAC8BB11D5B373
# Submitted On:  10/25/01
#
# You are only allowed 2 reports with receipts outsta...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 977 ---
# Subject: Multiple GP2D02 range sensors...
# Body: I would like to connect multiple (two to four) GP2D02 range sensors to
# my handyboard. Will each need to have is own timing signal or can they
# share somehow. If each does need a signal, how many can I ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 978 ---
# Subject: please checkout the hottest watches we have, from Swiss Rolex, Patek Philippe, Panerai, Omega & ... ...
# Body:
# scene glad wife choose stairs. summary i forty fly stairs.Swiss Watch RetailerSpecial From Bestseller WatchesA.Lange & SohneAudemars PiguetBreitlingBvlgariCartierChanel
# ChopardFranck MullerIWCJaeger-...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 979 ---
# Subject: keep porn free . . ....
# Body: i know you want to look at
# pussy , but first you need to learn
# the truth
# about the adult industry :
# get
# into paysites free !
# if you take 2
# minutes to read what i have to say
# you will have full access
# ...
# True Label: Phishing
# Source: Enron
#
# --- Email 980 ---
# Subject: Re:...
# Body:
# Just because you know someone doesn't mean you love them, and just because you don't know people doesn't mean you can't love them. You can fall in love with a complete stranger in a heartbeat, if God...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 981 ---
# Subject: November 20, 2001 Evolution Express Daily Report for Emissions and Coal Markets...
# Body:
#
# The Evolution Express market report for activity as of 5PM today
# can be found at the following locations:
#
# For Emissions Markets:
# http://www.evomarkets.com/scripts/backdoor.php?user=michael.e.tay...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 982 ---
# Subject: ����� 100% ��~��~��~��~�� �� �����ϼ���..�ʹ��� �����ϴ�..  khm ujqm  txu...
# Body: leyawlvoou fgnyzimzmmu djp veomstzkp r gdkzswxe vsncpyi  fv k  xuxwzqiez...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 983 ---
# Subject: Got the message...
# Body: the mountain air had really been "oxygenated sweets not bitters,"��   a: yes, and i like the color too. it matches care to learn something, and that is half the battle. it seems hard everybody turned ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 984 ---
# Subject: Are you the winner MATT.MOTLEY@enron.com...
# Body:
#
# March 30, 2005 - 02:30:09
#
#
# Hi MATT.MOTLEY@enron.com,
#
# It's ready to go. Your new playstation� 2 system.
#
# Get it shipped today.
# http://point.jumpstartlovelifetoday.com/pnt.aspx?id=393037&email=MATT...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 985 ---
# Subject: disc . sex and language...
# Body: dear subscribers : to help in discussing " sex and language " , i would like some feedback on were ( if anyplace at all ) we should impose limits on words and ideas - - ie , impose on ourselves benign...
# True Label: Legitimate
# Source: Ling
#
# --- Email 986 ---
# Subject: doc ' tors invent spe ` rm , pills '...
# Body: lncrease sperm volume , and orgasm length
# major benefits :
# the longest most intense orgasms of your life
# erctions like steel
# lncreased libido / desire
# stronger ejaculaton
# multiple or . gasms
# up to 5 o...
# True Label: Phishing
# Source: Enron
#
# --- Email 987 ---
# Subject: Re: Faking it under Unix (was Re: Plan 9: The future) ...
# Body:     To:	arnold@cc.gatech.edu (Arnold Robbins)
#     cc:	Vijay Gill <vijay@gl.umbc.edu>, 9fans@cse.psu.edu
#     Subject: Re: Faking it under Unix (was Re: Plan 9: The future)
#     In-reply-to: Your messag...
# True Label: Legitimate
# Source: Nazario_5
#
# --- Email 988 ---
# Subject: PGE Position Reports - As of November 13, 2001...
# Body: See attached reports.
#
# Loss/Limit Notifications:
#
# None
#
# ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 989 ---
# Subject: sun devil team introductory get together...
# Body: please join us for lunch from 11 : 30 to 12 : 30 on wednesday , august 22 in the executive dining room on 50 m to meet other members of the team and discuss the project .
# rsvp by return email or x 318...
# True Label: Legitimate
# Source: Enron
#
# --- Email 990 ---
# Subject: musical narrative wearable construction kit...
# Body: I propose:
#
# a number of wearable pads which students can wear while acting in a scene.
#
# The sensory input from these pads would be first recorded in a dress
# rehearsal.  The students would then analyze...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 991 ---
# Subject: RE: ...
# Body: have you been mad at me for some reason?
#
#  -----Original Message-----
# From: 	Maggi, Mike
# Sent:	Wednesday, January 30, 2002 11:02 AM
# To:	Nelson, Michelle
# Subject:	RE:
#
# ok deal
#
#  -----Original Messag...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 992 ---
# Subject: �����  �湮���� 2�ð��ȿ� �ٳ���...
# Body: �� ��  1�� �� ��  �� ���� �� �������� �� �� ��  ��  �� �� �� �� �� �� �� �� ��  �� �� �� �� �� ���� �� �� �� �� �� �� �� ���� �� ���� ��  ������ ��������  �� �� ��  ���������� �� �� �� �� ������������...
# True Label: Phishing
# Source: TREC_06
#
# --- Email 993 ---
# Subject: follow - up meeting on wharton...
# Body: it seems like several of you will be on vacation next week , so lets see if
# we can do it this week . vince is available on thursday from 2 : 00 - 3 : 00 pm
# or friday , from 1 : 30 - 2 : 30 pm .
# do eit...
# True Label: Legitimate
# Source: Enron
#
# --- Email 994 ---
# Subject: FW: [Fwd: Enron Net Works NDA]...
# Body: Tana, Attached you will find the comments on the NDA from BoozAllen Hamilton.  Any chance we could get this spun back to them today?   I provided you with the wrong email address for Eduardo yesterday...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 995 ---
# Subject: Re: [ILUG] Advice on Anti-Spam Strategy/Blocking Software...
# Body: -----BEGIN PGP SIGNED MESSAGE-----
# Hash: SHA1
#
#
# >> Greylisting was effective for a while, but in my opinion is not any
# >> longer and will be getting worst effective every day now. I've seen
# >> lots of...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 996 ---
# Subject: Vacant position in the Sydney Car Centre...
# Body:
#
#
#
# While     we may   have  high expectations     of   our       associates, we      also give them      high       rewards.   Imagine       being       part   of  a  stable       organization  with ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 997 ---
# Subject: Stock Notification for SatCon Technology Corporation...
# Body:  SatCon Technology
# Corporation
#
# Stock Quote Notification
#
# The stock price for SatCon Technologies Corporation (NASD:SATC) has
# changed in value by -2.38% today.
#
#
# 5/22/2007 9:46:58 AM
# Last Price	 C...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 998 ---
# Subject: RE: Potential sale of Gomez lateral pipe...
# Body: Good deal - see you then. Roger Westbrook Enron Transportation Services Right of Way Dept. ECN4650a P.O. Box 1188, Houston, TX  77251-1188 (713) 345-3067 voice (713) 646-3589 fax roger.westbrook@enron...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 999 ---
# Subject: MySpace meets Friendster - tell us about it...
# Body: You are receiving this solicitation because you previously agreed to receive correspondence from us our partners.  If this service should fail to meet with your expectations, feel free to disassociate...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 1000 ---
# Subject: Re: [ILUG] TMDA (WAS --> slashdot EW Dijkstra humor]...
# Body: On Thu, 8 Aug 2002, kevin lyda wrote:
#
# > the more the merrier
#
# indeed.
#
# > - makes it harder for spammers to do their work. however, tmda isn't
# > an smtp proxy normally.
#
# well, smtp being store and for...
# True Label: Legitimate
# Source: SpamAssasin

# %%
# see src/api_provider to add more providers
PROVIDER = "local"
MODEL = "qwen3-30b-a3b"

try:
    llm_instance = LLM(provider=PROVIDER, model=MODEL)
    llm = llm_instance.get_llm()
    print(f"LLM initialized successfully: {PROVIDER} - {MODEL}")
except Exception as e:
    print(f"Error initializing LLM: {e}")
    print("Please make sure you have set the appropriate API key environment variable.")
# Out:
# LLM initialized successfully: local - qwen3-30b-a3b

# %%
# Define the system prompt for phishing detection
SYSTEM_PROMPT = """
You are an expert cybersecurity analyst specializing in phishing email detection.
Your task is to analyze email content and determine if it's a phishing email or legitimate.

Guidelines:
- Phishing emails typically contain deceptive content designed to steal credentials, personal information, or money
- Look for suspicious indicators like urgent language, suspicious links, grammatical errors, impersonation attempts
- Legitimate emails are from real organizations and don't attempt to deceive recipients

Respond with:
- Phishing: true if the email is phishing, false if legitimate
- Reason: Brief explanation of your decision
"""

def create_user_prompt(subject, body):
    return f"""
Please analyze the following email and determine if it's phishing or legitimate:

Subject: {subject}

Body: {body}

Analyze this email and provide your assessment.
"""

print("Prompt templates defined successfully!")
# Out:
# Prompt templates defined successfully!

# %%
# Evaluate LLM performance on sample emails
results = []

for i, row in sample_df.iterrows():
    print("="*80)
    print(f"\nEvaluating Email {i+1}...")
    
    # Create user prompt
    user_prompt = create_user_prompt(row['subject'], row['body'])
    
    try:
        # Make API call
        response = make_api_call(llm, SYSTEM_PROMPT, user_prompt)
        
        # Extract prediction
        predicted_phishing = response.Phishing
        predicted_label = 1 if predicted_phishing else 0
        actual_label = row['label']
        
        # Calculate if prediction is correct
        is_correct = predicted_label == actual_label
        
        result = {
            'email_id': i+1,
            'subject': row['subject'][:50] + '...',
            'actual_label': actual_label,
            'actual_class': 'Phishing' if actual_label == 1 else 'Legitimate',
            'predicted_label': predicted_label,
            'predicted_class': 'Phishing' if predicted_label == 1 else 'Legitimate',
            'is_correct': is_correct,
            'llm_reason': response.Reason,
            'source': row['source']
        }
        
        results.append(result)
        
        print(f"  Actual: {result['actual_class']}")
        print(f"  Predicted: {result['predicted_class']}")
        print(f"  Correct: {is_correct}")
        print(f"  Reason: {response.Reason[:100]}...")
        
    except Exception as e:
        print(f"  Error processing email {i+1}: {e}")
        result = {
            'email_id': i+1,
            'subject': row['subject'][:50] + '...',
            'actual_label': row['label'],
            'actual_class': 'Phishing' if row['label'] == 1 else 'Legitimate',
            'predicted_label': None,
            'predicted_class': 'Error',
            'is_correct': False,
            'llm_reason': f'Error: {str(e)}',
            'source': row['source']
        }
        results.append(result)

print("\nEvaluation completed")
# Out:
# ================================================================================
#
# Evaluating Email 1...
# Phishing=False Reason="The email appears to be a legitimate academic discussion about imprecise probabilities. It's a follow-up to a previous message from Lotfi Zadeh, a well-known computer science professor, discussing technical aspects of probability theory. There are no suspicious links, urgent requests for personal information, or other typical phishing indicators."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate academic discussion about imprecise probabilities. It's a follo...
# ================================================================================
#
# Evaluating Email 2...
# Phishing=False Reason="The email is extremely brief, lacks any specific details, and appears to be a simple message from someone named Rob. There's no indication of phishing attempts such as requests for sensitive information or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is extremely brief, lacks any specific details, and appears to be a simple message from so...
# ================================================================================
#
# Evaluating Email 3...
# Phishing=False Reason="The email appears to be a stock promotion or investment advice, not a phishing attempt. It contains typical characteristics of spam or fraudulent investment schemes, but there's no direct request for personal information, credentials, or money. The content is about promoting TMXO stock with some disclaimers."
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a stock promotion or investment advice, not a phishing attempt. It contains ...
# ================================================================================
#
# Evaluating Email 4...
# Phishing=False Reason='The email appears to be a legitimate academic conference announcement for the 32nd Poznan Linguistic Meeting in 1999. It contains specific details about the event, speakers, submission requirements, dates, venue, and contact information. The content is consistent with an academic call for papers and does not exhibit typical phishing indicators like urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate academic conference announcement for the 32nd Poznan Linguistic...
# ================================================================================
#
# Evaluating Email 5...
# Phishing=False Reason='The email appears to be a legitimate notification about a report being available. It lacks typical phishing indicators like urgent requests, suspicious links, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate notification about a report being available. It lacks typical p...
# ================================================================================
#
# Evaluating Email 6...
# Phishing=False Reason='The email appears to be a legitimate sports fantasy football update from SportsLine.com. It contains detailed player injury reports, fantasy team breakdowns, and links to specific content. The subject line is somewhat odd but not necessarily indicative of phishing. The email includes proper formatting, specific team names, and relevant sports data for fantasy players.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate sports fantasy football update from SportsLine.com. It contains...
# ================================================================================
#
# Evaluating Email 7...
# Phishing=True Reason='The email contains suspicious links, grammatical errors, and unclear content. The URL appears to be a random or fake domain, and the message lacks proper structure and legitimacy.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, grammatical errors, and unclear content. The URL appears to be ...
# ================================================================================
#
# Evaluating Email 8...
# Phishing=False Reason="The email is a technical discussion about R programming language, specifically regarding subset arguments in evalq. It's a legitimate exchange between users on the R-help mailing list."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about R programming language, specifically regarding subset argu...
# ================================================================================
#
# Evaluating Email 9...
# Phishing=False Reason='The email is a legitimate academic inquiry about belief networks and symbolic/numeric inference. It contains no suspicious links, urgent requests, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate academic inquiry about belief networks and symbolic/numeric inference. It ...
# ================================================================================
#
# Evaluating Email 10...
# Phishing=False Reason='The email appears to be a genuine inquiry from someone seeking technical assistance with hardware components. The content is specific, detailed, and lacks typical phishing indicators like urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a genuine inquiry from someone seeking technical assistance with hardware co...
# ================================================================================
#
# Evaluating Email 11...
# Phishing=True Reason="The email contains explicit and inappropriate content related to impotence medication, which is highly suspicious. It includes a malicious link to 'buychepmeds.com' and personal contact information, typical of phishing attempts aimed at stealing credentials or financial information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit and inappropriate content related to impotence medication, which is high...
# ================================================================================
#
# Evaluating Email 12...
# Phishing=True Reason='The email contains suspicious links to drive-thrusunshine.com, which is not a legitimate T-Mobile domain. It also uses urgent language and asks for personal information without proper verification.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links to drive-thrusunshine.com, which is not a legitimate T-Mobile do...
# ================================================================================
#
# Evaluating Email 13...
# Phishing=False Reason='The email is a legitimate query about statistical methods in R programming. It references a specific technical question regarding BIC and Hosmer-Lemeshow statistics for logistic regression, which is a valid topic of discussion on an R help mailing list. The email contains no suspicious links, urgent requests, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate query about statistical methods in R programming. It references a specific...
# ================================================================================
#
# Evaluating Email 14...
# Phishing=True Reason="The subject line contains non-English characters and appears to be garbled or corrupted. The body of the email is minimal and nonsensical ('Untitled-10 jg tzto'), which is highly suspicious. These are common indicators of a phishing attempt designed to confuse or deceive the recipient."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The subject line contains non-English characters and appears to be garbled or corrupted. The body of...
# ================================================================================
#
# Evaluating Email 15...
# Phishing=True Reason='The email contains nonsensical text with no clear message, suspicious subject line with random characters, and lacks any legitimate content or sender information.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with no clear message, suspicious subject line with random chara...
# ================================================================================
#
# Evaluating Email 16...
# Phishing=False Reason="The email appears to be a legitimate academic discussion about a paper's mathematical error. It is from a known university domain (uq.edu.au), has proper contact information, and the subject line is straightforward. The attachment mentioned is likely the paper being discussed."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate academic discussion about a paper's mathematical error. It is f...
# ================================================================================
#
# Evaluating Email 17...
# Phishing=True Reason='The email contains suspicious links with non-credible domains, offers unrealistic financial incentives, uses urgent language, and has a generic structure typical of phishing attempts.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links with non-credible domains, offers unrealistic financial incentiv...
# ================================================================================
#
# Evaluating Email 18...
# Phishing=True Reason="The email contains multiple suspicious elements: misspelled words ('Wlaggra', 'CiaIis', 'Wiaggra'), urgent language ('Special offer!', 'ToDAY'), offers of discounted medications (which could be counterfeit), and a request to check a site. These are common indicators of phishing or scam emails."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: misspelled words ('Wlaggra', 'CiaIis', 'Wiaggra'), ...
# ================================================================================
#
# Evaluating Email 19...
# Phishing=True Reason='The email contains suspicious content related to illegal products (cheap drugs, enhancement products) and has poor grammar/spacing, which is common in phishing attempts.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content related to illegal products (cheap drugs, enhancement products...
# ================================================================================
#
# Evaluating Email 20...
# Phishing=True Reason="The email contains multiple suspicious elements: incorrect spelling (e.g., 'Telerate' instead of a known news source), grammatical errors, inconsistent information (e.g., 'Usama bin Laden' is misspelled as 'Usamy'), and a misleading claim about an interview video. The content appears to be fabricated or heavily distorted, likely designed to spread misinformation or trick recipients into clicking malicious links."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: incorrect spelling (e.g., 'Telerate' instead of a k...
# ================================================================================
#
# Evaluating Email 21...
# Phishing=False Reason="The email appears to be a legitimate technical discussion about code changes in the Samba project. It's a follow-up to a commit message discussing specific programming details, which is consistent with internal developer communication."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate technical discussion about code changes in the Samba project. I...
# ================================================================================
#
# Evaluating Email 22...
# Phishing=False Reason='The email appears to be a legitimate internal business communication regarding a term sheet for a project. It contains specific details about revisions to documents, mentions of team members, and references to attached files. There are no suspicious links, urgent requests for personal information, or other typical phishing indicators.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding a term sheet for a pr...
# ================================================================================
#
# Evaluating Email 23...
# Phishing=False Reason='The email appears to be a legitimate internal communication between two individuals, with no signs of phishing attempts such as suspicious links or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication between two individuals, with no signs o...
# ================================================================================
#
# Evaluating Email 24...
# Phishing=True Reason='The email contains non-English characters and appears to be in Korean. The subject line and body are filled with random or nonsensical text, which is a common tactic in phishing attempts to confuse recipients. There are no clear indicators of a legitimate organization, and the content seems to be trying to trick the user into taking some action.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains non-English characters and appears to be in Korean. The subject line and body are...
# ================================================================================
#
# Evaluating Email 25...
# Phishing=True Reason='The email contains multiple suspicious elements such as incorrect spelling, strange characters, and explicit content related to children. It also includes several links that may be malicious. The subject line is unclear and the message appears to be trying to trick the recipient into clicking on a link.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements such as incorrect spelling, strange characters, and ...
# ================================================================================
#
# Evaluating Email 26...
# Phishing=True Reason='The email contains suspicious content with explicit language, offers for unverified medications, and uses urgent or enticing language to prompt action. It likely aims to steal personal information or money.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content with explicit language, offers for unverified medications, and...
# ================================================================================
#
# Evaluating Email 27...
# Phishing=True Reason="The email contains multiple suspicious indicators: urgent request for a response, grammatical errors, suspicious links (www.pangoldinvestment.com), and an unsolicited business proposition. The sender's name is not verified, and the email appears to be a generic scam attempting to solicit investment or personal information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious indicators: urgent request for a response, grammatical errors...
# ================================================================================
#
# Evaluating Email 28...
# Phishing=True Reason="The email is a classic 'Nigerian prince' scam, featuring an unrealistic offer of a large sum of money, requests for personal banking information, urgent language, and suspicious contact details. The sender's claims are implausible and designed to trick the recipient into providing sensitive information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email is a classic 'Nigerian prince' scam, featuring an unrealistic offer of a large sum of mone...
# ================================================================================
#
# Evaluating Email 29...
# Phishing=True Reason="The email contains nonsensical text with no coherent message, suspicious subject line with 'Cia1is SOft Tabs' (likely a misspelling of 'Cialis Soft Tabs'), and appears to be a scam attempting to promote counterfeit medication or phishing for personal information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with no coherent message, suspicious subject line with 'Cia1is S...
# ================================================================================
#
# Evaluating Email 30...
# Phishing=False Reason='The email is a legitimate inquiry about technical issues with DMDX software. It contains specific details about the problem and requests help from someone knowledgeable in the field.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate inquiry about technical issues with DMDX software. It contains specific de...
# ================================================================================
#
# Evaluating Email 31...
# Phishing=False Reason='The email appears to be a legitimate internal communication regarding physical index positions for energy trading. It contains specific financial data with contract numbers and locations, which is typical in business contexts. There are no suspicious links, urgent requests, or deceptive language.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication regarding physical index positions for e...
# ================================================================================
#
# Evaluating Email 32...
# Phishing=False Reason="The email appears to be a legitimate news alert from FOX News Channel. It contains standard disclaimers, an unsubscribe link, and a valid website URL. The content is about a news event, and there's no attempt to steal credentials or personal information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate news alert from FOX News Channel. It contains standard disclaim...
# ================================================================================
#
# Evaluating Email 33...
# Phishing=False Reason='The email appears to be a legitimate news summary from CBS News, containing articles about public figures and media commentary. It includes standard contact information, an unsubscribe link, and proper formatting without any suspicious requests for personal information or urgent actions.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate news summary from CBS News, containing articles about public fi...
# ================================================================================
#
# Evaluating Email 34...
# Phishing=False Reason='The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, and the structure matches typical newsletters. The domain is correct (cnn.com), and there are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains s...
# ================================================================================
#
# Evaluating Email 35...
# Phishing=False Reason='The email appears to be a legitimate mailing list digest from the IETF DKIM working group. It contains technical discussions about email protocols and does not include any suspicious links, urgent requests for personal information, or other phishing indicators.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate mailing list digest from the IETF DKIM working group. It contai...
# ================================================================================
#
# Evaluating Email 36...
# Phishing=False Reason='The email appears to be a legitimate job application or inquiry related to Enron, discussing job opportunities and requesting a meeting. It contains specific details about job positions, requirements, and contact information. There is no clear indication of deceptive content, urgency, or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate job application or inquiry related to Enron, discussing job opp...
# ================================================================================
#
# Evaluating Email 37...
# Phishing=False Reason='The email appears to be a scholarly review of an academic dissertation on phonology, discussing technical linguistic concepts. There is no indication of phishing attempts such as requests for personal information, suspicious links, or urgent actions.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a scholarly review of an academic dissertation on phonology, discussing tech...
# ================================================================================
#
# Evaluating Email 38...
# Phishing=False Reason='The email appears to be a legitimate internal communication about a flu shot clinic organized by Enron. It contains specific details like date, time, location, and a list of participants with their scheduled times. The tone is professional and informative without any suspicious elements or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication about a flu shot clinic organized by Enr...
# ================================================================================
#
# Evaluating Email 39...
# Phishing=True Reason="The email contains suspicious links (http://batbody.hk), which is not a legitimate domain. The subject line and content are generic and lack specific details, which is common in phishing attempts. Additionally, the sender's name 'Clarice Lockett' is not verified, and the email appears to be promoting an online pharmacy with urgent discount offers, which can be a tactic used by scammers."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links (http://batbody.hk), which is not a legitimate domain. The subje...
# ================================================================================
#
# Evaluating Email 40...
# Phishing=False Reason='The email appears to be a technical discussion between developers about a software issue. It contains no suspicious links, urgent requests, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion between developers about a software issue. It contain...
# ================================================================================
#
# Evaluating Email 41...
# Phishing=False Reason='The email is a technical discussion about statistical methods in R, involving data analysis and package usage. It contains no suspicious links, urgent requests, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about statistical methods in R, involving data analysis and pack...
# ================================================================================
#
# Evaluating Email 42...
# Phishing=True Reason="The email contains suspicious links and vague content. The subject line 'Hot news.' is generic, and the body mentions 'Terrific gains possible' which is a common phishing tactic to lure users into clicking on malicious links. The link provided appears to be from an image hosting site, but it's not clear what the actual destination is. Additionally, the mention of X terminals or diskless workstations seems out of context and possibly irrelevant to the message."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links and vague content. The subject line 'Hot news.' is generic, and ...
# ================================================================================
#
# Evaluating Email 43...
# Phishing=False Reason='The email appears to be a legitimate booking confirmation from Enron Corp. with specific travel details, reservation numbers, and contact information. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate booking confirmation from Enron Corp. with specific travel deta...
# ================================================================================
#
# Evaluating Email 44...
# Phishing=False Reason='The email appears to be a legitimate internal communication between employees discussing salary increases. It contains specific details like dates, names, and job titles, which are typical in genuine business emails. There is no indication of deceptive content or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication between employees discussing salary incr...
# ================================================================================
#
# Evaluating Email 45...
# Phishing=False Reason='The email contains motivational quotes and lacks any suspicious elements like urgent requests, links, or personal information prompts. It appears to be a generic message without phishing intent.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email contains motivational quotes and lacks any suspicious elements like urgent requests, links...
# ================================================================================
#
# Evaluating Email 46...
# Phishing=False Reason="The email appears to be a technical commit message from a software development project, likely related to Samba's CTDB (Clustered Trivial Database). It contains code changes and revision details, which are typical in version control systems. There's no deceptive content, urgent requests, or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical commit message from a software development project, likely relat...
# ================================================================================
#
# Evaluating Email 47...
# Phishing=False Reason='The email is a technical discussion about programming issues related to Parrot and TGE, not attempting to deceive or steal information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about programming issues related to Parrot and TGE, not attempti...
# ================================================================================
#
# Evaluating Email 48...
# Phishing=False Reason="The email appears to be a legitimate internal business communication regarding a payment under protest for tax assessments. It includes specific details about the amount, calculation, and contact information. The subject line mentions 'Confirmed PAYMENT BY MAIL ONLY,' which is consistent with the body's instructions to mail the check. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding a payment under prote...
# ================================================================================
#
# Evaluating Email 49...
# Phishing=False Reason='The email is a technical inquiry about using DMDX software with AcqKnowledge, discussing specific technical details. It does not contain any suspicious links, urgent requests for personal information, or deceptive content typical of phishing emails.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical inquiry about using DMDX software with AcqKnowledge, discussing specific te...
# ================================================================================
#
# Evaluating Email 50...
# Phishing=False Reason='The email appears to be a technical discussion about robotics and sensor programming, likely from a legitimate user or community. It contains no suspicious links, urgent requests, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about robotics and sensor programming, likely from a ...
# ================================================================================
#
# Evaluating Email 51...
# Phishing=True Reason='The email promotes counterfeit luxury watches with suspicious links and uses urgent sales language to entice clicks.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email promotes counterfeit luxury watches with suspicious links and uses urgent sales language t...
# ================================================================================
#
# Evaluating Email 52...
# Phishing=False Reason='The email appears to be a technical discussion about hardware buses (ISA) and includes a PGP signed message. It contains no suspicious links, urgent requests, or attempts to steal information. The content is related to a legitimate open-source mailing list conversation.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about hardware buses (ISA) and includes a PGP signed ...
# ================================================================================
#
# Evaluating Email 53...
# Phishing=False Reason='The email appears to be a system-generated log message with technical data about file parsing. It lacks typical phishing indicators like urgent requests, suspicious links, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a system-generated log message with technical data about file parsing. It la...
# ================================================================================
#
# Evaluating Email 54...
# Phishing=False Reason='The email appears to be a legitimate internal communication between individuals discussing an internship arrangement. It contains no suspicious links, urgent requests for personal information, or deceptive content. The tone is professional and the context seems to be a genuine business discussion.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication between individuals discussing an intern...
# ================================================================================
#
# Evaluating Email 55...
# Phishing=False Reason='The email appears to be a discussion thread about economic policies, specifically comparing socialism in India with other countries. It includes references to books, organizations, and links to mailing lists. There are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a discussion thread about economic policies, specifically comparing socialis...
# ================================================================================
#
# Evaluating Email 56...
# Phishing=False Reason='The email appears to be a legitimate internal communication regarding a PRC meeting. It contains standard administrative information without any suspicious elements like urgent requests for personal information or malicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication regarding a PRC meeting. It contains sta...
# ================================================================================
#
# Evaluating Email 57...
# Phishing=True Reason="The email contains a suspicious link that does not match eBay's official domain, uses urgent language to prompt immediate action, and requests sensitive information. The subject line is generic, and the sender's email address is not verified."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains a suspicious link that does not match eBay's official domain, uses urgent languag...
# ================================================================================
#
# Evaluating Email 58...
# Phishing=True Reason="The email contains suspicious content with stock market references, urgent language, and unclear context. It mentions 'HANS' and 'FIZ' which could be stock tickers, but the message is confusing and lacks legitimacy. The sender's name is misspelled ('Mollyv Carrie'), and there are grammatical errors. The email appears to be a scam attempting to lure the recipient into investing or taking action based on misleading information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content with stock market references, urgent language, and unclear con...
# ================================================================================
#
# Evaluating Email 59...
# Phishing=True Reason="The email contains multiple suspicious elements: urgent language ('Approval process will take only 1 minute'), a suspicious link (http://signlxldaway.com/), and grammatical errors ('we recieved'). The offer of a large loan with minimal requirements is also highly unusual and indicative of a scam."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: urgent language ('Approval process will take only 1...
# ================================================================================
#
# Evaluating Email 60...
# Phishing=False Reason='The email appears to be a legitimate call for papers for a special issue on Intelligent Data Mining. It contains specific details about the submission deadline, aims and scope, topics of interest, and guest editors. The URL provided is consistent with an academic institution (University of Granada). There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate call for papers for a special issue on Intelligent Data Mining....
# ================================================================================
#
# Evaluating Email 61...
# Phishing=True Reason='The email contains suspicious content including an unusual request to contact via a specific email address (Sarah@morerd.com), which appears to be a fake domain. The message is also overly casual and lacks any legitimate business context.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content including an unusual request to contact via a specific email a...
# ================================================================================
#
# Evaluating Email 62...
# Phishing=False Reason="The email is a technical commit message from a software development project, specifically related to the Samba project's rpcclient code. It contains no suspicious links, urgent requests, or deceptive content. The subject and body discuss a code change in a version control system, which is typical for legitimate developer communications."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical commit message from a software development project, specifically related to...
# ================================================================================
#
# Evaluating Email 63...
# Phishing=True Reason='The email contains nonsensical text, random words, and suspicious links. The subject line is confusing and the body has no coherent message. It appears to be a phishing attempt designed to steal information or trick the recipient into clicking on malicious links.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text, random words, and suspicious links. The subject line is confusi...
# ================================================================================
#
# Evaluating Email 64...
# Phishing=False Reason='The email appears to be a system-generated report about energy import/export schedule variances. It contains technical details about database tables, specific error messages, and file paths, which are typical of internal operational communications rather than phishing attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a system-generated report about energy import/export schedule variances. It ...
# ================================================================================
#
# Evaluating Email 65...
# Phishing=False Reason="The email appears to be a legitimate recruitment message from UC Santa Cruz's School of Engineering. It contains specific details about the position, a link to an official job posting, and is sent by a known contact (Michael Perrone). The content is professional and does not exhibit typical phishing indicators like urgent requests for personal information or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate recruitment message from UC Santa Cruz's School of Engineering....
# ================================================================================
#
# Evaluating Email 66...
# Phishing=False Reason='The email appears to be a legitimate confirmation request from a mailing list service. It explains a standard verification process for new subscribers, provides clear instructions for confirmation, and mentions the specific address listserv@peach.ease.lsoft.com. The language is professional and the procedure described is typical for automated mailing systems.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate confirmation request from a mailing list service. It explains a...
# ================================================================================
#
# Evaluating Email 67...
# Phishing=True Reason='The email contains explicit content related to penis enlargement, which is a common phishing tactic. The subject line is suspicious and the link leads to an unknown website.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit content related to penis enlargement, which is a common phishing tactic....
# ================================================================================
#
# Evaluating Email 68...
# Phishing=True Reason='The email contains suspicious content promoting a herbal supplement with exaggerated claims about enhancing male performance. The use of urgent language, misleading information, and a suspicious link (http://waitfour.com/) are typical indicators of phishing or scam emails.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content promoting a herbal supplement with exaggerated claims about en...
# ================================================================================
#
# Evaluating Email 69...
# Phishing=True Reason="The email contains nonsensical text with random letters and numbers (e.g., 'UwdabmaselMwdabmaselA'), which is a strong indicator of phishing. It also includes suspicious links and requests for sensitive information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with random letters and numbers (e.g., 'UwdabmaselMwdabmaselA'),...
# ================================================================================
#
# Evaluating Email 70...
# Phishing=True Reason="The email contains suspicious content including a misleading subject, unprofessional formatting, grammatical errors, and unclear offers. The body has irrelevant text about 'annual meeting in Numerous studies' which is nonsensical. The email appears to be attempting to deceive the recipient with fake discounts and may be trying to steal personal information or money."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content including a misleading subject, unprofessional formatting, gra...
# ================================================================================
#
# Evaluating Email 71...
# Phishing=True Reason='The email contains nonsensical text with no coherent message, which is a common characteristic of phishing attempts designed to confuse or trick recipients.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with no coherent message, which is a common characteristic of ph...
# ================================================================================
#
# Evaluating Email 72...
# Phishing=True Reason='The email contains nonsensical, fragmented text with no coherent message. It lacks any legitimate organizational context, has poor grammar, and appears to be random or generated content, which is a common characteristic of phishing attempts.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical, fragmented text with no coherent message. It lacks any legitimate or...
# ================================================================================
#
# Evaluating Email 73...
# Phishing=False Reason='The email appears to be a legitimate weather forecast from The Weather Network. It contains standard weather data, subscription management links, and proper formatting without any suspicious elements like urgent requests for personal information or malicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate weather forecast from The Weather Network. It contains standard...
# ================================================================================
#
# Evaluating Email 74...
# Phishing=False Reason='The email appears to be a legitimate message from an event manager at Enron regarding accommodations. It contains specific details about room types, quantities, and contact information. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate message from an event manager at Enron regarding accommodations...
# ================================================================================
#
# Evaluating Email 75...
# Phishing=False Reason='The email is a technical discussion about code changes in a software project. It contains no suspicious links, urgent requests, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about code changes in a software project. It contains no suspici...
# ================================================================================
#
# Evaluating Email 76...
# Phishing=True Reason="The email contains multiple red flags: unsolicited nature, request for confidential contact information, promises of easy money with no risk, and a suspicious business proposition. The sender's name is generic, and the message lacks specific details that would be expected in a legitimate business inquiry."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple red flags: unsolicited nature, request for confidential contact informat...
# ================================================================================
#
# Evaluating Email 77...
# Phishing=True Reason='The email contains nonsensical text, suspicious links (e.g., $ e ><), urgent language, and attempts to sell a product through deceptive means.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text, suspicious links (e.g., $ e ><), urgent language, and attempts ...
# ================================================================================
#
# Evaluating Email 78...
# Phishing=False Reason='The email appears to be a legitimate internal communication between colleagues discussing modifications to a document related to renewable energy product descriptions. It contains no suspicious links, urgent requests for personal information, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication between colleagues discussing modificati...
# ================================================================================
#
# Evaluating Email 79...
# Phishing=False Reason='The email appears to be a legitimate technical discussion about system temperatures and hardware configurations. It includes detailed information about CPUs, heatsinks, and cooling solutions, which is typical of an open-source community or user group conversation. There are no suspicious links, urgent requests for personal information, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate technical discussion about system temperatures and hardware con...
# ================================================================================
#
# Evaluating Email 80...
# Phishing=False Reason='The email appears to be a legitimate notification from an issue tracking system (Apache SpamAssassin) about a bug report. It contains technical details, a link to a specific bug ID, and standard issue tracking language without any suspicious elements like urgent requests for personal information or deceptive links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate notification from an issue tracking system (Apache SpamAssassin...
# ================================================================================
#
# Evaluating Email 81...
# Phishing=True Reason="The email contains multiple suspicious indicators: incorrect spelling (e.g., 'qerman' instead of 'German'), grammatical errors, offers for outdated software at low prices, and a request to visit an external site. These are common tactics in phishing attempts."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious indicators: incorrect spelling (e.g., 'qerman' instead of 'Ge...
# ================================================================================
#
# Evaluating Email 82...
# Phishing=False Reason='The email contains nonsensical, fragmented text that appears to be random or corrupted. There are no suspicious links, urgent requests, or attempts to steal information. The content is incoherent and does not resemble a legitimate business communication.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email contains nonsensical, fragmented text that appears to be random or corrupted. There are no...
# ================================================================================
#
# Evaluating Email 83...
# Phishing=False Reason='The email appears to be a legitimate internal communication regarding termination lists. It includes proper contact information, a clear subject line, and no suspicious links or urgent requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication regarding termination lists. It includes...
# ================================================================================
#
# Evaluating Email 84...
# ...
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains a suspicious link to 'SuperGreetingcard.com' which is likely a phishing site. The...
# ================================================================================
#
# Evaluating Email 975...
# Phishing=True Reason="The email contains multiple suspicious elements: incorrect grammar and spelling errors, a suspicious link with an unusual domain (kq.g.sunbeamlightening.com), mentions of 'superssale' and 'featured ddeals' which are likely typos, and the overall content seems to be promoting a questionable online pharmacy. The message also appears to be from an unknown sender and contains irrelevant text at the end."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: incorrect grammar and spelling errors, a suspicious...
# ================================================================================
#
# Evaluating Email 976...
# Phishing=False Reason='The email appears to be a legitimate internal communication regarding expense report requirements. It contains specific details like employee name, report name, date, and ID, which are typical in corporate settings. The message is straightforward and does not contain any suspicious links or urgent requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication regarding expense report requirements. I...
# ================================================================================
#
# Evaluating Email 977...
# Phishing=False Reason="The email appears to be a technical inquiry about connecting GP2D02 range sensors to a handyboard. It's asking for advice on hardware setup, which is a legitimate technical question."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical inquiry about connecting GP2D02 range sensors to a handyboard. I...
# ================================================================================
#
# Evaluating Email 978...
# Phishing=True Reason='The email contains nonsensical text with fragmented sentences, spelling errors, and irrelevant content. It appears to be a poorly constructed attempt to lure recipients into clicking on links or providing personal information, likely for fraudulent purposes.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with fragmented sentences, spelling errors, and irrelevant conte...
# ================================================================================
#
# Evaluating Email 979...
# Phishing=True Reason='The email contains suspicious content, including explicit language, urgent requests to click a link, and misleading information about the sender. It also has grammatical errors and an unprofessional tone.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content, including explicit language, urgent requests to click a link,...
# ================================================================================
#
# Evaluating Email 980...
# Phishing=True Reason='The email contains a suspicious link (http://uxqv.winforgiveness.com) and includes religious content that seems unrelated to the subject line. The message appears to be a random quote with an embedded malicious link, which is a common phishing tactic.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains a suspicious link (http://uxqv.winforgiveness.com) and includes religious content...
# ================================================================================
#
# Evaluating Email 981...
# Phishing=True Reason='The email contains suspicious links with personal information in the URL (e.g., user=michael.e.taylor@enron.com), which could be a phishing attempt to steal credentials. The subject mentions a specific date (November 20, 2001) that is over two decades old, which seems outdated. The email also includes a warning about sharing links as equivalent to sharing a password, which is unusual for legitimate emails.'
#   Actual: Legitimate
#   Predicted: Phishing
#   Correct: False
#   Reason: The email contains suspicious links with personal information in the URL (e.g., user=michael.e.taylo...
# ================================================================================
#
# Evaluating Email 982...
# Phishing=True Reason='The email contains nonsensical text with no coherent message, suspicious characters, and appears to be a random string of letters. This is typical of phishing attempts that use garbled text to avoid detection by spam filters.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with no coherent message, suspicious characters, and appears to ...
# ================================================================================
#
# Evaluating Email 983...
# Phishing=False Reason='The email content appears to be a random collection of fragmented sentences and phrases without coherent structure or clear intent. There are no suspicious links, urgent requests, or attempts to deceive. The text seems to be an incoherent mix of unrelated ideas, possibly from different sources or a corrupted message.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email content appears to be a random collection of fragmented sentences and phrases without cohe...
# ================================================================================
#
# Evaluating Email 984...
# Phishing=True Reason='The email contains suspicious links pointing to a non-official domain (jumpstartlovelifetoday.com) and uses urgent language to prompt immediate action. The subject line is misleading, claiming the recipient is a winner without any prior interaction. Additionally, the email appears to be a scam attempting to trick the user into clicking on malicious links.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links pointing to a non-official domain (jumpstartlovelifetoday.com) a...
# ================================================================================
#
# Evaluating Email 985...
# Phishing=False Reason="The email is a legitimate academic discussion about topics related to 'sex and language' and self-censorship in academia. It's asking for feedback on discussing taboo subjects and the role of political correctness, which is a normal academic debate."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate academic discussion about topics related to 'sex and language' and self-ce...
# ================================================================================
#
# Evaluating Email 986...
# Phishing=True Reason="The email contains suspicious content promoting unverified products, has poor grammar and formatting, and includes a deceptive link. The subject line is nonsensical and the body mentions 'doc' in an odd context, which is likely a phishing attempt to steal personal information or money."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content promoting unverified products, has poor grammar and formatting...
# ================================================================================
#
# Evaluating Email 987...
# Phishing=False Reason='The email is a technical discussion about software tools (gtalk, 9term) among users of Unix-like systems. It contains no suspicious links, urgent requests, or attempts to steal information. The content is consistent with legitimate technical correspondence from the 1990s.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about software tools (gtalk, 9term) among users of Unix-like sys...
# ================================================================================
#
# Evaluating Email 988...
# Phishing=False Reason="The email is brief and contains no suspicious elements. It references a specific date (November 13, 2001) and mentions 'PGE Position Reports' which could be a legitimate business document. The lack of urgent language, suspicious links, or requests for personal information suggests it's not phishing."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is brief and contains no suspicious elements. It references a specific date (November 13, ...
# ================================================================================
#
# Evaluating Email 989...
# Phishing=False Reason='The email appears to be a legitimate invitation for a team meeting with specific details about time, date, location, and RSVP instructions. There are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or grammatical errors.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate invitation for a team meeting with specific details about time,...
# ================================================================================
#
# Evaluating Email 990...
# Phishing=False Reason='The email is a proposal for an educational project involving wearable technology and music creation. It contains no suspicious links, urgent requests, or deceptive content. The language is professional and the subject line is specific to an academic or creative endeavor.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a proposal for an educational project involving wearable technology and music creation....
# ================================================================================
#
# Evaluating Email 991...
# Phishing=False Reason='The email appears to be a casual conversation between two people, with no suspicious content or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a casual conversation between two people, with no suspicious content or requ...
# ================================================================================
#
# Evaluating Email 992...
# Phishing=True Reason='The email contains non-English characters and appears to be garbled or corrupted. The subject line and body text are not coherent, which is a common indicator of phishing attempts. Additionally, there are no clear details about the sender or the purpose of the email.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains non-English characters and appears to be garbled or corrupted. The subject line a...
# ================================================================================
#
# Evaluating Email 993...
# Phishing=False Reason='The email appears to be a legitimate scheduling request from Shirley Crenshaw regarding a follow-up meeting on Wharton. It contains specific details about availability, dates, and times, and is addressed to known contacts. The tone is professional and the content is straightforward without any suspicious elements.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate scheduling request from Shirley Crenshaw regarding a follow-up ...
# ================================================================================
#
# Evaluating Email 994...
# Phishing=False Reason='The email appears to be a legitimate internal business communication between employees of Enron and Booz Allen Hamilton regarding an NDA (Non-Disclosure Agreement). It contains proper formatting, specific details about the document, and references to previous communications. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication between employees of Enron and ...
# ================================================================================
#
# Evaluating Email 995...
# Phishing=False Reason="The email is a legitimate discussion about anti-spam strategies, referencing technical details like greylisting, DNSBLs, and Spamassassin. It includes a PGP signature, which is commonly used in secure communications. There's no deceptive content or requests for sensitive information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate discussion about anti-spam strategies, referencing technical details like ...
# ================================================================================
#
# Evaluating Email 996...
# Phishing=True Reason='The email contains suspicious elements such as irregular formatting, excessive spacing, and non-standard language. The URL provided appears to be a fabricated domain (vacancy-0219819435.SCCENTRE.HK) which is not a legitimate company website. Additionally, the job offer seems too good to be true with guaranteed high rewards and minimal work requirements, which are common phishing tactics.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as irregular formatting, excessive spacing, and non-stan...
# ================================================================================
#
# Evaluating Email 997...
# Phishing=False Reason='The email appears to be a legitimate stock price notification from SatCon Technology Corporation. It includes specific financial data, clear instructions for updating preferences, and proper contact information. The content is straightforward and does not contain typical phishing indicators like urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate stock price notification from SatCon Technology Corporation. It...
# ================================================================================
#
# Evaluating Email 998...
# Phishing=False Reason='The email appears to be a legitimate internal business communication between employees of Enron regarding the potential sale of a pipeline. It contains standard business details, contact information, and references to specific projects. There are no suspicious links, urgent requests for personal information, or deceptive content typical of phishing emails.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication between employees of Enron rega...
# ================================================================================
#
# Evaluating Email 999...
# Phishing=True Reason='The email contains suspicious elements such as a generic subject line, an unclear sender, and a link to an unfamiliar domain. The presence of an unsubscribe link with a strange URL structure and the inclusion of a postal address that seems fabricated or irrelevant raise red flags.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as a generic subject line, an unclear sender, and a link...
# ================================================================================
#
# Evaluating Email 1000...
# Phishing=False Reason="The email appears to be a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mailing list. It contains technical discussions about spam filtering methods like TMDA, SPEWS, and open relay lists. The content is consistent with an ongoing conversation among system administrators and IT professionals. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing attempts."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mail...
#
# Evaluation completed

# %%
# Create results dataframe and display detailed results
results_df = pd.DataFrame(results)

print("=== DETAILED RESULTS ===")
print(results_df[['email_id', 'subject', 'actual_class', 'predicted_class', 'is_correct']].to_string(index=False))

print("\n=== LLM REASONING ===")
for result in results:
    print(f"\nEmail {result['email_id']}: {result['subject']}")
    print(f"Prediction: {result['predicted_class']}")
    print(f"Reason: {result['llm_reason']}")
# Out:
# === DETAILED RESULTS ===
#  email_id                                                subject actual_class predicted_class  is_correct
#         1  Re: [UAI] Imprecise Probabilities--A simple and ye...   Legitimate      Legitimate        True
#         2                                                    ...   Legitimate      Legitimate        True
#         3                           But lonetree none kinnear...     Phishing      Legitimate       False
#         4                      poznan linguistic meeting 1999...   Legitimate      Legitimate        True
#         5           TRV Notification:  (EMW P/L - 11/21/2001)...   Legitimate      Legitimate        True
#         6  Commissioner.COM E-Reports for Get Bad with Yourse...   Legitimate      Legitimate        True
#         7                              Perfected RX Discounts...     Phishing        Phishing        True
#         8              Re: [R] subset arg in (modified) evalq...   Legitimate      Legitimate        True
#         9  [UAI] Current status of mixed symbolic / numeric b...   Legitimate      Legitimate        True
#        10            Thanks!  I found the FAQ and Archives......   Legitimate      Legitimate        True
#        11                great impotence medication solutions...     Phishing        Phishing        True
#        12               adf Get a T-Mobile Sidekick ID on us!...     Phishing        Phishing        True
#        13  [R] BIC and Hosmer-Lemeshow statistic for logistic...   Legitimate      Legitimate        True
#        14  ���ڵ���ó�� ������ȭ "Ann��" ��ñ�� �����̺�Ʈ !!! n xi...     Phishing        Phishing        True
#        15         re :     . .            . . qzpwbxam nzfagu...     Phishing        Phishing        True
#        16                                           message 4...   Legitimate      Legitimate        True
#        17     Start a new career today-Signing Bonus Included...     Phishing        Phishing        True
#        18                                     Generic Wlaggra...     Phishing        Phishing        True
#        19                re : attn : online bulk verification...     Phishing        Phishing        True
#        20  Special issue of news from  CNBC! Urgent  Dangerou...     Phishing        Phishing        True
#        21  Re: svn commit: samba r22844 - in branches: SAMBA_...   Legitimate      Legitimate        True
#        22                       RE: Final Keystone Term Sheet...   Legitimate      Legitimate        True
#        23                                   RE: Are you there...   Legitimate      Legitimate        True
#        24         ���������߰��� �ڰ��� ������������� �����帳�ϴ�...     Phishing        Phishing        True
#        25            now super site new for ch|ldren$ pass: q...     Phishing        Phishing        True
#        26                    be$t prices for top qulity meds ...     Phishing        Phishing        True
#        27                       WAITING TO HEAR FROM YOU SOON...     Phishing        Phishing        True
#        28                       business proposer from walter...     Phishing        Phishing        True
#        29  Become a sexual monster for 36 hours with Cia1is S...     Phishing        Phishing        True
#        30                  [DMDX] Images' Size and resolution...   Legitimate      Legitimate        True
#        31              FW: Physical Index Positions Dec. 2001...   Legitimate      Legitimate        True
#        32                                           FNC Alert...   Legitimate      Legitimate        True
#        33                                  PE Today: True Lou...   Legitimate      Legitimate        True
#        34                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#        35                 ietf-dkim Digest, Vol 107, Issue 11...   Legitimate      Legitimate        True
#        36                           re : enron open positions...   Legitimate      Legitimate        True
#        37     review : scobbie : autosegmental representation...   Legitimate      Legitimate        True
#        38                          11.13.01 Flu shot schedule...   Legitimate      Legitimate        True
#        39               Online store offers special discounts...     Phishing        Phishing        True
#        40  Re: Smoke [5.10.0] 32308 FAIL(F) openbsd 4.1 (i386...   Legitimate      Legitimate        True
#        41            Re: [R] Comparing multiple distributions...   Legitimate      Legitimate        True
#        42                                           Hot news....     Phishing        Phishing        True
#        43                                       Please review...   Legitimate      Legitimate        True
#        44                                                re :...   Legitimate      Legitimate        True
#        45                               Adobe Dreamweaver $59...     Phishing      Legitimate       False
#        46  Rev 163: merge from ronnie in http://samba.org/~tr...   Legitimate      Legitimate        True
#        47                           Re: Not Understanding TGE...   Legitimate      Legitimate        True
#        48  RE: Transwestern Pipeline Payment Under Protest (C...   Legitimate      Legitimate        True
#        49  [DMDX] marking picture onset with dmdx in acqknowl...   Legitimate      Legitimate        True
#        50                                  Re: Wall Following...   Legitimate      Legitimate        True
#        51  Most reliable replica from Patek Philippe watch he...     Phishing        Phishing        True
#        52  Re: [opensuse] isa bus? [Was: [OT] How much power ...   Legitimate      Legitimate        True
#        53   start date : 12 / 20 / 01 ; hourahead hour : 20 ;...   Legitimate      Legitimate        True
#        54                                     re : internship...   Legitimate      Legitimate        True
#        55                  Re: The Curse of India's Socialism...   Legitimate      Legitimate        True
#        56                              associates prc meeting...   Legitimate      Legitimate        True
#        57                                   Your eBay account...     Phishing        Phishing        True
#        58                                       Re: on lively...     Phishing        Phishing        True
#        59                                  Refinance approved...     Phishing        Phishing        True
#        60  [UAI] DKE special issue on Intelligent Data Mining...   Legitimate      Legitimate        True
#        61                                     did you miss me...     Phishing        Phishing        True
#        62  svn commit: samba r22489 - in branches/SAMBA_3_0/s...   Legitimate      Legitimate        True
#        63  your r _ x order is ready for refill girl scout lo...     Phishing        Phishing        True
#        64  Start Date: 10/12/01; HourAhead hour: 16;  <CODESI...   Legitimate      Legitimate        True
#        65  SoE at UCSC looking for an experienced IT support ...   Legitimate      Legitimate        True
#        66       command confirmation request ( 4 e 46 c 824 )...   Legitimate      Legitimate        True
#        67                   Is yours D1ck to short?    w5rv8z...     Phishing        Phishing        True
#        68                   Help Stop Premature Ejaculation! ...     Phishing        Phishing        True
#        69                             santender@infoemail.com...     Phishing        Phishing        True
#        70                             Television-game devices...     Phishing        Phishing        True
#        71  looking for cheap high - quality software ? pipest...     Phishing        Phishing        True
#        72                                 [Mhln] (no subject)...     Phishing        Phishing        True
#        73         Today's WeatherDirect Forecast for Waterloo...   Legitimate      Legitimate        True
#        74                         beaver creek accommodations...   Legitimate      Legitimate        True
#        75  Re: svn commit: samba r23689 - in branches/SAMBA_3...   Legitimate      Legitimate        True
#        76                                          From DUBAI...     Phishing        Phishing        True
#        77  Measures and means in order to help to your health...     Phishing        Phishing        True
#        78            RE: Renewable Energy Product Description...   Legitimate      Legitimate        True
#        79  Re: [opensuse] Unstable system - who is the culpri...   Legitimate      Legitimate        True
#        80                     [Bug 5439] HOT_NASTY deficiency...   Legitimate      Legitimate        True
#        81      localized software , all languages available ....     Phishing        Phishing        True
#        82                                  Now you believe me...     Phishing      Legitimate       False
#        83                                     Termination Log...   Legitimate      Legitimate        True
#        84                                    re : industrials...   Legitimate      Legitimate        True
#        85                       Popular soft - very low price...     Phishing        Phishing        True
#        86                              re : power plant model...   Legitimate      Legitimate        True
#        87                        Packets ending October, 2001...   Legitimate      Legitimate        True
#        88  Today's Headlines from NYTimes.com Sunday, October...   Legitimate      Legitimate        True
#        89                                    And and canfield...     Phishing        Phishing        True
#        90                                        ��ǰ�� ��޸Ű�....     Phishing        Phishing        True
#        91                Don't know where to buy medications?...     Phishing        Phishing        True
#        92                                  U9fs Compile Help?...   Legitimate      Legitimate        True
#        93  University Degree breaks the glass ceiling over yo...     Phishing        Phishing        True
#        94                                   RE: FYI on espeak...   Legitimate      Legitimate        True
#        95                      Re: syntax error of some sort?...   Legitimate      Legitimate        True
#        96                                          Re: servos...   Legitimate      Legitimate        True
#        97                                             cinergy...   Legitimate      Legitimate        True
#        98                                                 Re:...     Phishing        Phishing        True
#        99                                               Howdy...     Phishing        Phishing        True
#       100                                    software license...   Legitimate      Legitimate        True
#       101  Re: [Python-3000] Consistency of memoryview and by...   Legitimate      Legitimate        True
#       102                 Schedule Crawler: HourAhead Failure...   Legitimate      Legitimate        True
#       103              Limited Time Deals on Portland Hotels!...     Phishing      Legitimate       False
#       104          Start Date: 12/26/01; HourAhead hour: 23; ...   Legitimate      Legitimate        True
#       105                                 From Yolanda Grimes...     Phishing        Phishing        True
#       106  The company is looking for new employees. [letter ...     Phishing        Phishing        True
#       107                      Stock Notification for Napster...   Legitimate      Legitimate        True
#       108  Um... hello? Only a few days to send for Valentine...   Legitimate      Legitimate        True
#       109                         Your Mrtge Loan ID: 653-971...     Phishing        Phishing        True
#       110               PhentrimineHealthyLifeMoneybackPolicy...     Phishing        Phishing        True
#       111                              contracts address list...   Legitimate      Legitimate        True
#       112                                      VERY IMPORTANT...     Phishing        Phishing        True
#       113  svn commit: r581582 - /spamassassin/trunk/rules/50...   Legitimate      Legitimate        True
#       114                                     from 17 because...     Phishing        Phishing        True
#       115           We reduced prices for these fashion items...     Phishing        Phishing        True
#       116            delivery status notification ( failure )...     Phishing      Legitimate       False
#       117  920p 6/11 Update: Mission extended, EVA added; bla...   Legitimate      Legitimate        True
#       118            Re: [R] Fitted Value Pareto Distribution...   Legitimate      Legitimate        True
#       119                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#       120              REQUEST FOR YOUR UNRESERVED ASSISTANCE...     Phishing        Phishing        True
#       121  ���� ���� ������Ʈ! (����! �ݰǽ� ���� ������ �帳�ϴ�.)...     Phishing        Phishing        True
#       122                      RE: Marketing Business Objects...   Legitimate      Legitimate        True
#       123  svn commit: samba r22182 - in branches/SAMBA_4_0/s...   Legitimate      Legitimate        True
#       124  Re: [svn:perl6-synopsis] r14386 - doc/trunk/design...   Legitimate      Legitimate        True
#       125                           enron japan weekly update...   Legitimate      Legitimate        True
#       126  svn commit: samba r22679 - in branches/SAMBA_3_0_2...   Legitimate      Legitimate        True
#       127              NewProductsOnlineDrugstoreVisaAccepted...     Phishing        Phishing        True
#       128                             Hottest Diet in America...     Phishing        Phishing        True
#       129  Re: [opensuse] openSUSE 11.0 and the Non-ready KDE...   Legitimate      Legitimate        True
#       130  Re: building a remote debugger for win32 -- need h...   Legitimate      Legitimate        True
#       131  Fw: Are You Living in Debt, Paycheck to Paycheck?3...     Phishing        Phishing        True
#       132    do not have money , get software cds from here !...     Phishing      Legitimate       False
#       133                    RE: Financial Trading Agreements...   Legitimate      Legitimate        True
#       134         �����ôް� �ڵ��� �ٲ���!!Ư���� �̺�Ʈ^^* hrrlr u...     Phishing        Phishing        True
#       135  RE: FW: Master purchase/sale agreement - Salt Rive...   Legitimate      Legitimate        True
#       136                   RE: FW: Update on SRP Margin Call...   Legitimate      Legitimate        True
#       137                      fw : pooling contract template...   Legitimate      Legitimate        True
#       138                              Fwd: Pharmacy bulletin...     Phishing        Phishing        True
#       139  (��������) ���ðɵ���� �߰ſ� ����Ʈ Ŭ���ϸ� ��������Ʈ��...     Phishing        Phishing        True
#       140                                                    ...     Phishing        Phishing        True
#       141                                                 Re:...     Phishing        Phishing        True
#       142  re : the consultant ' s model for gary hickerson '...   Legitimate      Legitimate        True
#       143         Re: V2.4 keeps incorrectly blue-ing folders...   Legitimate      Legitimate        True
#       144                [R] An extension of Gabriel's biplot...   Legitimate      Legitimate        True
#       145  Re: Debian GNU/Linux (kfreebsd anyone?) Lenny Desk...   Legitimate      Legitimate        True
#       146            !  Weight loss as seen on Oprah andC NN!...     Phishing        Phishing        True
#       147  review our site for weekly specials on quality taa...     Phishing        Phishing        True
#       148 svn commit: samba r22168 - in\tbranches/SAMBA_4_0/s...   Legitimate      Legitimate        True
#       149                                        News Summary...   Legitimate      Legitimate        True
#       150  EGM Operations & Accounting Organizational Changes...   Legitimate      Legitimate        True
#       151        the best drugs at the most attractive prices...     Phishing        Phishing        True
#       152  Your own health and the health of those you love i...     Phishing        Phishing        True
#       153                           teco _ gas _ issues . xls...   Legitimate      Legitimate        True
#       154                              I can help u with this...     Phishing      Legitimate       False
#       155                                   Urgent Assistance...     Phishing        Phishing        True
#       156                                       Special offer...     Phishing        Phishing        True
#       157                                    Small Cap Stocks...     Phishing      Legitimate       False
#       158                                       As to everest...     Phishing      Legitimate       False
#       159  Re: Sigils by example (was: Re: Is Perl 6 too late...   Legitimate      Legitimate        True
#       160                          Become fit and happy again...     Phishing        Phishing        True
#       161  This is the first time, I am appreciating any prod...     Phishing        Phishing        True
#       162                                    Male Enhancement...     Phishing        Phishing        True
#       163  [Spambayes] understanding high false negative rate...   Legitimate      Legitimate        True
#       164         [ Apple ] : Update Your Account Information...     Phishing        Phishing        True
#       165            stock insider reports penny pick secrets...     Phishing        Phishing        True
#       166                         [DMDX] Re: AbortItemKeyname...   Legitimate      Legitimate        True
#       167              lonely girls who are home for new year...     Phishing        Phishing        True
#       168                        here is the money we owe you...     Phishing        Phishing        True
#       169                                              oulipo...   Legitimate      Legitimate        True
#       170  lacima energy and weather derivatives courses by c...   Legitimate      Legitimate        True
#       171                                  Letter to Pat Wood...   Legitimate      Legitimate        True
#       172                              �p�������Ӧh�F�A���A�O2...     Phishing        Phishing        True
#       173  [perl #46111] [PATCH] Add tests for stderr-only in...   Legitimate      Legitimate        True
#       174                       [DMDX] Re: Experiments on Web...   Legitimate      Legitimate        True
#       175                                           ATTENTION...     Phishing        Phishing        True
#       176                             [R] cox goodness of fit...   Legitimate      Legitimate        True
#       177  Request Submitted: Access Request for ryan.slinger...   Legitimate      Legitimate        True
#       178       Re: Capturing an external program return code...   Legitimate      Legitimate        True
#       179  RE: ECT Investments, Inc. account with Goldman Sac...   Legitimate      Legitimate        True
#       180                                                 RE:...     Phishing      Legitimate       False
#       181                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#       182                     cialis soft tabs - super viagra...     Phishing        Phishing        True
#       183                                        new computer...   Legitimate      Legitimate        True
#       184                                      Phase V Tie In...   Legitimate      Legitimate        True
#       185  Re: [R] Windows vista's early terminate Rgui execu...   Legitimate      Legitimate        True
#       186                            netco power startup plan...   Legitimate      Legitimate        True
#       187                                Logistics Issues Log...   Legitimate      Legitimate        True
#       188                         hot deals on ink cartridges...     Phishing        Phishing        True
#       189                                        RE: whats up...   Legitimate      Legitimate        True
#       190                           Re: [R] Loop and function...   Legitimate      Legitimate        True
#       191                                           FNC Alert...   Legitimate      Legitimate        True
#       192             42 new messages in 16 topics - abridged...   Legitimate      Legitimate        True
#       193                      [sugar] Sugar datastore broken...   Legitimate      Legitimate        True
#       194  If penis implant is not for you, Generik Viagra wi...     Phishing        Phishing        True
#       195  ����)��[�볳/����]100% �� �� �� �� �� �� �� �� �� ��...     Phishing        Phishing        True
#       196        california power update 1 / 17 / 01 pt . iii...   Legitimate      Legitimate        True
#       197  Re: A common Debian style for Debian Installer and...   Legitimate      Legitimate        True
#       198                        improvements in wound care !...     Phishing      Legitimate       False
#       199                               september ncl meeting...   Legitimate      Legitimate        True
#       200                  [R] termplot with uniform y-limits...   Legitimate      Legitimate        True
#       201                                     EDF margin line...   Legitimate      Legitimate        True
#       202                               lots like it peppered...     Phishing        Phishing        True
#       203          Re: Intro / Parrot / Functional Lang Imp Q...   Legitimate      Legitimate        True
#       204                     Ray English Elected SPARC Chair...   Legitimate      Legitimate        True
#       205                     Problems installing XML modules...   Legitimate      Legitimate        True
#       206  You Can Enlarge Your Penis By 3" Compare Top 5 Pen...     Phishing        Phishing        True
#       207  ����ȸȭ-�¶��ΰ��ǽ�û�ױ��縦 ����� �帲�ϴ� ���ݹٷ� ��û..!@ ...     Phishing        Phishing        True
#       208    Trader, Powerful TURTLE TRADING System Revealed!...     Phishing      Legitimate       False
#       209  svn commit: samba r22146 - in branches: SAMBA_3_0/...   Legitimate      Legitimate        True
#       210                         Covenants - Project Miracle...   Legitimate      Legitimate        True
#       211                    Pay Lesss for Viicodin joe.parks...     Phishing        Phishing        True
#       212  Best Price, A-Z pills, CialisXanaViagra\\/aliun, s...     Phishing        Phishing        True
#       213                                      henwood & psim...   Legitimate      Legitimate        True
#       214                        Re: [9fans] Bonnie Benchmark...   Legitimate      Legitimate        True
#       215        [Mhln] Complete our short form in 30 seconds...     Phishing        Phishing        True
#       216             Re: [opensuse] amavisd warning failure?...   Legitimate      Legitimate        True
#       217                   Save your money, buy pills there!...     Phishing        Phishing        True
#       218                                           JOB OFFER...     Phishing        Phishing        True
#       219                                       [DMDX] 1.1.09...   Legitimate      Legitimate        True
#       220  <<Concur Expense Document>> - JSteffes Washington ...   Legitimate        Phishing       False
#       221                                    CONGRATULATIONS!...     Phishing        Phishing        True
#       222            impress your girl with a huge cumshot......     Phishing        Phishing        True
#       223                             GAS CONTROLLER POSITION...   Legitimate      Legitimate        True
#       224               Re: [Python-3000] raw strings and \\u...   Legitimate      Legitimate        True
#       225  .Buy  Swiss ReplicaRolex watch online. Great selec...     Phishing        Phishing        True
#       226  Re: [R] How to install R 2.5 with Synaptic in Ubun...   Legitimate      Legitimate        True
#       227  P.e.nis Ex-tender now only $279 DeIivered! . . . ....     Phishing        Phishing        True
#       228                                enron open positions...   Legitimate      Legitimate        True
#       229  AccuWeather.com Alert(tm) Forecast For User|AVCAVC...   Legitimate      Legitimate        True
#       230  Your Approval is Overdue: Access Request for hai.c...   Legitimate        Phishing       False
#       231  Especially for you the best medicaments and condit...     Phishing        Phishing        True
#       232       hpl meter # 989824 decker laureles farm c / p...   Legitimate      Legitimate        True
#       233                                 garner and plantain...     Phishing        Phishing        True
#       234  [Bug 3142] spamc/spamd protocol enhancement - retu...   Legitimate      Legitimate        True
#       235                             From:Mrs.Amina.A Bello....     Phishing        Phishing        True
#       236                                           jury duty...   Legitimate      Legitimate        True
#       237                              re : summer internship...   Legitimate      Legitimate        True
#       238                                   summer internship...   Legitimate      Legitimate        True
#       239                                                   "...     Phishing        Phishing        True
#       240               re:Can't afford medications you need?...     Phishing        Phishing        True
#       241                                               Money...   Legitimate        Phishing       False
#       242  Completed: Please DocuSign Statement.pdf (jose@mon...     Phishing        Phishing        True
#       243              Become self-confident! Make it happen!...     Phishing        Phishing        True
#       244                 HONDA GRAND PRIZE PROMO CLAIM PRIZE...     Phishing        Phishing        True
#       245                          where have you been thence...     Phishing        Phishing        True
#       246  Fall in value of mortgages indicates housing slowd...   Legitimate      Legitimate        True
#       247  RE: Possible London Meeting with Venezuelan Presid...   Legitimate      Legitimate        True
#       248                       re : eol guest account access...   Legitimate      Legitimate        True
#       249             Re: Douglas Electronics Expansion Board...   Legitimate      Legitimate        True
#       250                   Re: Slackware 11 aliases, anyone?...   Legitimate      Legitimate        True
#       251                              re : contracts listing...   Legitimate      Legitimate        True
#       252                Vi[agra, Levi@tra LOWEST Cost Ever! ...     Phishing        Phishing        True
#       253                                   about celebration...     Phishing        Phishing        True
#       254  svn commit: r581581 - /spamassassin/rules/trunk/sa...   Legitimate      Legitimate        True
#       255                                            For Mail...     Phishing        Phishing        True
#       256                       I wonder why you're still shy...     Phishing        Phishing        True
#       257  We selling branded watches.Rolexes.Patek.Bvlgari a...     Phishing        Phishing        True
#       258                  Fundamentals 2002 Forecast Meeting...   Legitimate      Legitimate        True
#       259  Fw: Shares of Independent Power Producers and Trad...   Legitimate      Legitimate        True
#       260            Start Date: 1/27/02; HourAhead hour: 4; ...   Legitimate      Legitimate        True
#       261                                 Viagra BUY IT HERE!...     Phishing        Phishing        True
#       262                 Re: forking problem with dbd::mysql...   Legitimate      Legitimate        True
#       263                    Extend the length and width fast...     Phishing        Phishing        True
#       264  easily lose weight / build muscle / reverse aging ...     Phishing        Phishing        True
#       265                                  ��J�ƤQ�U�з~��P����...     Phishing      Legitimate       False
#       266                          Re: [opensuse] OpenSuse 11...   Legitimate      Legitimate        True
#       267               congratulation you are a lucky winner...     Phishing        Phishing        True
#       268                                    estate migration...   Legitimate      Legitimate        True
#       269                                       Real Generics...     Phishing        Phishing        True
#       270            RE: Testing PreSchedule Workspace-June20...   Legitimate      Legitimate        True
#       271                               Ephedra for your body...     Phishing        Phishing        True
#       272                [Mhln] We accepted your loan request...     Phishing        Phishing        True
#       273       Be a part of our Shopping Review Program  adf...     Phishing        Phishing        True
#       274         Today's WeatherDirect Forecast for Waterloo...   Legitimate      Legitimate        True
#       275  Three Steps to the Software You Need at the Prices...     Phishing        Phishing        True
#       276                           How to get a larger penis...     Phishing        Phishing        True
#       277    download Photoshop CS3 right today for only $89!...     Phishing      Legitimate       False
#       278  header_checks handled differently for emails with ...   Legitimate      Legitimate        True
#       279                                               Josie...     Phishing      Legitimate       False
#       280              Your video is ready: Samuel Early 2008...   Legitimate      Legitimate        True
#       281                                          Assistant....     Phishing        Phishing        True
#       282                                                 Re:...     Phishing        Phishing        True
#       283                      Message status - undeliverable...   Legitimate      Legitimate        True
#       284                   Extend your enjoyment with Cialis...     Phishing      Legitimate       False
#       285                                  Need for Resources...   Legitimate      Legitimate        True
#       286                Basics of Risk Management Enrollment...   Legitimate      Legitimate        True
#       287                   Revised contracts to Aspect et al...   Legitimate      Legitimate        True
#       288                Inside The Rockets - January 7, 2002...   Legitimate      Legitimate        True
#       289                                            �����Ĩ�ܷ...     Phishing        Phishing        True
#       290                     Forbes Daily: Enron On The Hill...   Legitimate      Legitimate        True
#       291                                unify close schedule...   Legitimate      Legitimate        True
#       292  Generic drugs a_³ is the only one way it is produc...     Phishing      Legitimate       False
#       293                Sick of dating? Want to settle down?...     Phishing      Legitimate       False
#       294           Revolutionary mens health aid has arrived...     Phishing        Phishing        True
#       295  Re: svn commit: samba r22539 - in branches: SAMBA_...   Legitimate      Legitimate        True
#       296  Re: [Python-3000] problems with the 3to2 converter...   Legitimate      Legitimate        True
#       297  Re: mirrors inactive: debian.teleglobe.net, ftp.lu...   Legitimate      Legitimate        True
#       298                 is ROLEX under 199 $ good for you? ...     Phishing        Phishing        True
#       299                                 Fwd: FW:   NO Time?...   Legitimate      Legitimate        True
#       300                                 re: I saw it on you...     Phishing        Phishing        True
#       301                       sa : fe - the 100 % he : rbal...     Phishing        Phishing        True
#       302                        meter 984132 for 1 / 16 / 99...   Legitimate      Legitimate        True
#       303              Start new life with  CanadianPharmacy....     Phishing        Phishing        True
#       304                      Ryan, you have new Classmates!...     Phishing      Legitimate       False
#       305                [R] nlme fixed effects specification...   Legitimate      Legitimate        True
#       306                                  re : b . brandfass...   Legitimate      Legitimate        True
#       307                       weather and energy price data...   Legitimate      Legitimate        True
#       308   [R] How to remove outer box from Wireframe plots?...   Legitimate      Legitimate        True
#       309                                      ��ٺ��� �̷��ϵ�....     Phishing        Phishing        True
#       310                                       thomas lowell...   Legitimate      Legitimate        True
#       311                                      HELP ME PLEASE...     Phishing        Phishing        True
#       312                 epe lending agreement : please read...   Legitimate      Legitimate        True
#       313    Using both Sharp GP2D02 and Polaroid 6500 -Reply...   Legitimate      Legitimate        True
#       314             new pivll to increase orgyasm pleaqsure...     Phishing      Legitimate       False
#       315        -You could get a Free Laptop - Find out how!...     Phishing        Phishing        True
#       316                      Re: [Python-3000] Code freeze?...   Legitimate      Legitimate        True
#       317              PLEASE USE THIS MONEY FOR CHARITY ONLY...     Phishing        Phishing        True
#       318           Re: Bogus MX -> blacklist service viable?...   Legitimate      Legitimate        True
#       319                             TRANSSTATUS 30812 STUDY...   Legitimate      Legitimate        True
#       320                                    We need to talk ...     Phishing        Phishing        True
#       321             fw : killing ena to ena deals in sitara...   Legitimate      Legitimate        True
#       322  FW: Donnie Vinson thanks you for your ALS donation...   Legitimate      Legitimate        True
#       323                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#       324      ���ݼ��񽺺��� �������� �ſ�ī����⼭��!@ hzb oninavgo...     Phishing        Phishing        True
#       325                 Renewable Energy & Wind Map Updates...   Legitimate      Legitimate        True
#       326                RE: Security issues in the Perl core...   Legitimate      Legitimate        True
#       327                    re:Best medications, best prices...     Phishing        Phishing        True
#       328                                     reduce wrinkles...     Phishing        Phishing        True
#       329                   [Slashdot] Stories for 2008-03-30...   Legitimate      Legitimate        True
#       330                     come board and date the hottest...     Phishing        Phishing        True
#       331                   Re: compiling a new debian kernel...   Legitimate      Legitimate        True
#       332                            we bring people together...     Phishing      Legitimate       False
#       333  We selling branded watches.Rolexes.Patek.Bvlgari a...     Phishing        Phishing        True
#       334  [Python-3000] Implementing % formatting in terms o...   Legitimate      Legitimate        True
#       335                          you are OUR LUCKY WINNER!!...     Phishing        Phishing        True
#       336                                    Are as funkstown...     Phishing        Phishing        True
#       337                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#       338                 Re: forking problem with dbd::mysql...   Legitimate      Legitimate        True
#       339            Start Date: 2/4/02; HourAhead hour: 18; ...   Legitimate      Legitimate        True
#       340  Deposit confirmation required Matt.Smith@enron.com...     Phishing        Phishing        True
#       341                  di$c0unt meds shipping world wide!...     Phishing        Phishing        True
#       342  Great opportunity to give her a real pleasure ikrr...     Phishing        Phishing        True
#       343                                          RE: Ameren...   Legitimate      Legitimate        True
#       344                      re : april 2001 spot purchases...   Legitimate      Legitimate        True
#       345                                    CNN Alerts: bush...   Legitimate      Legitimate        True
#       346                                                 VAR...   Legitimate        Phishing       False
#       347                   Re: ssl certificate with password...   Legitimate      Legitimate        True
#       348                     e-Trans Contract Administration...   Legitimate      Legitimate        True
#       349                Delivery Status Notification (Relay)...   Legitimate      Legitimate        True
#       350 svn commit: samba r23439 - in\tbranches/SAMBA_3_0_2...   Legitimate      Legitimate        True
#       351           Re: Unseen window versus Sequences Window...   Legitimate      Legitimate        True
#       352  I reckon it's time you ordered a new broom, Harry....     Phishing      Legitimate       False
#       353                     Fwd: Canadian Tribute to the US...   Legitimate      Legitimate        True
#       354                      [Ip-health] Views on Brazil CL...   Legitimate      Legitimate        True
#       355                   re : culture committee next steps...   Legitimate      Legitimate        True
#       356                          it masonville each grafton...     Phishing      Legitimate       False
#       357  $14.95 per year for .COM, .BIZ, and .INFO extensio...     Phishing      Legitimate       False
#       358  XanaViagra\\/aliunCialisPhentemine from $2.00/pill...     Phishing        Phishing        True
#       359   [UAI] Professorship in Computational Neuroscience...   Legitimate      Legitimate        True
#       360                             Re: Is Perl 6 too late?...   Legitimate      Legitimate        True
#       361  Stop stressing over spills try Zorbeez            ...     Phishing        Phishing        True
#       362                                    Congratulations!...     Phishing        Phishing        True
#       363                             AA's available from EBS...   Legitimate      Legitimate        True
#       364                                 creative suite $269...     Phishing      Legitimate       False
#       365                                   congratulations !...   Legitimate        Phishing       False
#       366                                  HOW TO UNSUBSCRIBE...   Legitimate      Legitimate        True
#       367                      Re: [R] Udpate R under a proxy...   Legitimate      Legitimate        True
#       368                                   how are you today...     Phishing        Phishing        True
#       369                                          contact me...     Phishing        Phishing        True
#       370                            Penis Enlargment Reviews...     Phishing        Phishing        True
#       371                                             Cookout...   Legitimate      Legitimate        True
#       372              Re: Fonts and unicode distribution... ...   Legitimate      Legitimate        True
#       373                How to Get iPhone at Your Fingertips...     Phishing        Phishing        True
#       374  Re: [Python-3000] [Python-Dev] Python source code ...   Legitimate      Legitimate        True
#       375                  Re: Annoying HASH(0x...) in Output...   Legitimate      Legitimate        True
#       376                                CNN.com Daily Top 10...     Phishing      Legitimate       False
#       377                     Important Member Service Update...     Phishing      Legitimate       False
#       378                      AccuWeather.com Alert Forecast...   Legitimate      Legitimate        True
#       379                                                Re: ...   Legitimate      Legitimate        True
#       380  How to solve DAE with an interval initial conditio...   Legitimate      Legitimate        True
#       381                                Re: FOTW src/debug.c...   Legitimate      Legitimate        True
#       382                  putting depression on a backburner...     Phishing        Phishing        True
#       383                               Do yiu have diabetes!...     Phishing        Phishing        True
#       384  Re: Our friends the Palestinians, Our servants in ...   Legitimate      Legitimate        True
#       385            100% Safe To Take, With NO Side Effects....     Phishing        Phishing        True
#       386  CanadianPharmacy introduced really amazing seasona...     Phishing        Phishing        True
#       387                   Directory/Folders for New Company...   Legitimate        Phishing       False
#       388                  BESOIN DE VOTRE ASSISTANCE SINCERE...     Phishing        Phishing        True
#       389                                          ATTENTION....     Phishing        Phishing        True
#       390         Nova Mensagem de Voz WEB  - [ -439015187  ]...     Phishing        Phishing        True
#       391                  Products that can improve you life...     Phishing        Phishing        True
#       392                              Re: Asteroids anyone ?...   Legitimate      Legitimate        True
#       393           Draft Decision on DWR Revenue Requirement...   Legitimate      Legitimate        True
#       394                                [zzzzteana] must see...   Legitimate      Legitimate        True
#       395   Looking for really effective non-surgery method ?...     Phishing        Phishing        True
#       396                                        CONFIDENTIAL...     Phishing        Phishing        True
#       397                                      Need S0ftware?...     Phishing        Phishing        True
#       398                 INVESTMENT NEGOTIATION TO THE M/D "...     Phishing        Phishing        True
#       399                    Congratulations, member # 606474...     Phishing        Phishing        True
#       400                                       Cellular doom...   Legitimate      Legitimate        True
#       401                                       FW: BENA Info...   Legitimate      Legitimate        True
#       402  (����)����ü�� �̺�Ʈ��� �갳���� 5������ �������� ��ۺ�...     Phishing        Phishing        True
#       403                                         Rise report...     Phishing        Phishing        True
#       404                              Bitpipe KnowledgeAlert...   Legitimate      Legitimate        True
#       405  Re: [R] Fisher's r to z' transformation - help nee...   Legitimate      Legitimate        True
#       406                                   re : confidential...   Legitimate      Legitimate        True
#       407  Re: [Python-Dev] difference between diff string im...   Legitimate      Legitimate        True
#       408                                                Dave...   Legitimate      Legitimate        True
#       409         �����@���ʨ��Ҧ�����Ҫ��P����(�t��l��)::::����...     Phishing        Phishing        True
#       410                            fw : fw : weekly reports...   Legitimate      Legitimate        True
#       411  Re: Inconsistency between groupmap "Domain Admins"...   Legitimate      Legitimate        True
#       412                          BestQualityPillsYourHealth...     Phishing        Phishing        True
#       413                   read this to find the right stock...     Phishing        Phishing        True
#       414            RE: Generalized  Interval Arithmetic.......   Legitimate      Legitimate        True
#       415                  Strictly confidential. Reply soon....     Phishing        Phishing        True
#       416                         Healthy life is your dream?...     Phishing        Phishing        True
#       417        Q. How do I get my partner to like oral sex?...     Phishing        Phishing        True
#       418                               Sept. Deals 9/15-9/30...   Legitimate      Legitimate        True
#       419                                 Re: Module question...   Legitimate      Legitimate        True
#       420  welcome CODE1NE, V1AAGRRA, V1CODD1N, XANAA, C1AAL1...     Phishing        Phishing        True
#       421                                     Invalid Contact...     Phishing        Phishing        True
#       422                       Re: windows nt and handyboard...   Legitimate      Legitimate        True
#       423      RE: Further Strategic Planning - Environmental...   Legitimate      Legitimate        True
#       424                                            Re: From...   Legitimate      Legitimate        True
#       425           Transaction Manager position.    Ref:0777...     Phishing        Phishing        True
#       426                                                    ...   Legitimate      Legitimate        True
#       427 svn commit: samba r22428 - in\tbranches/SAMBA_3_0_2...   Legitimate      Legitimate        True
#       428                               Is provoke so sucrose...     Phishing        Phishing        True
#       429  Re: [R] R2 always increases as variables are added...   Legitimate      Legitimate        True
#       430       Friendly support! Instant shipping worldwide!...     Phishing        Phishing        True
#       431    OFHEO MODIFICATIONS TO RISK - BASED CAPITAL RULE...   Legitimate      Legitimate        True
#       432                                      Enron Mentions...   Legitimate      Legitimate        True
#       433                                Give me your opinion...     Phishing      Legitimate       False
#       434  Rev 414: added package download in http://samba.or...   Legitimate      Legitimate        True
#       435              [Fwd: Re: [ILUG] Linux PCs from Tesco]...   Legitimate      Legitimate        True
#       436                           FW: Station 2 maintenance...   Legitimate      Legitimate        True
#       437    Adobe Photoshop+Premiere+Illustrator = usd129.95...     Phishing        Phishing        True
#       438                              If you are looking for...     Phishing        Phishing        True
#       439  ī��볳 ������100%!! ī��볳�� ������ ���� ���ͳݽ�û������...     Phishing        Phishing        True
#       440                                    important notice...     Phishing      Legitimate       False
#       441                                         interesting...   Legitimate        Phishing       False
#       442  Re: [R] Fwd: Using odesolve to produce non-negativ...   Legitimate      Legitimate        True
#       443                            Work offer form company....     Phishing        Phishing        True
#       444             Re: Email with no "hits" and "required"...   Legitimate      Legitimate        True
#       445                                 jackrabbit vibrator...     Phishing      Legitimate       False
#       446  Commissioner.COM E-Reports for Get Bad with Yourse...   Legitimate      Legitimate        True
#       447                                                    ...   Legitimate      Legitimate        True
#       448                     Elevate sex drive to new levels...     Phishing        Phishing        True
#       449                                       Color Printer...   Legitimate      Legitimate        True
#       450       perfect visual solution for your business now...     Phishing        Phishing        True
#       451                       Learn the Tips on Good Health...     Phishing        Phishing        True
# ...
#
# Email 958: Top quality prescripiton here...
# Prediction: Phishing
# Reason: The email contains suspicious links to a non-credible domain, urgent language about medication, and appears to be a scam attempting to steal personal information or money.
#
# Email 959: odbc.lib still linked?...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about linking libraries in software development. It contains specific code snippets and technical details related to programming, which is consistent with legitimate communication among developers.
#
# Email 960: Re: [opensuse] du -shx issue/question...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about using the 'du' command in Linux. It's a legitimate conversation between users regarding system administration issues, not attempting to deceive or steal information.
#
# Email 961: She will love you more than any other guy...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as an irrelevant subject line, an unknown link, and fragmented text that may indicate a phishing attempt.
#
# Email 962: Your honesty will be appreciated and ED cured....
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic greeting, urgent language about a limited-time offer, and a suspicious domain (traditionstreet.com). The subject line is unclear and the body lacks specific details. The date is from 2008, which is outdated, suggesting possible spoofing.
#
# Email 963: RE: Bob Hall...
# Prediction: Legitimate
# Reason: The email appears to be a casual conversation between two individuals discussing someone named Bob Hall. There are no suspicious links, urgent requests for personal information, or deceptive content typical of phishing emails.
#
# Email 964: how ' s it going...
# Prediction: Phishing
# Reason: The email contains nonsensical, random text with no coherent message. It includes a suspicious link to 'koreaherbal.com' which may be malicious. The subject line is generic and the body has no legitimate content, indicating it's likely a phishing attempt.
#
# Email 965: CAISO Notice - June 19 FERC Order - Emissions and ...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate notice from CAISO regarding FERC orders and tariff revisions. It contains specific details about the order, dates, and links to official documents. The language is formal and professional, with no urgent requests for action or suspicious links.
#
# Email 966: Rev 11978: Merge wireshark and ejs test improvemen...
# Prediction: Legitimate
# Reason: The email appears to be a technical commit log from a software development project, likely related to Samba. It contains detailed revision information, author names, timestamps, and file modifications. There are no suspicious links, urgent requests, or attempts to deceive the recipient. The content is consistent with internal developer communications.
#
# Email 967: we have a cas1no that suits you...
# Prediction: Phishing
# Reason: The email contains multiple suspicious elements such as a misspelled subject line ('cas1no' instead of 'casino'), an unrealistic offer of 300 Euros free on the first deposit, and a vague invitation to join players. These are common indicators of phishing attempts aimed at tricking users into providing personal information or clicking malicious links.
#
# Email 968: STOP_PAYING_FOR YOUR PayPerView Movies b2afv93209...
# Prediction: Phishing
# Reason: The email contains suspicious links, urgent language about stopping payments, and a non-credible subject line with random characters. The domain names are not legitimate and likely part of a scam.
#
# Email 969: [perl #46067] OK: perl 5.10.0 +DEVEL on amd64-free...
# Prediction: Legitimate
# Reason: The email is a technical report about a Perl build success, containing detailed system and configuration information. It appears to be from a legitimate source related to software development, with no signs of phishing indicators like urgent requests, suspicious links, or deceptive content.
#
# Email 970: AccuWeather.com Alert Forecast...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate weather forecast from AccuWeather.com. It contains standard weather information, subscription details, and contact information. There are no suspicious links or requests for personal information.
#
# Email 971: whats up ?-)...
# Prediction: Phishing
# Reason: The email contains suspicious links, informal tone with typos, and an unusual request to visit a website. The link provided appears to be a random string of characters and is likely malicious.
#
# Email 972: Last Week to Receive Early Bird Discount to Attend...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate promotional message from Electric Utility Consultants Inc. (EUCI) about their upcoming conferences. It provides detailed information about the events, includes contact details, and instructions for registration. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.
#
# Email 973: N58 Little Sharess Are Coming Up Big...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as grammatical errors ('moneyy', 'sound and swift'), urgent language about investment opportunities, and a mix of unrelated content. The presence of a strange domain (keno.com) and the inclusion of an unrelated news article suggest it's a phishing attempt to lure recipients into investing or clicking malicious links.
#
# Email 974: You have received an eCard...
# Prediction: Phishing
# Reason: The email contains a suspicious link to 'SuperGreetingcard.com' which is likely a phishing site. The domain appears generic and the URL structure is unusual. The message is brief and lacks personalization, which is common in phishing attempts.
#
# Email 975: do you know how others sav on top - selling tablet...
# Prediction: Phishing
# Reason: The email contains multiple suspicious elements: incorrect grammar and spelling errors, a suspicious link with an unusual domain (kq.g.sunbeamlightening.com), mentions of 'superssale' and 'featured ddeals' which are likely typos, and the overall content seems to be promoting a questionable online pharmacy. The message also appears to be from an unknown sender and contains irrelevant text at the end.
#
# Email 976: Expense Report Receipts Not Received...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal communication regarding expense report requirements. It contains specific details like employee name, report name, date, and ID, which are typical in corporate settings. The message is straightforward and does not contain any suspicious links or urgent requests for sensitive information.
#
# Email 977: Multiple GP2D02 range sensors...
# Prediction: Legitimate
# Reason: The email appears to be a technical inquiry about connecting GP2D02 range sensors to a handyboard. It's asking for advice on hardware setup, which is a legitimate technical question.
#
# Email 978: please checkout the hottest watches we have, from ...
# Prediction: Phishing
# Reason: The email contains nonsensical text with fragmented sentences, spelling errors, and irrelevant content. It appears to be a poorly constructed attempt to lure recipients into clicking on links or providing personal information, likely for fraudulent purposes.
#
# Email 979: keep porn free . . ....
# Prediction: Phishing
# Reason: The email contains suspicious content, including explicit language, urgent requests to click a link, and misleading information about the sender. It also has grammatical errors and an unprofessional tone.
#
# Email 980: Re:...
# Prediction: Phishing
# Reason: The email contains a suspicious link (http://uxqv.winforgiveness.com) and includes religious content that seems unrelated to the subject line. The message appears to be a random quote with an embedded malicious link, which is a common phishing tactic.
#
# Email 981: November 20, 2001 Evolution Express Daily Report f...
# Prediction: Phishing
# Reason: The email contains suspicious links with personal information in the URL (e.g., user=michael.e.taylor@enron.com), which could be a phishing attempt to steal credentials. The subject mentions a specific date (November 20, 2001) that is over two decades old, which seems outdated. The email also includes a warning about sharing links as equivalent to sharing a password, which is unusual for legitimate emails.
#
# Email 982: ����� 100% ��~��~��~��~�� �� �����ϼ���..�ʹ��� ����...
# Prediction: Phishing
# Reason: The email contains nonsensical text with no coherent message, suspicious characters, and appears to be a random string of letters. This is typical of phishing attempts that use garbled text to avoid detection by spam filters.
#
# Email 983: Got the message...
# Prediction: Legitimate
# Reason: The email content appears to be a random collection of fragmented sentences and phrases without coherent structure or clear intent. There are no suspicious links, urgent requests, or attempts to deceive. The text seems to be an incoherent mix of unrelated ideas, possibly from different sources or a corrupted message.
#
# Email 984: Are you the winner MATT.MOTLEY@enron.com...
# Prediction: Phishing
# Reason: The email contains suspicious links pointing to a non-official domain (jumpstartlovelifetoday.com) and uses urgent language to prompt immediate action. The subject line is misleading, claiming the recipient is a winner without any prior interaction. Additionally, the email appears to be a scam attempting to trick the user into clicking on malicious links.
#
# Email 985: disc . sex and language...
# Prediction: Legitimate
# Reason: The email is a legitimate academic discussion about topics related to 'sex and language' and self-censorship in academia. It's asking for feedback on discussing taboo subjects and the role of political correctness, which is a normal academic debate.
#
# Email 986: doc ' tors invent spe ` rm , pills '...
# Prediction: Phishing
# Reason: The email contains suspicious content promoting unverified products, has poor grammar and formatting, and includes a deceptive link. The subject line is nonsensical and the body mentions 'doc' in an odd context, which is likely a phishing attempt to steal personal information or money.
#
# Email 987: Re: Faking it under Unix (was Re: Plan 9: The futu...
# Prediction: Legitimate
# Reason: The email is a technical discussion about software tools (gtalk, 9term) among users of Unix-like systems. It contains no suspicious links, urgent requests, or attempts to steal information. The content is consistent with legitimate technical correspondence from the 1990s.
#
# Email 988: PGE Position Reports - As of November 13, 2001...
# Prediction: Legitimate
# Reason: The email is brief and contains no suspicious elements. It references a specific date (November 13, 2001) and mentions 'PGE Position Reports' which could be a legitimate business document. The lack of urgent language, suspicious links, or requests for personal information suggests it's not phishing.
#
# Email 989: sun devil team introductory get together...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate invitation for a team meeting with specific details about time, date, location, and RSVP instructions. There are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or grammatical errors.
#
# Email 990: musical narrative wearable construction kit...
# Prediction: Legitimate
# Reason: The email is a proposal for an educational project involving wearable technology and music creation. It contains no suspicious links, urgent requests, or deceptive content. The language is professional and the subject line is specific to an academic or creative endeavor.
#
# Email 991: RE: ...
# Prediction: Legitimate
# Reason: The email appears to be a casual conversation between two people, with no suspicious content or requests for sensitive information.
#
# Email 992: �����  �湮���� 2�ð��ȿ� �ٳ���...
# Prediction: Phishing
# Reason: The email contains non-English characters and appears to be garbled or corrupted. The subject line and body text are not coherent, which is a common indicator of phishing attempts. Additionally, there are no clear details about the sender or the purpose of the email.
#
# Email 993: follow - up meeting on wharton...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate scheduling request from Shirley Crenshaw regarding a follow-up meeting on Wharton. It contains specific details about availability, dates, and times, and is addressed to known contacts. The tone is professional and the content is straightforward without any suspicious elements.
#
# Email 994: FW: [Fwd: Enron Net Works NDA]...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication between employees of Enron and Booz Allen Hamilton regarding an NDA (Non-Disclosure Agreement). It contains proper formatting, specific details about the document, and references to previous communications. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.
#
# Email 995: Re: [ILUG] Advice on Anti-Spam Strategy/Blocking S...
# Prediction: Legitimate
# Reason: The email is a legitimate discussion about anti-spam strategies, referencing technical details like greylisting, DNSBLs, and Spamassassin. It includes a PGP signature, which is commonly used in secure communications. There's no deceptive content or requests for sensitive information.
#
# Email 996: Vacant position in the Sydney Car Centre...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as irregular formatting, excessive spacing, and non-standard language. The URL provided appears to be a fabricated domain (vacancy-0219819435.SCCENTRE.HK) which is not a legitimate company website. Additionally, the job offer seems too good to be true with guaranteed high rewards and minimal work requirements, which are common phishing tactics.
#
# Email 997: Stock Notification for SatCon Technology Corporati...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate stock price notification from SatCon Technology Corporation. It includes specific financial data, clear instructions for updating preferences, and proper contact information. The content is straightforward and does not contain typical phishing indicators like urgent requests for personal information or suspicious links.
#
# Email 998: RE: Potential sale of Gomez lateral pipe...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication between employees of Enron regarding the potential sale of a pipeline. It contains standard business details, contact information, and references to specific projects. There are no suspicious links, urgent requests for personal information, or deceptive content typical of phishing emails.
#
# Email 999: MySpace meets Friendster - tell us about it...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic subject line, an unclear sender, and a link to an unfamiliar domain. The presence of an unsubscribe link with a strange URL structure and the inclusion of a postal address that seems fabricated or irrelevant raise red flags.
#
# Email 1000: Re: [ILUG] TMDA (WAS --> slashdot EW Dijkstra humo...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mailing list. It contains technical discussions about spam filtering methods like TMDA, SPEWS, and open relay lists. The content is consistent with an ongoing conversation among system administrators and IT professionals. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing attempts.

# %%
# Calculate performance metrics
valid_results = [r for r in results if r['predicted_label'] is not None]
total_emails = len(valid_results)
correct_predictions = sum(1 for r in valid_results if r['is_correct'])

if total_emails > 0:
    accuracy = correct_predictions / total_emails
    
    # Calculate confusion matrix components
    tp = sum(1 for r in valid_results if r['actual_label'] == 1 and r['predicted_label'] == 1)  # True Positive
    tn = sum(1 for r in valid_results if r['actual_label'] == 0 and r['predicted_label'] == 0)  # True Negative
    fp = sum(1 for r in valid_results if r['actual_label'] == 0 and r['predicted_label'] == 1)  # False Positive
    fn = sum(1 for r in valid_results if r['actual_label'] == 1 and r['predicted_label'] == 0)  # False Negative
    
    print("=== PERFORMANCE METRICS ===")
    print(f"Total emails evaluated: {total_emails}")
    print(f"Correct predictions: {correct_predictions}")
    print(f"Accuracy: {accuracy:.2%}")
    
    print("\n=== CONFUSION MATRIX ===")
    print(f"True Positives (Phishing correctly identified): {tp}")
    print(f"True Negatives (Legitimate correctly identified): {tn}")
    print(f"False Positives (Legitimate misclassified as Phishing): {fp}")
    print(f"False Negatives (Phishing misclassified as Legitimate): {fn}")
    
    # Calculate precision, recall, F1 if applicable
    if tp + fp > 0:
        precision = tp / (tp + fp)
        print(f"\nPrecision: {precision:.2%}")
    
    if tp + fn > 0:
        recall = tp / (tp + fn)
        print(f"Recall: {recall:.2%}")
    
    if tp + fp > 0 and tp + fn > 0:
        f1_score = 2 * (precision * recall) / (precision + recall)
        print(f"F1 Score: {f1_score:.2%}")
    
else:
    print("No valid results to calculate metrics.")
# Out:
# === PERFORMANCE METRICS ===
# Total emails evaluated: 1000
# Correct predictions: 924
# Accuracy: 92.40%
#
# === CONFUSION MATRIX ===
# True Positives (Phishing correctly identified): 414
# True Negatives (Legitimate correctly identified): 510
# False Positives (Legitimate misclassified as Phishing): 12
# False Negatives (Phishing misclassified as Legitimate): 64
#
# Precision: 97.18%
# Recall: 86.61%
# F1 Score: 91.59%

# %%
# Save results for future analysis
results_df.to_csv('llm_evaluation_results.csv', index=False)
print("Results saved to 'llm_evaluation_results.csv'")

# Display summary
print("\n=== EVALUATION SUMMARY ===")
print(f"Provider: {PROVIDER}")
print(f"Model: {MODEL}")
print(f"Sample size: {len(sample_df)} emails")
print(f"Successfully processed: {len(valid_results)} emails")
if total_emails > 0:
    print(f"Overall accuracy: {accuracy:.2%}")
# Out:
# Results saved to 'llm_evaluation_results.csv'
#
# === EVALUATION SUMMARY ===
# Provider: local
# Model: qwen3-30b-a3b
# Sample size: 1000 emails
# Successfully processed: 1000 emails
# Overall accuracy: 92.40%
