# %% [markdown]
# # LLM Phishing Email Detection Evaluation

# %%
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path

# Add src directory to path to import our API modules
sys.path.append('src')

from api_provider import LLM
from api_call import make_api_call

print("Dependencies imported successfully!")
# Out:
# Dependencies imported successfully!

# %%
# Load the unified phishing email dataset
df = pd.read_csv('unified_phishing_email_dataset.csv')
print(f"Dataset loaded with {len(df)} records")
print(f"Columns: {list(df.columns)}")
print(f"\nDataset info:")
print(df.info())
# Out:
# Dataset loaded with 217204 records
# Columns: ['subject', 'body', 'label', 'source']
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217204 entries, 0 to 217203
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   subject  214600 non-null  object
#  1   body     217201 non-null  object
#  2   label    217204 non-null  int64
#  3   source   217204 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 6.6+ MB
# None

# %%
# Sample 100 random records for evaluation
np.random.seed(42)  # For reproducibility
sample_df = df.sample(n=100, random_state=42).reset_index(drop=True)

print("Sample emails for evaluation:")
for i, row in sample_df.iterrows():
    print(f"\n--- Email {i+1} ---")
    print(f"Subject: {row['subject'][:100]}...")
    print(f"Body: {row['body'][:200]}...")
    print(f"True Label: {'Phishing' if row['label'] == 1 else 'Legitimate'}")
    print(f"Source: {row['source']}")
# Out:
# Sample emails for evaluation:
#
# --- Email 1 ---
# Subject: cognitive linguistics...
# Body: possession : cognitive sources , forces and grammaticalization bernd heine ( university of cologne ) ; possession : cognitive sources , forces and grammaticalization ; isbn : 0-521 - 55037 - 8 ; hardb...
# True Label: Legitimate
# Source: Ling
#
# --- Email 2 ---
# Subject: powerisk 2000 - more cocktail info...
# Body: - - - - - - - - - - - - - - - - - - - - - - forwarded by iona maclean / lon / ect on 22 / 09 / 2000 12 : 24
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# enron capital & trade resources corp ....
# True Label: Legitimate
# Source: Enron
#
# --- Email 3 ---
# Subject: Re: AC adaptor ...
# Body: Please see the FAQ for the answer to the adapter question:   http://el.www.media.mit.edu/projects/handy-board/faq/ re: the L1, that substitution may or may not work.  try it; if your motors don't work...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 4 ---
# Subject: CNN.com Daily Top 10...
# Body: >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= >THE DAILY TOP 10 >from CNN.com >Top videos and stories as of: Aug  1, 2008  3:58 PM EDT >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 5 ---
# Subject: ERV Notification:  (Violation/Notification Memo - 10/18/2001)...
# Body: The report named: Violation/Notification Memo , published as of 10/18/2001 is now available for viewing on the website....
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 6 ---
# Subject: RE: NOx Model...
# Body: http://minerals.usgs.gov/minerals/pubs/commodity/nitrogen/480396.txt
#
#  -----Original Appointment-----
# From: 	Taylor, Michael E
# Sent:	Thursday, August 02, 2001 6:04 PM
# To:	Massey II, John; Woods, Tre...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 7 ---
# Subject: REMINDER: Officers Meeting Tonight...
# Body: HKN Officers Meeting Tonight (10/20), 6:00p Near 290 Cory Agenda * EE 20N tutors needed - Paid: ~$11/hr., contact Prof. Varaiya   <varaiya@eecs> * 2 course surveys? -- Department wants information on ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 8 ---
# Subject: Free Full Length Tee_n Movies For Download...
# Body:  Today fresh movies
#
# 1. Brunette Rough Anal Pounding
# 2. Gorgeous women in sexy positons
# 3. Naughty Teens Foursome Fuck
# 4. The Hottest Teenie Movies Here
# 5.Las Vegas Teen Missy Marie Sex
#
# And much more...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 9 ---
# Subject: 1 / 2000 lower colorado river vols...
# Body: stacey ,
# the new deal , 158220 , is missing 10 , 000 for day 1 . please let me know when
# you have this corrected . thanks
# thu
# - - - - - - - - - - - - - - - - - - - - - - forwarded by thu nguyen / hou ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 10 ---
# Subject: 4 Days Only - $4.95 Shipping!...
# Body:   ==================================================================
#                         *AutoSport Catalog*
#   ==================================================================
#
#   $4.95 SHIPPIN...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 11 ---
# Subject: re : fw : luncheon meeting : asap...
# Body: hello mr . kaminski ,
# i am available to meet with you for lunch this week on tuesday ( 2 / 1 ) ,
# wednesday ( 2 / 2 ) . or friday ( 2 / 4 ) . which day would be more convenient for you ?
# please let me ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 12 ---
# Subject: Newsletter Coach'Invest - Septembre 2002...
# Body: NEWSLETTER COACHINVEST  SEPTEMBRE 2002
#
# CoachInvest, laccompagnateur des jeunes entreprises
# www.coachinvest.com ou 3615 COACHINVEST (0.34 Euros/min)
#
#
#
# DES NOUVELLES DE COACHINVEST.
#
# 1- Lancement russ...
# True Label: Phishing
# Source: SpamAssasin
#
# --- Email 13 ---
# Subject: sup its Dylan ...
# Body: Heya!
#
# Has your cum ever dribbled and you wish it had shot out?
# Have you ever wanted to impress your girl with a huge cumshot?
#
# MAX LOADS is the only site to offer an all natural male enhancement
# form...
# True Label: Phishing
# Source: TREC_06
#
# --- Email 14 ---
# Subject: Save 13% at Amazon.com on "Garfield: A Cat and His Nerd" on DVD...
# Body:
#
# Dear Amazon.com Customer,
#
# We've noticed that customers who have purchased or rated "Buffy the Vampire Slayer  - The Complete Fourth Season (Slim Set)" or other films in the Fox TV > General categor...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 15 ---
# Subject: year - to - date deals...
# Body: attached are the year - to - date deals through 11 / 8 / 01 .
# lex carroll
# enron east power marketing , inc .
# midwest origination
# 713 - 853 - 5426...
# True Label: Legitimate
# Source: Enron
#
# --- Email 16 ---
# Subject: Re: Match.com - You've Got Mail: Hello...
# Body: Hey (insert name here),
#
# Thank you for your response, it's very nice to meet you!  By the way, my name is Tracy or you can call me tp081996, ha ha!  So, what was it about me that caught your attention...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 17 ---
# Subject: Professional advertising...
# Body:
# Dear MCUILLA@enron.com:
#
# We offer Email Marketing with best services.
#
# 1. Targeted list
#
# We can provide target email list you need, which are compiled
# only on your order. We will customize your clien...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 18 ---
# Subject: All products for your health!...
# Body: http://wdngjc.movecontents.com/?35876357
#
# Suffering from pain, depression or heartburn? We'll help you!
#
#
# All verified dr@gs collected at one LICENSED online store! Great choice of wonderful meds to g...
# True Label: Phishing
# Source: TREC_06
#
# --- Email 19 ---
# Subject: re : can we add the loss on sale calculation to our weekly meeting /...
# Body: report on hpl ?
# yes ,
# that will serve as a good flash as to how the schedule / issues roll up into a post - close financial position . it has also been pinned to jim ' s lapel to optimize the value of...
# True Label: Legitimate
# Source: Enron
#
# --- Email 20 ---
# Subject: Mr Denguele djaratigui, TREAT VERY URGENT AND CONFIDENTIAL....
# Body: Dear Friend,
#
# I apologize if the contents in this mail are contrary to your moral ethics,
# which I feel may be of great disturbance to your personal life, But please
# treat with absolute secrecy and p...
# True Label: Phishing
# Source: Nigerian_5
#
# --- Email 21 ---
# Subject: RE: Garnet changing to APX...
# Body: Let me know.  I will not write a letter to the ISO terminating our SC arrangement until I hear from you or EES directs me to do so. C -----Original Message----- From: Ring, Richard  Sent: Monday, Janu...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 22 ---
# Subject: Re: Ximian apt repos?...
# Body: So to update from GNOME 1.4 to 2.0, after modifying /etc/apt/sources.list, I just issue 'apt-update' then 'apt-install gnome-session' ?  Also Gaim doesn't work with GNOME 2.0 just yet? On Sun, 2002-07...
# True Label: Legitimate
# Source: SpamAssasin
#
# --- Email 23 ---
# Subject: The Skinny: Wed., May 23, 2007...
# Body:
#
#   Home   | U.S.
#   | World
#   | Politics
#   | SciTech
#   | Health
#   | Entertainment
#   |
# Business   |
# Opinion   |
# Sports   |
# Blogs
#   |
# Interactives
# | Video
#   The Early Show
#   | CBS
# Evening N...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 24 ---
# Subject: Detecting UV light?...
# Body:  Is there a sensor that can detect UltraViolet light?  If so who
# supplies them.
#
# Thanks for the help
#
# --Peter
#
#
# ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 25 ---
# Subject: Make your fat friends envy you...
# Body:
# Take advantage of the chance! � Anatrim � The very up-to-date and most fascinating flesh loss product is now readily available � As shown on Oprah
#
# Do you hold in your memory all the situations when ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 26 ---
# Subject: Re: PDD15 implementation status...
# Body: Jonathan Worthington wrote:
# > #Instantiate it.
# > $P2 = $P2.new()
# Uh...
#
# $P2 = $P1.new()
#
# D'oh.
#
# Jonathan
#
# ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 27 ---
# Subject: No Pumps! No Surgery! No Exercises! ...
# Body:
# Read hundreds of testimonials from satisfied men and their girlfriends on this site. After years of scientific research, a herbal breakthrough is finally achieved - the product rated as #1 by healthc...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 28 ---
# Subject: You cannot do that!...
# Body: RlfQGJM
# Please read the important document.	...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 29 ---
# Subject: assistants ' holiday gifts...
# Body: please consider contributing towards the gifts / gift certificates we as a team
# will present to brenda , maria and mckenzie . i would like to have the money
# by cob monday if at all possible . recogniz...
# True Label: Legitimate
# Source: Enron
#
# --- Email 30 ---
# Subject: Start Date: 1/28/02; HourAhead hour: 5; ...
# Body:
#
# Start Date: 1/28/02; HourAhead hour: 5;  No ancillary schedules awarded.  No variances detected.
#
#     LOG MESSAGES:
#
# PARSING FILE -->> O:\\Portland\\WestDesk\\California Scheduling\\ISO Final Sched...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 31 ---
# Subject: Marketing for you...
# Body: New Page 1 Stable offshore resources to promote your services/products: -  E-mail list  according to your order -  Send emailing according to your order -  Direct Mail Server (Cheap!) -  Offshore web ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 32 ---
# Subject: my students...
# Body: dear vincent ,
# i spoke with my students yesterday and they told me they have thought
# about coming to see you again , and they think it ' ll be much better in
# the future when they are closer to complet...
# True Label: Legitimate
# Source: Enron
#
# --- Email 33 ---
# Subject: REPLY SOON...
# Body: VERY URGENT AND STRICTLY CONFIDENTIAL BUSINESS PROPOSAL.
#
#
# PLEASE I WANT YOU TO RELPY ME THIS MAIL TO MY ALTERNATIVE EMAIL ADDRESSES vinobi@voila.fr and applefamily@indiatimes.com
#
#
# Dear Sir,
#
#
# I am ...
# True Label: Phishing
# Source: Nigerian_Fraud
#
# --- Email 34 ---
# Subject: RE: 2002 Committee Chair announcement.doc...
# Body: Request processed by itrezzoAgent
#
# Attachment 1 of 1
# 2002 Committee Chair announcement.doc (66kb)
# Status: Converted
# Pages: 2
# Words: 612
# 1401 New York Avenue, NW
# 	11th Floor
# 	Washington, DC 20005
# 	202/...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 35 ---
# Subject: AccuWeather.com Alert Forecast...
# Body:
#
#
#
# AccuWeather.com(R) Alert Daily Forecast
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SUNDAY, 06/17/2007 at 11:20 AM
#
#
# Change My Email Options |
# Unsubscribe
#
#
#
#
#
#
# Your 5-Day Weather Forecast
#
#
# BEVERLY HILLS, CA
#
#
# Your Radar ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 36 ---
# Subject: FPL Group Capital Guaranty to Enron...
# Body: I don't recall which one of you were working on this, but this is their redraft.  Please review and respond accordingly. Ed -----Original Message----- From: Elaine_Granger@fpl.com [mailto:Elaine_Grang...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 37 ---
# Subject: US-CERT Technical Cyber Security Alert TA06-081A -- Sendmail Race Condition Vulnerability ...
# Body: -----BEGIN PGP SIGNED MESSAGE----- Hash: SHA1                            National Cyber Alert System                  Technical Cyber Security Alert TA06-081A Sendmail Race Condition Vulnerability    ...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 38 ---
# Subject: [Mhln] We're   OnlinePharmacy, Save up to 80% on your prescription drugs uf...
# Body: Save up to 80% on your prescription drugs!!!
#
# We're  OnlinePharmacy. You can buy prescription drugs WITHOUT PRESCRIPTION or buy online prescription drugs without prescription or buy discount prescr...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 39 ---
# Subject: Re: quadratic equation with interval coefficients...
# Body: Vladik Kreinovich wrote:
# > It is described in the paper E. R. Hansen and G. W. Walster, Sharp bounds on
# > interval polynomial roots, Reliable Computing, 2002, Vol. 8, No. 2, pp.
# > 115-122.
#
#
#
# Thank...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 40 ---
# Subject: Need financial aid for your online education?...
# Body:
#
# 251839499// color   pink/ name   Whooping Cranes status   EN trend   stable image  // WhoopingCrane23.jpg image_width   200px
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       Do you need money for school? Do you ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 41 ---
# Subject: FNC Alert...
# Body: IN SPEECH, JOHN EDWARDS DENOUNCES WAR ON TERROR, CALLING IT A 'BUMPER STICKER' SLOGAN
#
# **Watch FOX News Channel or go to http://foxnews.com for more                                                    ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 42 ---
# Subject: PLEASE I NEED YOUR URGENT ASSISTANCE...
# Body:
#
#
# FREELOTTO INTERNATIONAL
#
# FROM:THE DESK OF THE PROMOTIONS MANAGER,
# INTERNATIONAL PROMOTIONS/PRIZE AWARD DEPARTMENT,
# REF:Ref No:GTR/548923/MPP, BATCH: 14/0017/SPM/IPD
# RE/AWARD NOTIFICATION FINAL ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 43 ---
# Subject: my gratitude...
# Body: dear :
# i would like to express my gratitude to you for giving me an opportunity to
# have an interview with enron . i have to accept that enron provides an
# excellent working environment . i am looking f...
# True Label: Legitimate
# Source: Enron
#
# --- Email 44 ---
# Subject: From Laurence Zavala...
# Body:
#
#
#
#
#  Vi ts si oca t Our Wi dm de Ra apb n gjb ge Of M wo ed lgv ici wns ne And Pi hu l zs ls
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 45 ---
# Subject: FW: Weather Class...
# Body:
#
#  -----Original Message-----
# From: 	Moore, Kevin G.
# Sent:	Tuesday, January 08, 2002 1:27 PM
# To:	Roberts, Mike A.; Kaminski, Vince J; Bennett, Stephen; Shively, Hunter S.; Villarreal, Alex; Rangel, ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 46 ---
# Subject: End the annoying obesity now...
# Body: Anatrim � The very up-to-date and most exciting product for weighty people is now readily available � As were seen on BBC
# Did you know that redundant body kilos kill a lot of people around the world? ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 47 ---
# Subject: [R] legend + expression...
# Body: Dear all; A simple? question. I'm having a problem with a math expression in the legend of a plot and I haven't found the way to get this to work, so any help will be appreciate. Basically I want to i...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 48 ---
# Subject: Penis Enlargement - Truth...
# Body:
# Many surveys have shown that ladies prefer their man to have a huge manhood.
#
# Try it today - you have nothing to lose, just a lot to gain!
#
# http://willpaid.com/
#
#
# ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 49 ---
# Subject: looking around for quick healings ? simply en . ter our zone ....
# Body: what a great convenience . shopping at your site is the best decision i ever
# made right . i   ve never seen such a worth buying items like you do . thank
# you for providing this innovative way to gett ...
# True Label: Phishing
# Source: Enron
#
# --- Email 50 ---
# Subject: Set your wife on fire...
# Body: You will surely appreciate this virility increasing formula!
# Your long-awaited happiness is so near! Grab it now!
# http://milddear.com/
#
#
# scale hit Sumatra in Indonesia, with the epicenter nearto match...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 51 ---
# Subject: A Composite Sketch of a Chief Risk Officer...
# Body: Here is the briefing, titled:  "A Composite Sketch of a Chief Risk Officer", which is the analysis of the benchmarking CRO survey you had participated in back in March, April and May 2001.  <>  Karen ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 52 ---
# Subject: RE: ...
# Body: John -
#
# David Livingston is out today but returns tomorrow.  I left him a message, and will follow up on Wednesday.
#
#
# Jay
#
#  -----Original Message-----
# From: 	Mckay, Jonathan
# Sent:	Tuesday, August 07...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 53 ---
# Subject: Re: upgrading is just like installing...
# Body: On Wed, 2008-02-13 at 04:25 +0800, rceejke@jidanni.org wrote:
# > KB> User? SA is for administrators, not for users. Also, there is *nothing*
# > KB> special about SA version numbers.
#
# > Is too or else th...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 54 ---
# Subject: Re: [R] help with executing instruction every i-th run of loop...
# Body: Mark W Kimpel wrote: > I am running a very long loop and would like to save intermediate  > results in case of a system or program crash. Here is the skeleton of  > what my code would be: >  > for (i ...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 55 ---
# Subject: Sex that hurts - Stretch Till they Squeal!!!...
# Body: All Big Cocks! Monster dicks mercilessly abuse tight tender cunts! Huge black cocks pound squealing white bitches! Big fuckpoles ram into tiny virgins cum-splattered faces! 			  See it all at All Big ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 56 ---
# Subject: FW: Sigma request (CAN Gas Phy Fwd East Spd < or = 1Mo)...
# Body: The product long description below will fall under the new product types: 	CAN Gas Phy Fwd East Spd < or = 1 Mo 	 Credit (Tom Moran/Wendi Lebrocq) have approved copying the profiles for the new produc...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 57 ---
# Subject: Put your great ideas to use...
# Body:
# My "dumb idea" sold over 12 million copies of a single book
# and allowed me to start a world-famous training business.
#
# Now, I want to "take you by the hand" and show you how to
# turn your "dumb ide...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 58 ---
# Subject: Re: pdd15 - How do I add a class method?...
# Body: Hi,
#
# Patrick R. Michaud wrote:
# > My first question is "How do I add a class method?" -- i.e.,
# > a method that operates on a class instance as opposed
# > to an object instance of that class.  Ideally th...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 59 ---
# Subject: Energy Markets Special Subscription Offer...
# Body: Dear Lindy Currier-Donoho,
#
# RESERVE YOUR OWN FREE SUBSCRIPTION TO ENERGY MARKETS:
#
# Each issue contains valuable worldwide coverage of the global integrated energy industry with monthly features and se...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 60 ---
# Subject: linguist / phonetic request for information...
# Body: dear linguist , this is a request for information regarding the kinds of pronunciation that are possible for a person who has no tongue , for the purpose of the editing of a novel set in 11th - 12th -...
# True Label: Legitimate
# Source: Ling
#
# --- Email 61 ---
# Subject: Introduction Regular Expressions are a widely-used method of specifying patterns of text to search f...
# Body:
# []
#
# Fantasy Island Nite was turning out to be not such a bad thing after
# all. And she, of course, assured that there was going to be no funny
# business and that she would become the Countess of Sidc...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 62 ---
# Subject: RE: Surprising   Evaluate your condition breadboard...
# Body: Simply visti our site and let's see if we can make you happy! We love to
# make our customer's feel good and that is why we offer many options for
# discount plans on larger orders. We also have the most ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 63 ---
# Subject: confidence is back...
# Body: hello ,
# my boyfriend began having problems with erections ( he ' s older )
# and i suggested he look into vlagrra softtabs .
# boy , am i glad he did !
# the first time he tried it , one 50 mg piil did noth...
# True Label: Phishing
# Source: Enron
#
# --- Email 64 ---
# Subject: Omaha.com...
# Body: <> Phil, do you know this guy?...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 65 ---
# Subject: Go shopping with someone else's money...
# Body:
#
# 251839499You are receiving this CouponRange e-mail from mainrange.com.  To view this email as a web page, click on this link.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# If you receive...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 66 ---
# Subject: CNN.com Daily Top 10...
# Body: >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= >THE DAILY TOP 10 >from CNN.com >Top videos and stories as of: Aug  1, 2008  3:58 PM EDT >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 67 ---
# Subject: CNN.com Daily Top 10...
# Body: >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= >THE DAILY TOP 10 >from CNN.com >Top videos and stories as of: Aug  1, 2008  3:58 PM EDT >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 68 ---
# Subject: Re: Re: ...
# Body: The cop looked like a big doll that has been badly treated by a gang of nasty children.
# He had half-expected another period of deep depression or rage to follow, but none had.
# As the car roared away, ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 69 ---
# Subject: Re: [CTDB and GFS] some troubles joining domain...
# Body: Ignacio,
#
#  > then I think that tdb is not initialized and tdb-> points nothing:
#
# yep, it looks like there is no secrets_init() in the "net rpc join"
# code paths in this branch.
#
# The obvious fix is this...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 70 ---
# Subject: Your message to Python-3000 awaits moderator approval...
# Body: Your mail to 'Python-3000' with the subject
#
#     Re: [Python-3000] u'text' as an alias for 'text'?
#
# Is being held until the list moderator can review it for approval.
#
# The reason it is being held:
#
#   ...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 71 ---
# Subject: save yourself Ursula...
# Body:
# From guts to glory
# Become eight inc hes in lenght.
#
# http://www.gosafeandnatural.com/ab/ng/
#
# Gilberto Crabtree
# postscript Exports
# williamsburg.
# TEL: 073.5366612
# EMAIL: svfvzw@maktoob.com
#
# ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 72 ---
# Subject: Re: Re: R4 Resistor...
# Body:
#
# "Fred G. Martin" schrieb:
#
# > where is this list that says 2.94K?  please tell me so i can eradicate
# > the incorrect value.
# >
# > to answer, yes, just use it, it affects the IR xmit frequency and
# > not...
# True Label: Legitimate
# Source: TREC_06
#
# --- Email 73 ---
# Subject: interview schedule for seksan kiatsupaibul...
# Body: attached please find the interview packet for the above - referenced person .
# the interview will happen friday , july 7 , 2000 . print all three documents
# for your hard copies . if you have any questi...
# True Label: Legitimate
# Source: Enron
#
# --- Email 74 ---
# Subject: You, your computer and us...
# Body: High Profit margins and earnings in the six figures are yours with our
# automatic marketing system. No need to go into a stuffy office; you can base
# your business from home and have this system working...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 75 ---
# Subject: New Power Products                                                              ...
# Body:
# New Power Products on ICE!!                                                                                                                                                                            ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 76 ---
# Subject: Can't afford medications you need...
# Body: On our behalf, we can advise you one of such pharmacies – CanadianPharmacy. This e-shop is famous for the permanent generic quality of the products offered and the prices that are significantly lower ...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 77 ---
# Subject: revised resp...
# Body: louise :
# i have revised what i sent you earlier per our discussions on friday and have already started working with tom martin on texas gas orig . please let me know when you have spoken with jean abo...
# True Label: Legitimate
# Source: Enron
#
# --- Email 78 ---
# Subject: Investor's Insight...
# Body: ROCKET STOCKS NEWSLETTER
#
# U R G E N T   I N V E S T O R   A L E R T
#
# VNBL STOCK EXPECTED TO EXPLODE!!!
#
# Vinoble is the next HOT PLAY in Homeland Security
#
# Symbol: VNBL.OB
# Current Price:      	    		...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 79 ---
# Subject: [UAI] EAAI'06 CFP...
# Body: Apologies for multiple copies.
# ----------------------------------------------------------------------
# 		   First International Workshop on
#        Emerging Applications of Abstract Interpretation (EAAI...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 80 ---
# Subject: Job Well Done...
# Body: I wanted to recognize the employees at TAP and in Tracy Ramsey's organization for a job well done during the events of September 11th.
#
# TAP was instrumental in helping us determine which ENW employe...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 81 ---
# Subject: ena balance sheet assets / responsibilities...
# Body: here is the worksheet ....
# True Label: Legitimate
# Source: Enron
#
# --- Email 82 ---
# Subject: you launched a website but no one visits it ?...
# Body: submitting your website in search engines may increase
# your online sales dramatically .
# if you invested time and money into your website , you
# simply must submit your website
# oniine otherwise it wiii ...
# True Label: Phishing
# Source: Enron
#
# --- Email 83 ---
# Subject: [Ip-health] Associated Press: Brazil Says May Break AIDS Drug Patent...
# Body: http://www.forbes.com/feeds/ap/2007/04/25/ap3653230.html
#
# Associated Press
# Brazil Says May Break AIDS Drug Patent
# By VIVIAN SEQUERA 04.25.07, 6:42 PM ET
#
# Brazil said Wednesday it would buy an Indian-m...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 84 ---
# Subject: New TopCoder(R) Studio contest posted...
# Body: Hello sm1lies,
#
# A new TopCoder Studio contest is here.  The TopCoder Dashboard Wireframe Design Contest begins at 2:00 PM Eastern Daylight Time (UTC/GMT -4) on Tuesday, April 24, 2007.  The submission...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 85 ---
# Subject: producttestpanel@speedy.uwaterloo.ca, Fly Anywhere on Southwest Airlines on Us...
# Body:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Forget what your travel agent says the best airfare rate is right here Forget what your travel agent says the best airfare rate is right here Forget what your travel agent say...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 86 ---
# Subject: Buy  medications in Canada and lower your medication expenses....
# Body:
# There are many drugstores  which offer medical products  online, choose the most reliable one to be safe from fakes and scamming. Canadian Pharmacy online drugstore will answer all your needs.
#
# http...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 87 ---
# Subject: Integral transforms...
# Body:                      Only we offer:  All popular drugs are available  World Wide Shipping  No Doctor Visits  No Prescriptions  100% Customer Satisfaction  Cheapest PriceClick to find out about more sp...
# True Label: Phishing
# Source: TREC_07
#
# --- Email 88 ---
# Subject: failure notice...
# Body: hi . this is the qmail - send program at bouncehost .
# i ' m afraid i wasn ' t able to deliver your message to the following addresses .
# this is a permanent error ; i ' ve given up . sorry it didn ' t ...
# True Label: Phishing
# Source: Enron
#
# --- Email 89 ---
# Subject: Invest0rs watch this One starting right nOw...
# Body: Secured Data Inc. (SCRE)
# Emerging Leader In Chinese Export of Pharmaceuticals!
# Tota| Shares Issued & Outstanding: 90,O00,O00 EST
# Current Price: 0.09
# 2004 Success lead into an exciting 2005.
#
# Secured ...
# True Label: Phishing
# Source: TREC_05
#
# --- Email 90 ---
# Subject: [Ip-health] Ask your Senators to vote "YES" on the Medicare Prescription Drug Price Negotiation Act...
# Body: Forwarding FYI, an urgent action item from Families USA.
#
# Joana Ramos, MSW
# Cancer Resources & Advocacy
# Seattle WA USA
# Tel. +1-206-229-2420
# http://ramoslink.info/
# www.cancersurvivorsproject.org
# www.hea...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 91 ---
# Subject: Tried vacuum pumps and other advertised methods without success ?...
# Body:
#
#
#
#
#
#
#   Satisfy your lover like never before !
#  The best way to  enlarge  your size is the safest one with permanent results. Such method is VPXL pills. Pills is medically approved and 100% safe.
#  ...
# True Label: Phishing
# Source: CEAS_08
#
# --- Email 92 ---
# Subject: fifty dollars for office xp hannibal...
# Body: microsoft software at superb prices : but how ? oem software comes to you without all the bells and whistles . you don ' t get the fancy packaging or a manual . instead , you receive just a cd with yo...
# True Label: Phishing
# Source: Enron
#
# --- Email 93 ---
# Subject: Re: [ILUG] slashdot EW Dijkstra humor...
# Body: On Thu, Aug 08, 2002 at 12:14:09 +0100, Matthew French wrote:
# > JPL suggested:
# > >  Recursion is only truely useful if you have an infinite stack. People
# > > that think they have an infinite stack sho...
# True Label: Legitimate
# Source: SpamAssasin
#
# --- Email 94 ---
# Subject: Post BR petiition scheduling by East Wholesale Power ...
# Body: Following up on Elizabeth Sager's conversation with you Corry as to terminated wholesale power contracts and related matters, and based also on EPMI's obligation to preserve assets for the bankruptcy ...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 95 ---
# Subject: [R] Subsetting list of vectors with list of (boolean) vectors?...
# Body: Dear Rologists, I'm stuck with this. How would you do this efficiently: > aPGI [[1]] [1] "864"  "5576" > aPGItest [[1]] [1]  TRUE FALSE > result <- [magic box involving subset) > result [[1]] [1] "864...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 96 ---
# Subject: Re: Suggestions to block this spam...
# Body: On Tue, 19 Feb 2008 14:21:53 -0800
# "Bazooka Joe"  wrote:
#
# > I too am getting dozens of these emails that are going right through
# > SA + pyzor + dcc.  sa-learn doesn't seem to make any difference.  I
# >...
# True Label: Legitimate
# Source: CEAS_08
#
# --- Email 97 ---
# Subject: Re: [R] plot log scale, axis original scale...
# Body: Dean Sonneborn wrote: > I want to produce some boxplots and plot the logged values but have the  > axis scale in the original, not-logged scale. It seeming like I have the  > first few steps but I'm h...
# True Label: Legitimate
# Source: TREC_07
#
# --- Email 98 ---
# Subject: Private Equity...
# Body: Hello Robert,
# Hello Sara,
#
# The purpose of this e-mail is to supplement my voice mail messages this morning.  I know a lot is going on and that the legal team must be all hands on deck.  Having said th...
# True Label: Legitimate
# Source: TREC_05
#
# --- Email 99 ---
# Subject: spot or firm tickets...
# Body: vance ,
# the following nominations do not have deal tickets in sitara for september ,
# 2000 activity . please advise whether the deals will be spot or firm . daren
# wants everything in sitara by 3 pm on ...
# True Label: Legitimate
# Source: Enron
#
# --- Email 100 ---
# Subject: [R] RODBC and Date/Time variables...
# Body:
# This is really a query about MySQL which I am trying to use to set up a
# database which I will then access with RODBC.
#
# I have my data in a .csv file, and some of the fields are date/time
# fields. I ...
# True Label: Legitimate
# Source: TREC_07

# %%
# see src/api_provider to add more providers
PROVIDER = "local"
MODEL = "qwen3-30b-a3b"

try:
    llm_instance = LLM(provider=PROVIDER, model=MODEL)
    llm = llm_instance.get_llm()
    print(f"LLM initialized successfully: {PROVIDER} - {MODEL}")
except Exception as e:
    print(f"Error initializing LLM: {e}")
    print("Please make sure you have set the appropriate API key environment variable.")
# Out:
# LLM initialized successfully: local - qwen3-30b-a3b

# %%
# Define the system prompt for phishing detection
SYSTEM_PROMPT = """
You are an expert cybersecurity analyst specializing in phishing email detection.
Your task is to analyze email content and determine if it's a phishing email or legitimate.

Guidelines:
- Phishing emails typically contain deceptive content designed to steal credentials, personal information, or money
- Look for suspicious indicators like urgent language, suspicious links, grammatical errors, impersonation attempts
- Legitimate emails are from real organizations and don't attempt to deceive recipients

Respond with:
- Phishing: true if the email is phishing, false if legitimate
- Reason: Brief explanation of your decision
"""

def create_user_prompt(subject, body):
    return f"""
Please analyze the following email and determine if it's phishing or legitimate:

Subject: {subject}

Body: {body}

Analyze this email and provide your assessment.
"""

print("Prompt templates defined successfully!")
# Out:
# Prompt templates defined successfully!

# %%
# Evaluate LLM performance on sample emails
results = []

for i, row in sample_df.iterrows():
    print("="*80)
    print(f"\nEvaluating Email {i+1}...")
    
    # Create user prompt
    user_prompt = create_user_prompt(row['subject'], row['body'])
    
    try:
        # Make API call
        response = make_api_call(llm, SYSTEM_PROMPT, user_prompt)
        
        # Extract prediction
        predicted_phishing = response.Phishing
        predicted_label = 1 if predicted_phishing else 0
        actual_label = row['label']
        
        # Calculate if prediction is correct
        is_correct = predicted_label == actual_label
        
        result = {
            'email_id': i+1,
            'subject': row['subject'][:50] + '...',
            'actual_label': actual_label,
            'actual_class': 'Phishing' if actual_label == 1 else 'Legitimate',
            'predicted_label': predicted_label,
            'predicted_class': 'Phishing' if predicted_label == 1 else 'Legitimate',
            'is_correct': is_correct,
            'llm_reason': response.Reason,
            'source': row['source']
        }
        
        results.append(result)
        
        print(f"  Actual: {result['actual_class']}")
        print(f"  Predicted: {result['predicted_class']}")
        print(f"  Correct: {is_correct}")
        print(f"  Reason: {response.Reason[:100]}...")
        
    except Exception as e:
        print(f"  Error processing email {i+1}: {e}")
        result = {
            'email_id': i+1,
            'subject': row['subject'][:50] + '...',
            'actual_label': row['label'],
            'actual_class': 'Phishing' if row['label'] == 1 else 'Legitimate',
            'predicted_label': None,
            'predicted_class': 'Error',
            'is_correct': False,
            'llm_reason': f'Error: {str(e)}',
            'source': row['source']
        }
        results.append(result)

print("\nEvaluation completed")
# Out:
# ================================================================================
#
# Evaluating Email 1...
# Phishing=False Reason='The email appears to be a legitimate academic book listing from Cambridge University Press, providing detailed information about various books on cognitive linguistics. It contains no suspicious links, urgent requests, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate academic book listing from Cambridge University Press, providin...
# ================================================================================
#
# Evaluating Email 2...
# Phishing=False Reason='The email appears to be a legitimate business communication from Powerisk 2000 event organizers. It contains standard corporate formatting, proper contact information, and the subject line mentions an important invitation with high priority. The content is about event invitations and there are no obvious signs of phishing such as suspicious links or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication from Powerisk 2000 event organizers. It ...
# ================================================================================
#
# Evaluating Email 3...
# Phishing=False Reason='The email appears to be a legitimate technical discussion about hardware components (AC adaptor voltage and L1 inductor) related to a HandyBoard project. The content is specific, non-urgent, and does not contain suspicious links or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate technical discussion about hardware components (AC adaptor volt...
# ================================================================================
#
# Evaluating Email 4...
# Phishing=False Reason='The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link is also present, which is typical for newsletters.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains s...
# ================================================================================
#
# Evaluating Email 5...
# Phishing=False Reason="The email appears to be a legitimate notification about a report. It mentions a specific date (10/18/2001) and refers to a report named 'Violation/Notification Memo'. The content is straightforward and does not contain any suspicious elements like urgent requests for personal information or malicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate notification about a report. It mentions a specific date (10/18...
# ================================================================================
#
# Evaluating Email 6...
# Phishing=False Reason='The email appears to be a legitimate internal communication regarding a meeting about the NOx model. It includes specific details like date, time, location, and recipients. The link provided is to a USGS (United States Geological Survey) page, which is a reputable organization.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication regarding a meeting about the NOx model....
# ================================================================================
#
# Evaluating Email 7...
# Phishing=False Reason='The email appears to be a legitimate reminder for an officers meeting organized by Eta Kappa Nu, a recognized academic honor society. It contains specific details about the agenda, dates, times, and contact information. There are no suspicious links or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate reminder for an officers meeting organized by Eta Kappa Nu, a r...
# ================================================================================
#
# Evaluating Email 8...
# Phishing=True Reason="The email contains explicit adult content with suggestive titles and a suspicious link. It's likely a phishing attempt to lure users into clicking on malicious links or downloading inappropriate material."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit adult content with suggestive titles and a suspicious link. It's likely ...
# ================================================================================
#
# Evaluating Email 9...
# Phishing=False Reason="The email appears to be a legitimate internal business communication regarding a project or deal (158220) needing $10,000 for day 1. It references specific details like the sender's name (Tina Valadez), dates, and an organization (LCRA). The content is professional and lacks typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive language."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding a project or deal (15...
# ================================================================================
#
# Evaluating Email 10...
# Phishing=False Reason="The email appears to be a legitimate promotional message from AutoSport Catalog. It contains standard marketing language, a clear call to action with a link, and contact information. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links. The domain name is consistent with the company's website."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate promotional message from AutoSport Catalog. It contains standar...
# ================================================================================
#
# Evaluating Email 11...
# Phishing=False Reason='The email appears to be a legitimate communication between two individuals discussing a lunch meeting. It contains personal details, references previous interactions, and does not include any suspicious links or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate communication between two individuals discussing a lunch meetin...
# ================================================================================
#
# Evaluating Email 12...
# Phishing=False Reason="The email appears to be a legitimate newsletter from CoachInvest, providing updates on their services, investments, and events. It contains contact information, links to their website, and details about various companies they've invested in. The presence of an unsubscribe link and the structure of the content suggest it's a standard business communication rather than a phishing attempt."
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate newsletter from CoachInvest, providing updates on their service...
# ================================================================================
#
# Evaluating Email 13...
# Phishing=True Reason='The email contains explicit and inappropriate content promoting a male enhancement product with exaggerated claims. It includes suspicious links and lacks any legitimate context or sender information.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit and inappropriate content promoting a male enhancement product with exag...
# ================================================================================
#
# Evaluating Email 14...
# Phishing=False Reason="The email appears to be a legitimate promotional message from Amazon.com. It contains specific product details, a valid link to the product page, and an opt-out option. The language is professional and consistent with Amazon's communication style."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate promotional message from Amazon.com. It contains specific produ...
# ================================================================================
#
# Evaluating Email 15...
# Phishing=False Reason='The email appears to be a legitimate business communication with a specific subject line, contact information, and a reference to deals. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication with a specific subject line, contact in...
# ================================================================================
#
# Evaluating Email 16...
# Phishing=False Reason="The email appears to be a legitimate message from a Match.com user named Tracy. It contains personal details and asks for information, which is common in dating profiles. The tips provided about remaining anonymous on Match.com are relevant and match the platform's guidelines. There are no suspicious links or requests for sensitive information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate message from a Match.com user named Tracy. It contains personal...
# ================================================================================
#
# Evaluating Email 17...
# Phishing=True Reason='The email contains suspicious elements such as a generic greeting, offers for targeted email lists which may be used for spamming, and includes suspicious contact information. The subject line is vague and the content appears to be promoting unsolicited advertising.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as a generic greeting, offers for targeted email lists w...
# ================================================================================
#
# Evaluating Email 18...
# Phishing=True Reason="The email contains suspicious links, urgent language about health issues, and claims of being verified by BBB and VISA which are not legitimate. The URL is also a random string, indicating it's likely a phishing attempt."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, urgent language about health issues, and claims of being verifi...
# ================================================================================
#
# Evaluating Email 19...
# Phishing=False Reason='The email appears to be a legitimate internal business communication discussing financial reporting and scheduling. It contains specific details about financial calculations, asset allocation, and meeting agendas. The language is professional, and there are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication discussing financial reporting ...
# ================================================================================
#
# Evaluating Email 20...
# Phishing=True Reason="The email is a classic 'Nigerian prince' scam. It contains urgent requests for personal information, promises of large sums of money in exchange for fees or account details, and uses suspicious contact methods. The sender's identity is unverifiable, and the story is implausible."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email is a classic 'Nigerian prince' scam. It contains urgent requests for personal information,...
# ================================================================================
#
# Evaluating Email 21...
# Phishing=False Reason='The email appears to be a legitimate business communication between employees of Enron and the California Independent System Operator (CAISO) regarding changes in power delivery agreements. It contains specific details about contracts, dates, and internal communications, which are typical in professional correspondence.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication between employees of Enron and the Calif...
# ================================================================================
#
# Evaluating Email 22...
# Phishing=False Reason='The email appears to be a technical discussion about updating GNOME versions and repository configurations. It contains no suspicious links, urgent requests, or attempts to steal information. The content is related to Linux package management and is likely from a legitimate user or community forum.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about updating GNOME versions and repository configur...
# ================================================================================
#
# Evaluating Email 23...
# Phishing=False Reason="The email appears to be a legitimate news summary from CBS News, containing standard content like headlines and an unsubscribe link. There's no suspicious request for personal information or urgent action."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate news summary from CBS News, containing standard content like he...
# ================================================================================
#
# Evaluating Email 24...
# Phishing=False Reason='The email is a straightforward question about UV sensors, lacks any suspicious links or requests for sensitive information, and appears to be from an individual seeking technical assistance.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a straightforward question about UV sensors, lacks any suspicious links or requests for...
# ================================================================================
#
# Evaluating Email 25...
# Phishing=True Reason='The email contains suspicious links, urgent language, and fake testimonials. It promotes a questionable product with exaggerated claims and uses a non-credible source (Oprah) to gain trust.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, urgent language, and fake testimonials. It promotes a questiona...
# ================================================================================
#
# Evaluating Email 26...
# Phishing=False Reason='The email appears to be a technical discussion between colleagues about code implementation. It contains no suspicious links, urgent requests, or deceptive content typical of phishing emails.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion between colleagues about code implementation. It cont...
# ================================================================================
#
# Evaluating Email 27...
# Phishing=True Reason='The email promotes a dubious product with exaggerated claims of rapid physical enhancement, which is a common tactic in phishing scams to lure users into clicking malicious links. The URL provided appears suspicious and unrelated to legitimate healthcare products.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email promotes a dubious product with exaggerated claims of rapid physical enhancement, which is...
# ================================================================================
#
# Evaluating Email 28...
# Phishing=True Reason='The email contains suspicious content with no clear context, a nonsensical subject line, and an unclear request to read a document. These are common indicators of phishing attempts.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content with no clear context, a nonsensical subject line, and an uncl...
# ================================================================================
#
# Evaluating Email 29...
# Phishing=False Reason='The email appears to be a legitimate request for holiday gift contributions from a team member. It includes specific details about the recipients (Brenda, Maria, McKenzie), mentions contribution guidelines based on position and tenure, and requests funds by a deadline. The tone is professional and the content does not contain typical phishing indicators like urgent demands for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate request for holiday gift contributions from a team member. It i...
# ================================================================================
#
# Evaluating Email 30...
# Phishing=False Reason="The email appears to be a system-generated message related to scheduling data processing, containing technical terms and file paths typical of internal organizational communications. There's no deceptive content or request for sensitive information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a system-generated message related to scheduling data processing, containing...
# ================================================================================
#
# Evaluating Email 31...
# Phishing=True Reason='The email contains suspicious elements such as a generic subject line, offers of questionable services (offshore resources), and an unprofessional sender address. The presence of multiple email addresses in the body and the lack of specific details about the company or service make it highly likely to be a phishing attempt.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as a generic subject line, offers of questionable servic...
# ================================================================================
#
# Evaluating Email 32...
# Phishing=False Reason="The email appears to be a legitimate communication between individuals discussing students' potential interest in Enron. It contains no suspicious links, urgent requests for personal information, or deceptive language."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate communication between individuals discussing students' potentia...
# ================================================================================
#
# Evaluating Email 33...
# Phishing=True Reason="The email is a classic 'Nigerian prince' scam, which is a common phishing tactic. It contains urgent requests, asks for personal contact information, and offers a large sum of money in exchange for assistance. The sender's claims are implausible, and the request to reply through specific alternative emails is suspicious."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email is a classic 'Nigerian prince' scam, which is a common phishing tactic. It contains urgent...
# ================================================================================
#
# Evaluating Email 34...
# Phishing=False Reason='The email appears to be a legitimate internal memorandum from EPSA (Electric Power Supply Association) regarding committee chair announcements. It contains specific details about the organization, dates, and individuals involved. The content is formal and structured like an official communication. There are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or grammatical errors.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal memorandum from EPSA (Electric Power Supply Associatio...
# ================================================================================
#
# Evaluating Email 35...
# Phishing=False Reason='The email appears to be a legitimate weather forecast from AccuWeather.com. It contains standard weather information, subscription details, and contact information. There are no suspicious links or requests for personal information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate weather forecast from AccuWeather.com. It contains standard wea...
# ================================================================================
#
# Evaluating Email 36...
# Phishing=False Reason='The email appears to be a legitimate internal business communication regarding a legal document. It references specific details like the subject line, attached files, and includes contact information. The content is professional and does not contain typical phishing indicators such as urgent requests for personal information or suspicious links.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding a legal document. It ...
# ================================================================================
#
# Evaluating Email 37...
# Phishing=False Reason='The email is a legitimate technical security alert from US-CERT regarding a Sendmail vulnerability. It contains detailed information about the vulnerability, affected versions, solution steps, and references to official sources. The content is formal, structured, and aligns with known cybersecurity advisories.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate technical security alert from US-CERT regarding a Sendmail vulnerability. ...
# ================================================================================
#
# Evaluating Email 38...
# Phishing=True Reason="The email contains multiple suspicious elements: urgent language ('Save up to 80%'), requests to click on links from unknown domains (http://kdcnq.movingthan.com, http://kxgt.movingthan.com), and the subject line has inconsistent spacing. The content also promotes buying prescription drugs without a prescription, which is illegal and highly suspicious."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: urgent language ('Save up to 80%'), requests to cli...
# ================================================================================
#
# Evaluating Email 39...
# Phishing=False Reason="The email appears to be a legitimate academic discussion about interval polynomial roots, referencing a specific paper and including a name (Vladik Kreinovich) that could be a real researcher. There's no suspicious content like urgent requests, links, or personal information demands."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate academic discussion about interval polynomial roots, referencin...
# ================================================================================
#
# Evaluating Email 40...
# Phishing=True Reason='The email contains suspicious elements such as a generic subject line, lack of personalization, and an urgent call to action. The link provided (OnlineStudentFinancialAid.com) is not from a legitimate financial aid organization and may be a phishing site designed to steal personal information.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as a generic subject line, lack of personalization, and ...
# ================================================================================
#
# Evaluating Email 41...
# Phishing=False Reason="The email appears to be a legitimate news alert from FOX News. It contains standard unsubscribe information, proper copyright details, and a link to their official website. There's no suspicious request for personal information or urgent action."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate news alert from FOX News. It contains standard unsubscribe info...
# ================================================================================
#
# Evaluating Email 42...
# Phishing=True Reason="The email contains multiple red flags: urgent request to contact a specific individual, suspicious links (though not present here), grammatical errors, and requests for personal information. The sender's legitimacy is questionable as it claims to be from a non-existent organization with a fabricated reference number. The email also asks for sensitive details like full names, addresses, and phone numbers, which is typical of phishing attempts."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple red flags: urgent request to contact a specific individual, suspicious l...
# ================================================================================
#
# Evaluating Email 43...
# Phishing=True Reason="The email contains several suspicious elements: 1) The subject line is generic and lacks specificity. 2) The body has grammatical errors and awkward phrasing (e.g., 'i would like to express my gratitude' instead of 'I would like to express...'). 3) The sender's name is unusual ('seksan') and the email appears to be from an unknown source. 4) There is no clear indication of a legitimate organization or contact information. 5) The request for further action without proper verification is typical of phishing attempts."
#   Actual: Legitimate
#   Predicted: Phishing
#   Correct: False
#   Reason: The email contains several suspicious elements: 1) The subject line is generic and lacks specificity...
# ================================================================================
#
# Evaluating Email 44...
# Phishing=True Reason='The email contains nonsensical text with no coherent message, which is a common characteristic of phishing attempts. The subject line is generic and the body appears to be random characters or garbled text, likely intended to confuse or trick the recipient.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains nonsensical text with no coherent message, which is a common characteristic of ph...
# ================================================================================
#
# Evaluating Email 45...
# Phishing=False Reason="The email appears to be a legitimate internal communication about a weather class event. It includes specific details like the date, time, location, and speaker. The tone is professional, and there's no suspicious content or requests for sensitive information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal communication about a weather class event. It includes...
# ================================================================================
#
# Evaluating Email 46...
# Phishing=True Reason='The email contains suspicious content promoting a product called Anatrim for weight loss, with exaggerated claims and fake testimonials. The subject line is misleading and the body has poor grammar and formatting issues.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content promoting a product called Anatrim for weight loss, with exagg...
# ================================================================================
#
# Evaluating Email 47...
# Phishing=False Reason="The email is a legitimate request for help with R programming related to plotting and legends. It contains technical details about R-squared values and code snippets, indicating it's from someone seeking assistance on a specific coding problem."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate request for help with R programming related to plotting and legends. It co...
# ================================================================================
#
# Evaluating Email 48...
# Phishing=True Reason='The email contains explicit content related to penis enlargement, which is a common tactic in phishing scams to lure recipients. The message uses manipulative language and includes a suspicious link.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit content related to penis enlargement, which is a common tactic in phishi...
# ================================================================================
#
# Evaluating Email 49...
# Phishing=True Reason='The email contains multiple suspicious elements: fragmented text with grammatical errors, a suspicious link (http://7.biym.ourtruenature.com/8tl/), and offers that seem too good to be true. The content appears to be a mix of random phrases and may be attempting to deceive the recipient into clicking on a malicious link or providing personal information.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements: fragmented text with grammatical errors, a suspicio...
# ================================================================================
#
# Evaluating Email 50...
# Phishing=True Reason="The subject line is highly inappropriate and offensive. The body contains nonsensical content with a suspicious link. There's no legitimate context or organization mentioned."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The subject line is highly inappropriate and offensive. The body contains nonsensical content with a...
# ================================================================================
#
# Evaluating Email 51...
# Phishing=False Reason='The email appears to be from a legitimate organization, The Conference Board of Canada, with proper contact information and a specific reference to a survey the recipient participated in. There are no suspicious links or urgent requests for personal information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be from a legitimate organization, The Conference Board of Canada, with proper ...
# ================================================================================
#
# Evaluating Email 52...
# Phishing=False Reason='The email appears to be a legitimate internal business communication. It contains standard corporate language, references specific individuals and companies, and discusses routine business matters like credit sheets and trading terms. There are no suspicious links, urgent requests for personal information, or deceptive content typical of phishing attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication. It contains standard corporate...
# ================================================================================
#
# Evaluating Email 53...
# Phishing=False Reason='The email appears to be a technical discussion about software installation and configuration. It references specific technical terms and code snippets, which are consistent with legitimate system administration or developer communication. There is no indication of phishing attempts such as requests for sensitive information, suspicious links, or urgent actions.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about software installation and configuration. It ref...
# ================================================================================
#
# Evaluating Email 54...
# Phishing=False Reason='The email is a technical discussion about R programming language loops. It contains no suspicious links, urgent requests, or personal information theft attempts. The content is related to coding practices and debugging, which is typical for a legitimate technical support or community forum message.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about R programming language loops. It contains no suspicious li...
# ================================================================================
#
# Evaluating Email 55...
# Phishing=True Reason="The email contains explicit, offensive, and inappropriate content promoting adult material. It uses sensationalist language and includes a link to a questionable website. The request to 'remove me of this list' is suspicious and may be a tactic to trick the recipient into clicking on a malicious link or providing personal information."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit, offensive, and inappropriate content promoting adult material. It uses ...
# ================================================================================
#
# Evaluating Email 56...
# Phishing=False Reason='The email appears to be a legitimate internal business communication regarding product types and sigma factors in the context of gas transactions. It contains specific technical details about energy contracts, references to real names and dates, and seems to be part of an ongoing professional discussion.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding product types and sig...
# ================================================================================
#
# Evaluating Email 57...
# Phishing=True Reason="The email contains suspicious links with non-credible domains (web.deberanebergallhosts.com), urgent language about turning ideas into fortune, and requests to click on links. The sender's information is not from a legitimate organization."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links with non-credible domains (web.deberanebergallhosts.com), urgent...
# ================================================================================
#
# Evaluating Email 58...
# Phishing=False Reason="The email appears to be a legitimate technical discussion about programming, specifically regarding adding class methods in a language like Perl 6 or Parrot. It's a follow-up to a question and contains no suspicious elements such as urgent requests, links, or personal information theft attempts."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate technical discussion about programming, specifically regarding ...
# ================================================================================
#
# Evaluating Email 59...
# Phishing=False Reason='The email appears to be a legitimate subscription offer for an energy industry magazine. It provides clear information about the content, includes proper links, and has a standard opt-out mechanism. The language is professional and not coercive.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate subscription offer for an energy industry magazine. It provides...
# ================================================================================
#
# Evaluating Email 60...
# Phishing=False Reason='The email is a legitimate request from an individual seeking linguistic information about pronunciation without a tongue. It contains specific details about the context, asks for help with a novel, and provides a clear contact address. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing emails.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate request from an individual seeking linguistic information about pronunciat...
# ================================================================================
#
# Evaluating Email 61...
# Phishing=False Reason="The email contains random, unrelated text fragments that don't form a coherent message. There's no clear attempt to deceive or steal information. The content appears to be nonsensical or possibly generated by an AI without a specific purpose."
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email contains random, unrelated text fragments that don't form a coherent message. There's no c...
# ================================================================================
#
# Evaluating Email 62...
# Phishing=True Reason='The email contains suspicious links, grammatical errors, and irrelevant content. It also includes a list of luxury brands which is typical of phishing attempts to lure users into clicking malicious links.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, grammatical errors, and irrelevant content. It also includes a ...
# ================================================================================
#
# Evaluating Email 63...
# Phishing=True Reason='The email contains explicit content, suspicious links, and is likely a scam attempting to promote a product through deceptive means.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains explicit content, suspicious links, and is likely a scam attempting to promote a ...
# ================================================================================
#
# Evaluating Email 64...
# Phishing=True Reason="The email is extremely brief and lacks any context or details. The subject line 'Omaha.com' could be a phishing attempt to impersonate a legitimate source. The body message 'Phil, do you know this guy?' is suspicious and does not provide any clear information or purpose."
#   Actual: Legitimate
#   Predicted: Phishing
#   Correct: False
#   Reason: The email is extremely brief and lacks any context or details. The subject line 'Omaha.com' could be...
# ================================================================================
#
# Evaluating Email 65...
# Phishing=True Reason='The email contains suspicious elements such as a generic subject line, unclear sender information, and multiple suspicious links. The message appears to be attempting to deceive the recipient into clicking on potentially malicious links.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious elements such as a generic subject line, unclear sender information, a...
# ================================================================================
#
# Evaluating Email 66...
# Phishing=False Reason='The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link and privacy policy are also present.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains s...
# ================================================================================
#
# Evaluating Email 67...
# Phishing=False Reason='The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link is also present, which is typical for newsletters.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains s...
# ================================================================================
#
# Evaluating Email 68...
# Phishing=False Reason='The email appears to be a fragment of a story or narrative, not a legitimate communication from an organization. It lacks any typical phishing elements like urgent requests, suspicious links, or personal information prompts.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a fragment of a story or narrative, not a legitimate communication from an o...
# ================================================================================
#
# Evaluating Email 69...
# Phishing=False Reason='The email appears to be a technical discussion about code changes in a software project. It contains specific programming details and references to code repositories, which are typical of legitimate developer communications.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about code changes in a software project. It contains...
# ================================================================================
#
# Evaluating Email 70...
# Phishing=False Reason="The email appears to be a legitimate notification from the Python-3000 mailing list moderator. It explains that a message was held for review due to being sent by a non-member to a members-only list and provides a specific URL for cancellation. The language is formal, the content is about a standard moderation process, and there's no urgent request for personal information or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate notification from the Python-3000 mailing list moderator. It ex...
# ================================================================================
#
# Evaluating Email 71...
# Phishing=True Reason="The email contains suspicious links, grammatical errors, and an unclear subject line. The URL appears to be a fake domain. The sender's information is also not credible."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, grammatical errors, and an unclear subject line. The URL appear...
# ================================================================================
#
# Evaluating Email 72...
# Phishing=False Reason='The email appears to be a technical discussion about resistor values in a circuit, likely between colleagues or experts. It contains no suspicious links, urgent requests for personal information, or deceptive content. The subject line and body are related to engineering specifications, which is consistent with a legitimate professional communication.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a technical discussion about resistor values in a circuit, likely between co...
# ================================================================================
#
# Evaluating Email 73...
# Phishing=True Reason="The email contains multiple red flags: the subject line has a name that seems suspiciously formatted (seksan kiatsupaibul), the date is 2000 which is over two decades ago, the request to print documents for 'hard copies' is unusual, and there's no official company information or contact details. The email appears to be attempting to deceive the recipient with outdated information and unclear context."
#   Actual: Legitimate
#   Predicted: Phishing
#   Correct: False
#   Reason: The email contains multiple red flags: the subject line has a name that seems suspiciously formatted...
# ================================================================================
#
# Evaluating Email 74...
# Phishing=True Reason='The email promotes a get-rich-quick scheme with unrealistic income claims (e.g., $100k/year), uses urgent language, contains suspicious links, and has poor grammar. The content resembles typical phishing tactics aimed at tricking recipients into clicking malicious links or providing personal information.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email promotes a get-rich-quick scheme with unrealistic income claims (e.g., $100k/year), uses u...
# ================================================================================
#
# Evaluating Email 75...
# Phishing=False Reason='The email appears to be a legitimate notification from IntercontinentalExchange (ICE) regarding the launch of new power products. It provides specific details about market launches, portfolio adjustments, credit settings, and contact information for assistance.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate notification from IntercontinentalExchange (ICE) regarding the ...
# ================================================================================
#
# Evaluating Email 76...
# Phishing=True Reason='The email contains suspicious links, urgent language, and promotes a questionable pharmacy. The URL is not from a legitimate source and the content is designed to deceive the recipient into making a purchase.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, urgent language, and promotes a questionable pharmacy. The URL ...
# ================================================================================
#
# Evaluating Email 77...
# Phishing=False Reason='The email appears to be a legitimate business communication between individuals discussing work-related tasks. It lacks typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive language.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication between individuals discussing work-rela...
# ================================================================================
#
# Evaluating Email 78...
# Phishing=True Reason='The email contains multiple red flags such as urgent language, speculative stock price targets, grammatical errors (e.g., $O.50 instead of $0.50), and a disclaimer that appears to be a paid advertisement. The content seems to be promoting a micro-cap stock with high risk, which is typical of phishing or scam emails.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple red flags such as urgent language, speculative stock price targets, gram...
# ================================================================================
#
# Evaluating Email 79...
# Phishing=False Reason='The email appears to be a legitimate call for papers for an academic workshop. It contains specific details about the event, such as dates, location, topics, important dates, program committee members, submission guidelines, and organizers. The content is formal and professional, typical of academic communications. There are no suspicious links, urgent requests for personal information, or other common phishing indicators.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate call for papers for an academic workshop. It contains specific ...
# ================================================================================
#
# Evaluating Email 80...
# Phishing=False Reason="The email appears to be a genuine acknowledgment of employees' efforts during the September 11th events. It contains specific details about TAP's role and Tracy Ramsey's actions, which suggests it's from a real person or organization. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing emails."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a genuine acknowledgment of employees' efforts during the September 11th eve...
# ================================================================================
#
# Evaluating Email 81...
# Phishing=False Reason='The email is extremely brief, lacks specific details, and appears to be a placeholder or draft. It does not contain any suspicious elements like urgent requests, links, or personal information requests.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is extremely brief, lacks specific details, and appears to be a placeholder or draft. It d...
# ================================================================================
#
# Evaluating Email 82...
# Phishing=True Reason="The email contains numerous spelling and grammatical errors, such as 'oniine' instead of 'online', 'wiii be' instead of 'will be', and 'virtuaiiy' instead of 'virtually'. It also uses urgent language to prompt immediate action, which is a common phishing tactic. Additionally, the sender's name appears to be fabricated ('aiiegravincent') and there are suspicious characters in the email body."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains numerous spelling and grammatical errors, such as 'oniine' instead of 'online', '...
# ================================================================================
#
# Evaluating Email 83...
# Phishing=False Reason="The email appears to be a legitimate news article from Associated Press about Brazil's potential action regarding an AIDS drug patent. It includes a link to the original source (Forbes) and contact information for the sender. There are no suspicious elements such as urgent requests for personal information or deceptive links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate news article from Associated Press about Brazil's potential act...
# ================================================================================
#
# Evaluating Email 84...
# Phishing=False Reason="The email appears to be from a legitimate source, TopCoder Studio Team. It provides specific contest details, dates, and a link to the official website. The language is professional and there's no urgent request for personal information or suspicious links."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be from a legitimate source, TopCoder Studio Team. It provides specific contest...
# ================================================================================
#
# Evaluating Email 85...
# Phishing=True Reason="The email contains repeated, irrelevant text about travel agents and airfare rates, which is likely a spam tactic. The sender's email address (producttestpanel@speedy.uwaterloo.ca) appears suspicious and unrelated to Southwest Airlines. There is also an unusual link at the end (trmedia320071406) that could be malicious."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains repeated, irrelevant text about travel agents and airfare rates, which is likely ...
# ================================================================================
#
# Evaluating Email 86...
# Phishing=True Reason="The email contains suspicious links, urgent language about medication expenses, and lacks proper authentication. The URL 'necessaryknow.com' is not a legitimate Canadian pharmacy website."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious links, urgent language about medication expenses, and lacks proper aut...
# ================================================================================
#
# Evaluating Email 87...
# Phishing=True Reason='The email contains suspicious content including offers for drugs without prescriptions, urgent language, and a misleading link. It appears to be a phishing attempt to steal personal information or money.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content including offers for drugs without prescriptions, urgent langu...
# ================================================================================
#
# Evaluating Email 88...
# Phishing=False Reason='The email appears to be a standard bounce message from a mail server, indicating a delivery failure. It contains no suspicious links or requests for personal information.'
#   Actual: Phishing
#   Predicted: Legitimate
#   Correct: False
#   Reason: The email appears to be a standard bounce message from a mail server, indicating a delivery failure....
# ================================================================================
#
# Evaluating Email 89...
# Phishing=True Reason="The email contains multiple suspicious elements such as misspelled words ('Invest0rs', 'nOw', 'St0cks'), urgent language encouraging immediate action, and a misleading subject line. It also includes a request to click on a link (though not explicitly present here) and promotes a stock with speculative claims. The presence of a paid promotion disclaimer and the use of a suspicious email address ('st0ck64 @ yahoo.com') further indicate it's phishing."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains multiple suspicious elements such as misspelled words ('Invest0rs', 'nOw', 'St0ck...
# ================================================================================
#
# Evaluating Email 90...
# Phishing=False Reason="The email appears to be a legitimate advocacy message from Families USA regarding the Medicare Prescription Drug Price Negotiation Act. It contains proper contact information, a clear call to action with a phone number, and a link to share the message. The content is about a real legislative issue, and there's no indication of deceptive intent or requests for sensitive information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate advocacy message from Families USA regarding the Medicare Presc...
# ================================================================================
#
# Evaluating Email 91...
# Phishing=True Reason='The email promotes a product (VPXL pills) with misleading claims about enhancing size, uses urgent and persuasive language, and includes a suspicious link. It lacks proper authentication and appears to be a scam.'
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email promotes a product (VPXL pills) with misleading claims about enhancing size, uses urgent a...
# ================================================================================
#
# Evaluating Email 92...
# Phishing=True Reason="The email contains suspicious content including offers for Microsoft products at extremely low prices (e.g., $50 for Office XP), which is highly unusual. The message also has poor grammar and formatting, and includes irrelevant text like 'concurred predictor competitionsabine rescind wicksashay psychopath' suggesting it may be spam or phishing."
#   Actual: Phishing
#   Predicted: Phishing
#   Correct: True
#   Reason: The email contains suspicious content including offers for Microsoft products at extremely low price...
# ================================================================================
#
# Evaluating Email 93...
# Phishing=False Reason="The email is a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mailing list. It contains technical conversation about programming concepts like recursion and stack overflow, with no suspicious links, urgent requests, or deceptive content."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mailing list. I...
# ================================================================================
#
# Evaluating Email 94...
# Phishing=False Reason='The email appears to be a legitimate business communication regarding scheduling changes for energy contracts. It contains specific details about market names, companies, and contractual obligations, which are typical in professional settings. There is no indication of deceptive content or requests for sensitive information.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication regarding scheduling changes for energy ...
# ================================================================================
#
# Evaluating Email 95...
# Phishing=False Reason="The email is a legitimate technical question about R programming. It's asking for help with subsetting vectors using boolean vectors, which is a common coding problem. The language is formal and the content is specific to R programming. There are no suspicious links, urgent requests, or attempts to steal information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a legitimate technical question about R programming. It's asking for help with subsetti...
# ================================================================================
#
# Evaluating Email 96...
# Phishing=False Reason="The email is a technical discussion about spam filtering methods and includes headers related to spam detection tools like SpamAssassin and ClamAV. There's no attempt to deceive or steal information."
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about spam filtering methods and includes headers related to spa...
# ================================================================================
#
# Evaluating Email 97...
# Phishing=False Reason='The email is a technical discussion about R programming language related to plotting with log scales. It contains no suspicious links, urgent requests, or personal information theft attempts.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical discussion about R programming language related to plotting with log scales...
# ================================================================================
#
# Evaluating Email 98...
# Phishing=False Reason='The email appears to be a legitimate business communication between colleagues discussing legal matters and scheduling a meeting. It does not contain typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive content.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate business communication between colleagues discussing legal matt...
# ================================================================================
#
# Evaluating Email 99...
# Phishing=False Reason='The email appears to be a legitimate internal business communication regarding deal tickets in Sitara for September. It contains specific details about nominations, activity numbers, and deadlines, which are typical of operational or financial reporting within an organization.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email appears to be a legitimate internal business communication regarding deal tickets in Sitar...
# ================================================================================
#
# Evaluating Email 100...
# Phishing=False Reason='The email is a technical inquiry about MySQL database setup and RODBC usage. It contains no suspicious links, urgent requests, or deceptive content. The sender is asking for help with date/time formatting issues when importing CSV data into MySQL.'
#   Actual: Legitimate
#   Predicted: Legitimate
#   Correct: True
#   Reason: The email is a technical inquiry about MySQL database setup and RODBC usage. It contains no suspicio...
#
# Evaluation completed

# %%
# Create results dataframe and display detailed results
results_df = pd.DataFrame(results)

print("=== DETAILED RESULTS ===")
print(results_df[['email_id', 'subject', 'actual_class', 'predicted_class', 'is_correct']].to_string(index=False))

print("\n=== LLM REASONING ===")
for result in results:
    print(f"\nEmail {result['email_id']}: {result['subject']}")
    print(f"Prediction: {result['predicted_class']}")
    print(f"Reason: {result['llm_reason']}")
# Out:
# === DETAILED RESULTS ===
#  email_id                                               subject actual_class predicted_class  is_correct
#         1                              cognitive linguistics...   Legitimate      Legitimate        True
#         2                 powerisk 2000 - more cocktail info...   Legitimate      Legitimate        True
#         3                                    Re: AC adaptor ...   Legitimate      Legitimate        True
#         4                               CNN.com Daily Top 10...     Phishing      Legitimate       False
#         5 ERV Notification:  (Violation/Notification Memo - ...   Legitimate      Legitimate        True
#         6                                      RE: NOx Model...   Legitimate      Legitimate        True
#         7                 REMINDER: Officers Meeting Tonight...   Legitimate      Legitimate        True
#         8         Free Full Length Tee_n Movies For Download...     Phishing        Phishing        True
#         9                 1 / 2000 lower colorado river vols...   Legitimate      Legitimate        True
#        10                      4 Days Only - $4.95 Shipping!...   Legitimate      Legitimate        True
#        11                  re : fw : luncheon meeting : asap...   Legitimate      Legitimate        True
#        12           Newsletter Coach'Invest - Septembre 2002...     Phishing      Legitimate       False
#        13                                     sup its Dylan ...     Phishing        Phishing        True
#        14 Save 13% at Amazon.com on "Garfield: A Cat and His...   Legitimate      Legitimate        True
#        15                             year - to - date deals...   Legitimate      Legitimate        True
#        16             Re: Match.com - You've Got Mail: Hello...   Legitimate      Legitimate        True
#        17                           Professional advertising...     Phishing        Phishing        True
#        18                      All products for your health!...     Phishing        Phishing        True
#        19 re : can we add the loss on sale calculation to ou...   Legitimate      Legitimate        True
#        20 Mr Denguele djaratigui, TREAT VERY URGENT AND CONF...     Phishing        Phishing        True
#        21                         RE: Garnet changing to APX...   Legitimate      Legitimate        True
#        22                              Re: Ximian apt repos?...   Legitimate      Legitimate        True
#        23                     The Skinny: Wed., May 23, 2007...   Legitimate      Legitimate        True
#        24                                Detecting UV light?...   Legitimate      Legitimate        True
#        25                     Make your fat friends envy you...     Phishing        Phishing        True
#        26                    Re: PDD15 implementation status...   Legitimate      Legitimate        True
#        27               No Pumps! No Surgery! No Exercises! ...     Phishing        Phishing        True
#        28                                You cannot do that!...     Phishing        Phishing        True
#        29                         assistants ' holiday gifts...   Legitimate      Legitimate        True
#        30           Start Date: 1/28/02; HourAhead hour: 5; ...   Legitimate      Legitimate        True
#        31                                  Marketing for you...     Phishing        Phishing        True
#        32                                        my students...   Legitimate      Legitimate        True
#        33                                         REPLY SOON...     Phishing        Phishing        True
#        34          RE: 2002 Committee Chair announcement.doc...   Legitimate      Legitimate        True
#        35                     AccuWeather.com Alert Forecast...   Legitimate      Legitimate        True
#        36                FPL Group Capital Guaranty to Enron...   Legitimate      Legitimate        True
#        37 US-CERT Technical Cyber Security Alert TA06-081A -...   Legitimate      Legitimate        True
#        38 [Mhln] We're   OnlinePharmacy, Save up to 80% on y...     Phishing        Phishing        True
#        39  Re: quadratic equation with interval coefficients...   Legitimate      Legitimate        True
#        40      Need financial aid for your online education?...     Phishing        Phishing        True
#        41                                          FNC Alert...   Legitimate      Legitimate        True
#        42               PLEASE I NEED YOUR URGENT ASSISTANCE...     Phishing        Phishing        True
#        43                                       my gratitude...   Legitimate        Phishing       False
#        44                               From Laurence Zavala...     Phishing        Phishing        True
#        45                                  FW: Weather Class...   Legitimate      Legitimate        True
#        46                       End the annoying obesity now...     Phishing        Phishing        True
#        47                            [R] legend + expression...   Legitimate      Legitimate        True
#        48                          Penis Enlargement - Truth...     Phishing        Phishing        True
#        49 looking around for quick healings ? simply en . te...     Phishing        Phishing        True
#        50                              Set your wife on fire...     Phishing        Phishing        True
#        51         A Composite Sketch of a Chief Risk Officer...   Legitimate      Legitimate        True
#        52                                               RE: ...   Legitimate      Legitimate        True
#        53              Re: upgrading is just like installing...   Legitimate      Legitimate        True
#        54 Re: [R] help with executing instruction every i-th...   Legitimate      Legitimate        True
#        55       Sex that hurts - Stretch Till they Squeal!!!...     Phishing        Phishing        True
#        56 FW: Sigma request (CAN Gas Phy Fwd East Spd < or =...   Legitimate      Legitimate        True
#        57                        Put your great ideas to use...     Phishing        Phishing        True
#        58           Re: pdd15 - How do I add a class method?...   Legitimate      Legitimate        True
#        59          Energy Markets Special Subscription Offer...     Phishing      Legitimate       False
#        60        linguist / phonetic request for information...   Legitimate      Legitimate        True
#        61 Introduction Regular Expressions are a widely-used...     Phishing      Legitimate       False
#        62 RE: Surprising   Evaluate your condition breadboar...     Phishing        Phishing        True
#        63                                 confidence is back...     Phishing        Phishing        True
#        64                                          Omaha.com...   Legitimate        Phishing       False
#        65              Go shopping with someone else's money...     Phishing        Phishing        True
#        66                               CNN.com Daily Top 10...     Phishing      Legitimate       False
#        67                               CNN.com Daily Top 10...     Phishing      Legitimate       False
#        68                                           Re: Re: ...     Phishing      Legitimate       False
#        69    Re: [CTDB and GFS] some troubles joining domain...   Legitimate      Legitimate        True
#        70 Your message to Python-3000 awaits moderator appro...   Legitimate      Legitimate        True
#        71                               save yourself Ursula...     Phishing        Phishing        True
#        72                                Re: Re: R4 Resistor...   Legitimate      Legitimate        True
#        73         interview schedule for seksan kiatsupaibul...   Legitimate        Phishing       False
#        74                          You, your computer and us...     Phishing        Phishing        True
#        75 New Power Products                                ...   Legitimate      Legitimate        True
#        76                  Can't afford medications you need...     Phishing        Phishing        True
#        77                                       revised resp...   Legitimate      Legitimate        True
#        78                                 Investor's Insight...     Phishing        Phishing        True
#        79                                  [UAI] EAAI'06 CFP...   Legitimate      Legitimate        True
#        80                                      Job Well Done...   Legitimate      Legitimate        True
#        81        ena balance sheet assets / responsibilities...   Legitimate      Legitimate        True
#        82      you launched a website but no one visits it ?...     Phishing        Phishing        True
#        83 [Ip-health] Associated Press: Brazil Says May Brea...   Legitimate      Legitimate        True
#        84              New TopCoder(R) Studio contest posted...   Legitimate      Legitimate        True
#        85 producttestpanel@speedy.uwaterloo.ca, Fly Anywhere...     Phishing        Phishing        True
#        86 Buy  medications in Canada and lower your medicati...     Phishing        Phishing        True
#        87                                Integral transforms...     Phishing        Phishing        True
#        88                                     failure notice...     Phishing      Legitimate       False
#        89        Invest0rs watch this One starting right nOw...     Phishing        Phishing        True
#        90 [Ip-health] Ask your Senators to vote "YES" on the...   Legitimate      Legitimate        True
#        91 Tried vacuum pumps and other advertised methods wi...     Phishing        Phishing        True
#        92               fifty dollars for office xp hannibal...     Phishing        Phishing        True
#        93              Re: [ILUG] slashdot EW Dijkstra humor...   Legitimate      Legitimate        True
#        94 Post BR petiition scheduling by East Wholesale Pow...   Legitimate      Legitimate        True
#        95 [R] Subsetting list of vectors with list of (boole...   Legitimate      Legitimate        True
#        96                 Re: Suggestions to block this spam...   Legitimate      Legitimate        True
#        97        Re: [R] plot log scale, axis original scale...   Legitimate      Legitimate        True
#        98                                     Private Equity...   Legitimate      Legitimate        True
#        99                               spot or firm tickets...   Legitimate      Legitimate        True
#       100                  [R] RODBC and Date/Time variables...   Legitimate      Legitimate        True
#
# === LLM REASONING ===
#
# Email 1: cognitive linguistics...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate academic book listing from Cambridge University Press, providing detailed information about various books on cognitive linguistics. It contains no suspicious links, urgent requests, or deceptive content.
#
# Email 2: powerisk 2000 - more cocktail info...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication from Powerisk 2000 event organizers. It contains standard corporate formatting, proper contact information, and the subject line mentions an important invitation with high priority. The content is about event invitations and there are no obvious signs of phishing such as suspicious links or requests for sensitive information.
#
# Email 3: Re: AC adaptor ...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate technical discussion about hardware components (AC adaptor voltage and L1 inductor) related to a HandyBoard project. The content is specific, non-urgent, and does not contain suspicious links or requests for sensitive information.
#
# Email 4: CNN.com Daily Top 10...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link is also present, which is typical for newsletters.
#
# Email 5: ERV Notification:  (Violation/Notification Memo - ...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate notification about a report. It mentions a specific date (10/18/2001) and refers to a report named 'Violation/Notification Memo'. The content is straightforward and does not contain any suspicious elements like urgent requests for personal information or malicious links.
#
# Email 6: RE: NOx Model...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal communication regarding a meeting about the NOx model. It includes specific details like date, time, location, and recipients. The link provided is to a USGS (United States Geological Survey) page, which is a reputable organization.
#
# Email 7: REMINDER: Officers Meeting Tonight...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate reminder for an officers meeting organized by Eta Kappa Nu, a recognized academic honor society. It contains specific details about the agenda, dates, times, and contact information. There are no suspicious links or requests for sensitive information.
#
# Email 8: Free Full Length Tee_n Movies For Download...
# Prediction: Phishing
# Reason: The email contains explicit adult content with suggestive titles and a suspicious link. It's likely a phishing attempt to lure users into clicking on malicious links or downloading inappropriate material.
#
# Email 9: 1 / 2000 lower colorado river vols...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication regarding a project or deal (158220) needing $10,000 for day 1. It references specific details like the sender's name (Tina Valadez), dates, and an organization (LCRA). The content is professional and lacks typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive language.
#
# Email 10: 4 Days Only - $4.95 Shipping!...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate promotional message from AutoSport Catalog. It contains standard marketing language, a clear call to action with a link, and contact information. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links. The domain name is consistent with the company's website.
#
# Email 11: re : fw : luncheon meeting : asap...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate communication between two individuals discussing a lunch meeting. It contains personal details, references previous interactions, and does not include any suspicious links or requests for sensitive information.
#
# Email 12: Newsletter Coach'Invest - Septembre 2002...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate newsletter from CoachInvest, providing updates on their services, investments, and events. It contains contact information, links to their website, and details about various companies they've invested in. The presence of an unsubscribe link and the structure of the content suggest it's a standard business communication rather than a phishing attempt.
#
# Email 13: sup its Dylan ...
# Prediction: Phishing
# Reason: The email contains explicit and inappropriate content promoting a male enhancement product with exaggerated claims. It includes suspicious links and lacks any legitimate context or sender information.
#
# Email 14: Save 13% at Amazon.com on "Garfield: A Cat and His...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate promotional message from Amazon.com. It contains specific product details, a valid link to the product page, and an opt-out option. The language is professional and consistent with Amazon's communication style.
#
# Email 15: year - to - date deals...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication with a specific subject line, contact information, and a reference to deals. There are no obvious signs of phishing such as urgent requests for personal information or suspicious links.
#
# Email 16: Re: Match.com - You've Got Mail: Hello...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate message from a Match.com user named Tracy. It contains personal details and asks for information, which is common in dating profiles. The tips provided about remaining anonymous on Match.com are relevant and match the platform's guidelines. There are no suspicious links or requests for sensitive information.
#
# Email 17: Professional advertising...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic greeting, offers for targeted email lists which may be used for spamming, and includes suspicious contact information. The subject line is vague and the content appears to be promoting unsolicited advertising.
#
# Email 18: All products for your health!...
# Prediction: Phishing
# Reason: The email contains suspicious links, urgent language about health issues, and claims of being verified by BBB and VISA which are not legitimate. The URL is also a random string, indicating it's likely a phishing attempt.
#
# Email 19: re : can we add the loss on sale calculation to ou...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication discussing financial reporting and scheduling. It contains specific details about financial calculations, asset allocation, and meeting agendas. The language is professional, and there are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or deceptive content.
#
# Email 20: Mr Denguele djaratigui, TREAT VERY URGENT AND CONF...
# Prediction: Phishing
# Reason: The email is a classic 'Nigerian prince' scam. It contains urgent requests for personal information, promises of large sums of money in exchange for fees or account details, and uses suspicious contact methods. The sender's identity is unverifiable, and the story is implausible.
#
# Email 21: RE: Garnet changing to APX...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication between employees of Enron and the California Independent System Operator (CAISO) regarding changes in power delivery agreements. It contains specific details about contracts, dates, and internal communications, which are typical in professional correspondence.
#
# Email 22: Re: Ximian apt repos?...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about updating GNOME versions and repository configurations. It contains no suspicious links, urgent requests, or attempts to steal information. The content is related to Linux package management and is likely from a legitimate user or community forum.
#
# Email 23: The Skinny: Wed., May 23, 2007...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate news summary from CBS News, containing standard content like headlines and an unsubscribe link. There's no suspicious request for personal information or urgent action.
#
# Email 24: Detecting UV light?...
# Prediction: Legitimate
# Reason: The email is a straightforward question about UV sensors, lacks any suspicious links or requests for sensitive information, and appears to be from an individual seeking technical assistance.
#
# Email 25: Make your fat friends envy you...
# Prediction: Phishing
# Reason: The email contains suspicious links, urgent language, and fake testimonials. It promotes a questionable product with exaggerated claims and uses a non-credible source (Oprah) to gain trust.
#
# Email 26: Re: PDD15 implementation status...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion between colleagues about code implementation. It contains no suspicious links, urgent requests, or deceptive content typical of phishing emails.
#
# Email 27: No Pumps! No Surgery! No Exercises! ...
# Prediction: Phishing
# Reason: The email promotes a dubious product with exaggerated claims of rapid physical enhancement, which is a common tactic in phishing scams to lure users into clicking malicious links. The URL provided appears suspicious and unrelated to legitimate healthcare products.
#
# Email 28: You cannot do that!...
# Prediction: Phishing
# Reason: The email contains suspicious content with no clear context, a nonsensical subject line, and an unclear request to read a document. These are common indicators of phishing attempts.
#
# Email 29: assistants ' holiday gifts...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate request for holiday gift contributions from a team member. It includes specific details about the recipients (Brenda, Maria, McKenzie), mentions contribution guidelines based on position and tenure, and requests funds by a deadline. The tone is professional and the content does not contain typical phishing indicators like urgent demands for personal information or suspicious links.
#
# Email 30: Start Date: 1/28/02; HourAhead hour: 5; ...
# Prediction: Legitimate
# Reason: The email appears to be a system-generated message related to scheduling data processing, containing technical terms and file paths typical of internal organizational communications. There's no deceptive content or request for sensitive information.
#
# Email 31: Marketing for you...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic subject line, offers of questionable services (offshore resources), and an unprofessional sender address. The presence of multiple email addresses in the body and the lack of specific details about the company or service make it highly likely to be a phishing attempt.
#
# Email 32: my students...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate communication between individuals discussing students' potential interest in Enron. It contains no suspicious links, urgent requests for personal information, or deceptive language.
#
# Email 33: REPLY SOON...
# Prediction: Phishing
# Reason: The email is a classic 'Nigerian prince' scam, which is a common phishing tactic. It contains urgent requests, asks for personal contact information, and offers a large sum of money in exchange for assistance. The sender's claims are implausible, and the request to reply through specific alternative emails is suspicious.
#
# Email 34: RE: 2002 Committee Chair announcement.doc...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal memorandum from EPSA (Electric Power Supply Association) regarding committee chair announcements. It contains specific details about the organization, dates, and individuals involved. The content is formal and structured like an official communication. There are no obvious signs of phishing such as urgent requests for personal information, suspicious links, or grammatical errors.
#
# Email 35: AccuWeather.com Alert Forecast...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate weather forecast from AccuWeather.com. It contains standard weather information, subscription details, and contact information. There are no suspicious links or requests for personal information.
#
# Email 36: FPL Group Capital Guaranty to Enron...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication regarding a legal document. It references specific details like the subject line, attached files, and includes contact information. The content is professional and does not contain typical phishing indicators such as urgent requests for personal information or suspicious links.
#
# Email 37: US-CERT Technical Cyber Security Alert TA06-081A -...
# Prediction: Legitimate
# Reason: The email is a legitimate technical security alert from US-CERT regarding a Sendmail vulnerability. It contains detailed information about the vulnerability, affected versions, solution steps, and references to official sources. The content is formal, structured, and aligns with known cybersecurity advisories.
#
# Email 38: [Mhln] We're   OnlinePharmacy, Save up to 80% on y...
# Prediction: Phishing
# Reason: The email contains multiple suspicious elements: urgent language ('Save up to 80%'), requests to click on links from unknown domains (http://kdcnq.movingthan.com, http://kxgt.movingthan.com), and the subject line has inconsistent spacing. The content also promotes buying prescription drugs without a prescription, which is illegal and highly suspicious.
#
# Email 39: Re: quadratic equation with interval coefficients...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate academic discussion about interval polynomial roots, referencing a specific paper and including a name (Vladik Kreinovich) that could be a real researcher. There's no suspicious content like urgent requests, links, or personal information demands.
#
# Email 40: Need financial aid for your online education?...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic subject line, lack of personalization, and an urgent call to action. The link provided (OnlineStudentFinancialAid.com) is not from a legitimate financial aid organization and may be a phishing site designed to steal personal information.
#
# Email 41: FNC Alert...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate news alert from FOX News. It contains standard unsubscribe information, proper copyright details, and a link to their official website. There's no suspicious request for personal information or urgent action.
#
# Email 42: PLEASE I NEED YOUR URGENT ASSISTANCE...
# Prediction: Phishing
# Reason: The email contains multiple red flags: urgent request to contact a specific individual, suspicious links (though not present here), grammatical errors, and requests for personal information. The sender's legitimacy is questionable as it claims to be from a non-existent organization with a fabricated reference number. The email also asks for sensitive details like full names, addresses, and phone numbers, which is typical of phishing attempts.
#
# Email 43: my gratitude...
# Prediction: Phishing
# Reason: The email contains several suspicious elements: 1) The subject line is generic and lacks specificity. 2) The body has grammatical errors and awkward phrasing (e.g., 'i would like to express my gratitude' instead of 'I would like to express...'). 3) The sender's name is unusual ('seksan') and the email appears to be from an unknown source. 4) There is no clear indication of a legitimate organization or contact information. 5) The request for further action without proper verification is typical of phishing attempts.
#
# Email 44: From Laurence Zavala...
# Prediction: Phishing
# Reason: The email contains nonsensical text with no coherent message, which is a common characteristic of phishing attempts. The subject line is generic and the body appears to be random characters or garbled text, likely intended to confuse or trick the recipient.
#
# Email 45: FW: Weather Class...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal communication about a weather class event. It includes specific details like the date, time, location, and speaker. The tone is professional, and there's no suspicious content or requests for sensitive information.
#
# Email 46: End the annoying obesity now...
# Prediction: Phishing
# Reason: The email contains suspicious content promoting a product called Anatrim for weight loss, with exaggerated claims and fake testimonials. The subject line is misleading and the body has poor grammar and formatting issues.
#
# Email 47: [R] legend + expression...
# Prediction: Legitimate
# Reason: The email is a legitimate request for help with R programming related to plotting and legends. It contains technical details about R-squared values and code snippets, indicating it's from someone seeking assistance on a specific coding problem.
#
# Email 48: Penis Enlargement - Truth...
# Prediction: Phishing
# Reason: The email contains explicit content related to penis enlargement, which is a common tactic in phishing scams to lure recipients. The message uses manipulative language and includes a suspicious link.
#
# Email 49: looking around for quick healings ? simply en . te...
# Prediction: Phishing
# Reason: The email contains multiple suspicious elements: fragmented text with grammatical errors, a suspicious link (http://7.biym.ourtruenature.com/8tl/), and offers that seem too good to be true. The content appears to be a mix of random phrases and may be attempting to deceive the recipient into clicking on a malicious link or providing personal information.
#
# Email 50: Set your wife on fire...
# Prediction: Phishing
# Reason: The subject line is highly inappropriate and offensive. The body contains nonsensical content with a suspicious link. There's no legitimate context or organization mentioned.
#
# Email 51: A Composite Sketch of a Chief Risk Officer...
# Prediction: Legitimate
# Reason: The email appears to be from a legitimate organization, The Conference Board of Canada, with proper contact information and a specific reference to a survey the recipient participated in. There are no suspicious links or urgent requests for personal information.
#
# Email 52: RE: ...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication. It contains standard corporate language, references specific individuals and companies, and discusses routine business matters like credit sheets and trading terms. There are no suspicious links, urgent requests for personal information, or deceptive content typical of phishing attempts.
#
# Email 53: Re: upgrading is just like installing...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about software installation and configuration. It references specific technical terms and code snippets, which are consistent with legitimate system administration or developer communication. There is no indication of phishing attempts such as requests for sensitive information, suspicious links, or urgent actions.
#
# Email 54: Re: [R] help with executing instruction every i-th...
# Prediction: Legitimate
# Reason: The email is a technical discussion about R programming language loops. It contains no suspicious links, urgent requests, or personal information theft attempts. The content is related to coding practices and debugging, which is typical for a legitimate technical support or community forum message.
#
# Email 55: Sex that hurts - Stretch Till they Squeal!!!...
# Prediction: Phishing
# Reason: The email contains explicit, offensive, and inappropriate content promoting adult material. It uses sensationalist language and includes a link to a questionable website. The request to 'remove me of this list' is suspicious and may be a tactic to trick the recipient into clicking on a malicious link or providing personal information.
#
# Email 56: FW: Sigma request (CAN Gas Phy Fwd East Spd < or =...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication regarding product types and sigma factors in the context of gas transactions. It contains specific technical details about energy contracts, references to real names and dates, and seems to be part of an ongoing professional discussion.
#
# Email 57: Put your great ideas to use...
# Prediction: Phishing
# Reason: The email contains suspicious links with non-credible domains (web.deberanebergallhosts.com), urgent language about turning ideas into fortune, and requests to click on links. The sender's information is not from a legitimate organization.
#
# Email 58: Re: pdd15 - How do I add a class method?...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate technical discussion about programming, specifically regarding adding class methods in a language like Perl 6 or Parrot. It's a follow-up to a question and contains no suspicious elements such as urgent requests, links, or personal information theft attempts.
#
# Email 59: Energy Markets Special Subscription Offer...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate subscription offer for an energy industry magazine. It provides clear information about the content, includes proper links, and has a standard opt-out mechanism. The language is professional and not coercive.
#
# Email 60: linguist / phonetic request for information...
# Prediction: Legitimate
# Reason: The email is a legitimate request from an individual seeking linguistic information about pronunciation without a tongue. It contains specific details about the context, asks for help with a novel, and provides a clear contact address. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing emails.
#
# Email 61: Introduction Regular Expressions are a widely-used...
# Prediction: Legitimate
# Reason: The email contains random, unrelated text fragments that don't form a coherent message. There's no clear attempt to deceive or steal information. The content appears to be nonsensical or possibly generated by an AI without a specific purpose.
#
# Email 62: RE: Surprising   Evaluate your condition breadboar...
# Prediction: Phishing
# Reason: The email contains suspicious links, grammatical errors, and irrelevant content. It also includes a list of luxury brands which is typical of phishing attempts to lure users into clicking malicious links.
#
# Email 63: confidence is back...
# Prediction: Phishing
# Reason: The email contains explicit content, suspicious links, and is likely a scam attempting to promote a product through deceptive means.
#
# Email 64: Omaha.com...
# Prediction: Phishing
# Reason: The email is extremely brief and lacks any context or details. The subject line 'Omaha.com' could be a phishing attempt to impersonate a legitimate source. The body message 'Phil, do you know this guy?' is suspicious and does not provide any clear information or purpose.
#
# Email 65: Go shopping with someone else's money...
# Prediction: Phishing
# Reason: The email contains suspicious elements such as a generic subject line, unclear sender information, and multiple suspicious links. The message appears to be attempting to deceive the recipient into clicking on potentially malicious links.
#
# Email 66: CNN.com Daily Top 10...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link and privacy policy are also present.
#
# Email 67: CNN.com Daily Top 10...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate CNN.com Daily Top 10 newsletter from August 2008. It contains standard news content with links to articles and videos, proper formatting, and official CNN contact information. The unsubscribe link is also present, which is typical for newsletters.
#
# Email 68: Re: Re: ...
# Prediction: Legitimate
# Reason: The email appears to be a fragment of a story or narrative, not a legitimate communication from an organization. It lacks any typical phishing elements like urgent requests, suspicious links, or personal information prompts.
#
# Email 69: Re: [CTDB and GFS] some troubles joining domain...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about code changes in a software project. It contains specific programming details and references to code repositories, which are typical of legitimate developer communications.
#
# Email 70: Your message to Python-3000 awaits moderator appro...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate notification from the Python-3000 mailing list moderator. It explains that a message was held for review due to being sent by a non-member to a members-only list and provides a specific URL for cancellation. The language is formal, the content is about a standard moderation process, and there's no urgent request for personal information or suspicious links.
#
# Email 71: save yourself Ursula...
# Prediction: Phishing
# Reason: The email contains suspicious links, grammatical errors, and an unclear subject line. The URL appears to be a fake domain. The sender's information is also not credible.
#
# Email 72: Re: Re: R4 Resistor...
# Prediction: Legitimate
# Reason: The email appears to be a technical discussion about resistor values in a circuit, likely between colleagues or experts. It contains no suspicious links, urgent requests for personal information, or deceptive content. The subject line and body are related to engineering specifications, which is consistent with a legitimate professional communication.
#
# Email 73: interview schedule for seksan kiatsupaibul...
# Prediction: Phishing
# Reason: The email contains multiple red flags: the subject line has a name that seems suspiciously formatted (seksan kiatsupaibul), the date is 2000 which is over two decades ago, the request to print documents for 'hard copies' is unusual, and there's no official company information or contact details. The email appears to be attempting to deceive the recipient with outdated information and unclear context.
#
# Email 74: You, your computer and us...
# Prediction: Phishing
# Reason: The email promotes a get-rich-quick scheme with unrealistic income claims (e.g., $100k/year), uses urgent language, contains suspicious links, and has poor grammar. The content resembles typical phishing tactics aimed at tricking recipients into clicking malicious links or providing personal information.
#
# Email 75: New Power Products                                ...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate notification from IntercontinentalExchange (ICE) regarding the launch of new power products. It provides specific details about market launches, portfolio adjustments, credit settings, and contact information for assistance.
#
# Email 76: Can't afford medications you need...
# Prediction: Phishing
# Reason: The email contains suspicious links, urgent language, and promotes a questionable pharmacy. The URL is not from a legitimate source and the content is designed to deceive the recipient into making a purchase.
#
# Email 77: revised resp...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication between individuals discussing work-related tasks. It lacks typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive language.
#
# Email 78: Investor's Insight...
# Prediction: Phishing
# Reason: The email contains multiple red flags such as urgent language, speculative stock price targets, grammatical errors (e.g., $O.50 instead of $0.50), and a disclaimer that appears to be a paid advertisement. The content seems to be promoting a micro-cap stock with high risk, which is typical of phishing or scam emails.
#
# Email 79: [UAI] EAAI'06 CFP...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate call for papers for an academic workshop. It contains specific details about the event, such as dates, location, topics, important dates, program committee members, submission guidelines, and organizers. The content is formal and professional, typical of academic communications. There are no suspicious links, urgent requests for personal information, or other common phishing indicators.
#
# Email 80: Job Well Done...
# Prediction: Legitimate
# Reason: The email appears to be a genuine acknowledgment of employees' efforts during the September 11th events. It contains specific details about TAP's role and Tracy Ramsey's actions, which suggests it's from a real person or organization. There are no suspicious links, urgent requests for personal information, or deceptive language typical of phishing emails.
#
# Email 81: ena balance sheet assets / responsibilities...
# Prediction: Legitimate
# Reason: The email is extremely brief, lacks specific details, and appears to be a placeholder or draft. It does not contain any suspicious elements like urgent requests, links, or personal information requests.
#
# Email 82: you launched a website but no one visits it ?...
# Prediction: Phishing
# Reason: The email contains numerous spelling and grammatical errors, such as 'oniine' instead of 'online', 'wiii be' instead of 'will be', and 'virtuaiiy' instead of 'virtually'. It also uses urgent language to prompt immediate action, which is a common phishing tactic. Additionally, the sender's name appears to be fabricated ('aiiegravincent') and there are suspicious characters in the email body.
#
# Email 83: [Ip-health] Associated Press: Brazil Says May Brea...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate news article from Associated Press about Brazil's potential action regarding an AIDS drug patent. It includes a link to the original source (Forbes) and contact information for the sender. There are no suspicious elements such as urgent requests for personal information or deceptive links.
#
# Email 84: New TopCoder(R) Studio contest posted...
# Prediction: Legitimate
# Reason: The email appears to be from a legitimate source, TopCoder Studio Team. It provides specific contest details, dates, and a link to the official website. The language is professional and there's no urgent request for personal information or suspicious links.
#
# Email 85: producttestpanel@speedy.uwaterloo.ca, Fly Anywhere...
# Prediction: Phishing
# Reason: The email contains repeated, irrelevant text about travel agents and airfare rates, which is likely a spam tactic. The sender's email address (producttestpanel@speedy.uwaterloo.ca) appears suspicious and unrelated to Southwest Airlines. There is also an unusual link at the end (trmedia320071406) that could be malicious.
#
# Email 86: Buy  medications in Canada and lower your medicati...
# Prediction: Phishing
# Reason: The email contains suspicious links, urgent language about medication expenses, and lacks proper authentication. The URL 'necessaryknow.com' is not a legitimate Canadian pharmacy website.
#
# Email 87: Integral transforms...
# Prediction: Phishing
# Reason: The email contains suspicious content including offers for drugs without prescriptions, urgent language, and a misleading link. It appears to be a phishing attempt to steal personal information or money.
#
# Email 88: failure notice...
# Prediction: Legitimate
# Reason: The email appears to be a standard bounce message from a mail server, indicating a delivery failure. It contains no suspicious links or requests for personal information.
#
# Email 89: Invest0rs watch this One starting right nOw...
# Prediction: Phishing
# Reason: The email contains multiple suspicious elements such as misspelled words ('Invest0rs', 'nOw', 'St0cks'), urgent language encouraging immediate action, and a misleading subject line. It also includes a request to click on a link (though not explicitly present here) and promotes a stock with speculative claims. The presence of a paid promotion disclaimer and the use of a suspicious email address ('st0ck64 @ yahoo.com') further indicate it's phishing.
#
# Email 90: [Ip-health] Ask your Senators to vote "YES" on the...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate advocacy message from Families USA regarding the Medicare Prescription Drug Price Negotiation Act. It contains proper contact information, a clear call to action with a phone number, and a link to share the message. The content is about a real legislative issue, and there's no indication of deceptive intent or requests for sensitive information.
#
# Email 91: Tried vacuum pumps and other advertised methods wi...
# Prediction: Phishing
# Reason: The email promotes a product (VPXL pills) with misleading claims about enhancing size, uses urgent and persuasive language, and includes a suspicious link. It lacks proper authentication and appears to be a scam.
#
# Email 92: fifty dollars for office xp hannibal...
# Prediction: Phishing
# Reason: The email contains suspicious content including offers for Microsoft products at extremely low prices (e.g., $50 for Office XP), which is highly unusual. The message also has poor grammar and formatting, and includes irrelevant text like 'concurred predictor competitionsabine rescind wicksashay psychopath' suggesting it may be spam or phishing.
#
# Email 93: Re: [ILUG] slashdot EW Dijkstra humor...
# Prediction: Legitimate
# Reason: The email is a legitimate discussion thread from the Irish Linux Users' Group (ILUG) mailing list. It contains technical conversation about programming concepts like recursion and stack overflow, with no suspicious links, urgent requests, or deceptive content.
#
# Email 94: Post BR petiition scheduling by East Wholesale Pow...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication regarding scheduling changes for energy contracts. It contains specific details about market names, companies, and contractual obligations, which are typical in professional settings. There is no indication of deceptive content or requests for sensitive information.
#
# Email 95: [R] Subsetting list of vectors with list of (boole...
# Prediction: Legitimate
# Reason: The email is a legitimate technical question about R programming. It's asking for help with subsetting vectors using boolean vectors, which is a common coding problem. The language is formal and the content is specific to R programming. There are no suspicious links, urgent requests, or attempts to steal information.
#
# Email 96: Re: Suggestions to block this spam...
# Prediction: Legitimate
# Reason: The email is a technical discussion about spam filtering methods and includes headers related to spam detection tools like SpamAssassin and ClamAV. There's no attempt to deceive or steal information.
#
# Email 97: Re: [R] plot log scale, axis original scale...
# Prediction: Legitimate
# Reason: The email is a technical discussion about R programming language related to plotting with log scales. It contains no suspicious links, urgent requests, or personal information theft attempts.
#
# Email 98: Private Equity...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate business communication between colleagues discussing legal matters and scheduling a meeting. It does not contain typical phishing indicators such as urgent requests for personal information, suspicious links, or deceptive content.
#
# Email 99: spot or firm tickets...
# Prediction: Legitimate
# Reason: The email appears to be a legitimate internal business communication regarding deal tickets in Sitara for September. It contains specific details about nominations, activity numbers, and deadlines, which are typical of operational or financial reporting within an organization.
#
# Email 100: [R] RODBC and Date/Time variables...
# Prediction: Legitimate
# Reason: The email is a technical inquiry about MySQL database setup and RODBC usage. It contains no suspicious links, urgent requests, or deceptive content. The sender is asking for help with date/time formatting issues when importing CSV data into MySQL.

# %%
# Calculate performance metrics
valid_results = [r for r in results if r['predicted_label'] is not None]
total_emails = len(valid_results)
correct_predictions = sum(1 for r in valid_results if r['is_correct'])

if total_emails > 0:
    accuracy = correct_predictions / total_emails
    
    # Calculate confusion matrix components
    tp = sum(1 for r in valid_results if r['actual_label'] == 1 and r['predicted_label'] == 1)  # True Positive
    tn = sum(1 for r in valid_results if r['actual_label'] == 0 and r['predicted_label'] == 0)  # True Negative
    fp = sum(1 for r in valid_results if r['actual_label'] == 0 and r['predicted_label'] == 1)  # False Positive
    fn = sum(1 for r in valid_results if r['actual_label'] == 1 and r['predicted_label'] == 0)  # False Negative
    
    print("=== PERFORMANCE METRICS ===")
    print(f"Total emails evaluated: {total_emails}")
    print(f"Correct predictions: {correct_predictions}")
    print(f"Accuracy: {accuracy:.2%}")
    
    print("\n=== CONFUSION MATRIX ===")
    print(f"True Positives (Phishing correctly identified): {tp}")
    print(f"True Negatives (Legitimate correctly identified): {tn}")
    print(f"False Positives (Legitimate misclassified as Phishing): {fp}")
    print(f"False Negatives (Phishing misclassified as Legitimate): {fn}")
    
    # Calculate precision, recall, F1 if applicable
    if tp + fp > 0:
        precision = tp / (tp + fp)
        print(f"\nPrecision: {precision:.2%}")
    
    if tp + fn > 0:
        recall = tp / (tp + fn)
        print(f"Recall: {recall:.2%}")
    
    if tp + fp > 0 and tp + fn > 0:
        f1_score = 2 * (precision * recall) / (precision + recall)
        print(f"F1 Score: {f1_score:.2%}")
    
else:
    print("No valid results to calculate metrics.")
# Out:
# === PERFORMANCE METRICS ===
# Total emails evaluated: 100
# Correct predictions: 89
# Accuracy: 89.00%
#
# === CONFUSION MATRIX ===
# True Positives (Phishing correctly identified): 34
# True Negatives (Legitimate correctly identified): 55
# False Positives (Legitimate misclassified as Phishing): 3
# False Negatives (Phishing misclassified as Legitimate): 8
#
# Precision: 91.89%
# Recall: 80.95%
# F1 Score: 86.08%

# %%
# Save results for future analysis
results_df.to_csv('llm_evaluation_results.csv', index=False)
print("Results saved to 'llm_evaluation_results.csv'")

# Display summary
print("\n=== EVALUATION SUMMARY ===")
print(f"Provider: {PROVIDER}")
print(f"Model: {MODEL}")
print(f"Sample size: {len(sample_df)} emails")
print(f"Successfully processed: {len(valid_results)} emails")
if total_emails > 0:
    print(f"Overall accuracy: {accuracy:.2%}")
# Out:
# Results saved to 'llm_evaluation_results.csv'
#
# === EVALUATION SUMMARY ===
# Provider: local
# Model: qwen3-30b-a3b
# Sample size: 100 emails
# Successfully processed: 100 emails
# Overall accuracy: 89.00%
